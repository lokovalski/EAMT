# %%
#$ Entity Masking
import json
from span_marker import SpanMarkerModel


def load_entities_mapping(file_path):
    """
    Loads entities and their translations from the given JSON file, skipping invalid lines.
    Args:
        file_path (str): Path to the JSON file containing entity mappings.
    Returns:
        list: A list of dictionaries representing the JSON data.
    """
    with open(file_path, 'r') as jf:
        try:
            return json.load(jf)  # Load the entire JSON array
        except json.JSONDecodeError as e:
            print(f"Error loading JSON file: {e}")
            return []


def mask_entities_with_spanmarker(text, model):
    """
    Masks named entities in text using predictions from SpanMarkerModel.

    Args:
        text (Union[str, List[str]]): Input text(s). Can be a single string or a list of strings.
        model (SpanMarkerModel): Pretrained SpanMarker model for entity prediction.

    Returns:
        Union[Tuple[str, dict], List[Tuple[str, dict]]]:
            - For a single string:
                - masked_text (str): Text with entities replaced by placeholders.
                - mapping (dict): Mapping of placeholders to original entities.
            - For a list of strings:
                - List of (masked_text, mapping) tuples.
    """
    # Check if input is a single string or a list of strings
    is_single_string = isinstance(text, str)
    if is_single_string:
        text = [text]  # Convert single string to list for uniform processing

    # Perform predictions using the model
    predictions = model.predict(text)  # Handles batch processing

    results = []
    for i, sentence in enumerate(text):
        masked_text = sentence
        mapping = {}
        type_counters = {}
        offset = 0

        # If no predictions for this sentence
        if not predictions[i]:  # Empty list
            print(f"No entities found for text: {sentence}")
            results.append((masked_text, mapping))
            continue

        # Process each entity in the prediction
        for entity in predictions[i]:
            entity_text = entity['span']
            entity_type = entity['label'].upper()
            start = entity['char_start_index']
            end = entity['char_end_index']

            # Counter for entity type
            if entity_type not in type_counters:
                type_counters[entity_type] = 1
            else:
                type_counters[entity_type] += 1

            # Generate a placeholder
            placeholder = f"[ENTITY_{entity_type}_{type_counters[entity_type]}]"

            # Replace entity with placeholder in the text
            start += offset
            end += offset
            masked_text = masked_text[:start] + placeholder + masked_text[end:]
            offset += len(placeholder) - len(entity_text)

            # Add to mapping
            mapping[placeholder] = {
                "original_text": entity_text,
                "type": entity_type,
                "confidence": entity['score'],
                "start": start,
                "end": end
            }

        results.append((masked_text, mapping))

    #if text input is a single string
    return results[0] if is_single_string else results

def ensure_pad_token(model):
    if not hasattr(model.tokenizer, "pad_token") or model.tokenizer.pad_token is None:
        print("Setting pad_token manually...")
        model.tokenizer.pad_token = "[PAD]"
        model.tokenizer.pad_token_id = model.tokenizer.convert_tokens_to_ids("[PAD]")

# %%
#$ MT Translation

from transformers import M2M100ForConditionalGeneration, M2M100Tokenizer

# Load the M2M100 model and tokenizer
model_name = "facebook/m2m100_418M"
model = M2M100ForConditionalGeneration.from_pretrained(model_name)
tokenizer = M2M100Tokenizer.from_pretrained(model_name)

def translate_with_placeholders_m2m(masked_text, mapping, src_lang, tgt_lang):
    """
    Translates the non-entity parts of a text and re-inserts placeholders using M2M100.

    Args:
        masked_text (str): Text with placeholders for entities.
        mapping (dict): Mapping of placeholders to entity details.
        src_lang (str): Source language code.
        tgt_lang (str): Target language code.

    Returns:
        str: Translated text with placeholders intact.
    """
    tokenizer.src_lang = src_lang

    # Encode and translate the entire sentence
    encoded_text = tokenizer(masked_text, return_tensors="pt")
    generated_tokens = model.generate(
        **encoded_text,
        forced_bos_token_id=tokenizer.get_lang_id(tgt_lang),
        max_length=128,  # Ensure sufficient length for translation
        early_stopping=True
    )

    # Decode the translated sentence
    translated_text = tokenizer.batch_decode(generated_tokens, skip_special_tokens=True)[0]
    return translated_text

# %%
#$ Entity Reintegration

from transformers import M2M100ForConditionalGeneration, M2M100Tokenizer

def translate_entity(entity, src_lang, tgt_lang):
    """
    Translates an entity if its type requires translation, otherwise returns the original entity.

    Args:
        entity (str): The placeholder or entity to process.
        src_lang (str): Source language code.
        tgt_lang (str): Target language code.

    Returns:
        str: The translated or original entity.
    """
    # types that should not be translated
    non_translatable_types = {"PER", "INST", "MEDIA", "PLANT", "VEHI"}

    # Check if the entity contains one of the non-translatable types
    if any(ntype in entity for ntype in non_translatable_types):
        return entity 

    # Translate the entity using M2M100
    tokenizer = M2M100Tokenizer.from_pretrained("facebook/m2m100_418M")
    model = M2M100ForConditionalGeneration.from_pretrained("facebook/m2m100_418M")
    tokenizer.src_lang = src_lang
    encoded_entity = tokenizer(entity, return_tensors="pt")
    generated_tokens = model.generate(**encoded_entity, forced_bos_token_id=tokenizer.get_lang_id(tgt_lang))
    translated_entity = tokenizer.batch_decode(generated_tokens, skip_special_tokens=True)[0]

    return translated_entity


def reintegrate_entities(translation, mapping, src_lang, tgt_lang):
    """
    Replaces placeholders in the translated text with original or translated entities.

    Args:
        translation (str): Translated text with placeholders.
        mapping (dict): Mapping of placeholders to original entities.
        src_lang (str): Source language code.
        tgt_lang (str): Target language code.

    Returns:
        str: Translation with entities reintegrated.
    """
    for placeholder, entity_info in mapping.items():
        # Get the original entity
        original_entity = entity_info["original_text"]

        # Translate the entity if needed
        translated_entity = translate_entity(original_entity, src_lang, tgt_lang)

        # Replace placeholder with the translated entity
        translation = translation.replace(placeholder, translated_entity)

    return translation

# %%
import os
it_datapath = os.path.abspath('data/italian_test.json')

    # Step 1: Load the data
print("Loading Italian data...")
italian_data = load_entities_mapping(it_datapath)
# Out:
# Loading Italian data...

# %%
italian_data
# Out:
# [{'id': '86fb5e94',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'How old is the author of the Goosebumps series?',
#   'target': "Quanti anni ha l'autore della serie Piccoli Brividi?",
#   'entities': {'Q3260367': {'it': 'Piccoli brividi', 'en': 'Goosebumps'}},
#   'from': 'mintaka'},
#  {'id': '14b9185d',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Which of the three largest islands in the Mediterranean Sea is not part of Italy?',
#   'target': 'Quale delle tre isole più grandi del Mediterraneo non è italiana?',
#   'entities': {'Q38': {'it': 'Italia', 'en': 'Italy'}},
#   'from': 'mintaka'},
#  {'id': 'ff37d660',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'What house did Severus Snape belong to?',
#   'target': 'Qual è la casa di Severus Piton?',
#   'entities': {'Q176772': {'it': 'Severus Piton', 'en': 'Severus Snape'}},
#   'from': 'mintaka'},
#  {'id': 'ff9a84d2',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Who is the current president of Japan?',
#   'target': "Chi è l'attuale presidente del Giappone?",
#   'entities': {'Q17': {'it': 'Giappone', 'en': 'Japan'}},
#   'from': 'mintaka'},
#  {'id': 'c9f42ee8',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'What date was the actress born who played Scarlett in "Gone with the Wind"?',
#   'target': 'Qual è la data di nascita dell\'attrice che impersonò Rossella in "Via col vento"?',
#   'entities': {'Q2875': {'it': 'Via col vento', 'en': 'Gone with the Wind'}},
#   'from': 'mintaka'},
#  {'id': '05dd0471',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Who is president of Peru?',
#   'target': 'Chi è il Presidente del Perù?',
#   'entities': {'Q419': {'it': 'Perù', 'en': 'Peru'}},
#   'from': 'mintaka'},
#  {'id': '10f0085c',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Did Queen Elizabeth I have the longest reign in the UK?',
#   'target': 'La Regina Elisabetta I ha regnato più a lungo di tutti nel Regno Unito?',
#   'entities': {'Q145': {'it': 'Regno Unito', 'en': 'United Kingdom'}},
#   'from': 'mintaka'},
#  {'id': 'f01e2309',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Which dynasty built the Great Wall of China?',
#   'target': 'Quale dinastia fece costruire la Grande Muraglia Cinese?',
#   'entities': {'Q12501': {'it': 'Grande muraglia cinese',
#     'en': 'Great Wall of China'}},
#   'from': 'mintaka'},
#  {'id': '7487d160',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Who was the oldest person when they started their reign over the United Kingdom?',
#   'target': 'Chi è la persona più anziana ad aver iniziato il proprio regno sul Regno Unito?',
#   'entities': {'Q145': {'it': 'Regno Unito', 'en': 'United Kingdom'}},
#   'from': 'mintaka'},
#  {'id': '4fd117b2',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Is the Yangtze or Yellow River longer?',
#   'target': 'È più lungo il Fiume Azzurro o il Fiume Giallo?',
#   'entities': {'Q7355': {'it': 'Fiume Giallo', 'en': 'Yellow River'},
#    'Q5413': {'it': 'Fiume Azzurro', 'en': 'Yangtze'}},
#   'from': 'mintaka'},
#  {'id': 'f99594ce',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Which main series Pokémon game were you not able to transfer every Pokémon to?',
#   'target': 'In quante principale gioco della serie Pokemon tu non sei stato in grado di trasferire ciascun Pokemon?',
#   'entities': {'Q864': {'it': 'Pokémon', 'en': 'Pokémon'}},
#   'from': 'mintaka'},
#  {'id': 'b69991e0',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Who directed the movie that is based on the second book of The Lord of the Rings series?',
#   'target': 'Chi ha diretto il film basato sul secondo libro della saga Il Signore degli Anelli?',
#   'entities': {'Q15228': {'it': 'Il Signore degli Anelli',
#     'en': 'The Lord of the Rings'}},
#   'from': 'mintaka'},
#  {'id': '78fe9980',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Which volcanoes in Hawaii are not extinct?',
#   'target': 'Quali vulcani hawaiani non sono spenti?',
#   'entities': {'Q782': {'it': 'Hawaii', 'en': 'Hawaii'}},
#   'from': 'mintaka'},
#  {'id': 'eef2eca2',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Is Berlin the capital of Germany?',
#   'target': 'La capitale della Germania è Berlino?',
#   'entities': {'Q183': {'it': 'Germania', 'en': 'Germany'}},
#   'from': 'mintaka'},
#  {'id': '20511234',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'What is the political party of President Cyril Ramaphosa of South Africa?',
#   'target': 'Qual è il partito politico del presidente Cyril Ramaphosa del Sud Africa?',
#   'entities': {'Q258': {'it': 'Sudafrica', 'en': 'South Africa'}},
#   'from': 'mintaka'},
#  {'id': '145f7241',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Who are some characters in the Lord of Rings books but not the movies?',
#   'target': 'Chi sono i personaggi de "Il signore degli anelli" che compaiono nei libri ma non nei film?',
#   'entities': {'Q15228': {'it': 'Il Signore degli Anelli',
#     'en': 'The Lord of the Rings'}},
#   'from': 'mintaka'},
#  {'id': '5edaa144',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Which mountain in Brazil is smaller: Pedra da Mina or Monte Caburai?',
#   'target': 'Quale monte in Brasile è più basso: Pedra da Mina o Monte Caburai?',
#   'entities': {'Q155': {'it': 'Brasile', 'en': 'Brazil'}},
#   'from': 'mintaka'},
#  {'id': '41128178',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Which volcano in the Philippines is not taller than 311 meters?',
#   'target': 'Quale vulcano nelle Filippine non supera i 311 metri di altezza?',
#   'entities': {'Q928': {'it': 'Filippine', 'en': 'Philippines'}},
#   'from': 'mintaka'},
#  {'id': '5aa3fb08',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Yoshihide Suga serves as what political position in the government of Japan?',
#   'target': 'Quale carica politica ricoprì Yoshihide Suga nel governo del Giappone?',
#   'entities': {'Q17': {'it': 'Giappone', 'en': 'Japan'}},
#   'from': 'mintaka'},
#  {'id': '61e19f4e',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'What was the first book in the Wheel of Time series?',
#   'target': 'Qual è stato il primo libro della collana La Ruota del Tempo?',
#   'entities': {'Q4470': {'it': 'La Ruota del Tempo',
#     'en': 'The Wheel of Time'}},
#   'from': 'mintaka'},
#  {'id': '80ebdb26',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Who was the first African-American to direct a major motion picture?',
#   'target': 'Chi è stato il primo afro-americano a dirigere un importante lungometraggio?',
#   'entities': {'Q49085': {'it': 'afroamericano', 'en': 'African Americans'}},
#   'from': 'mintaka'},
#  {'id': 'a735999b',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': "Who was the director of The Goodfellas and attended school at New York University's School of Film?",
#   'target': 'Chi è stato il regista di Quei bravi ragazzi che ha frequentato la scuola di cinema di New York?',
#   'entities': {'Q42047': {'it': 'Quei bravi ragazzi', 'en': 'Goodfellas'}},
#   'from': 'mintaka'},
#  {'id': 'f46a2a65',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Which country has a larger population, Germany or Italy?',
#   'target': 'Quale Paese ha maggiore popolazione, Germania o Italia?',
#   'entities': {'Q183': {'it': 'Germania', 'en': 'Germany'},
#    'Q38': {'it': 'Italia', 'en': 'Italy'}},
#   'from': 'mintaka'},
#  {'id': 'c2dd55fb',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Did Harry Potter and the Prisoner of Azkaban come out before Harry Potter and the Goblet of Fire?',
#   'target': 'Harry Potter e il prigioniero di Azkaban è uscito prima di Harry Potter e il calice di fuoco?',
#   'entities': {'Q102225': {'it': 'Harry Potter e il calice di fuoco',
#     'en': 'Harry Potter and the Goblet of Fire'},
#    'Q102448': {'it': 'Harry Potter e il prigioniero di Azkaban',
#     'en': 'Harry Potter and the Prisoner of Azkaban'}},
#   'from': 'mintaka'},
#  {'id': '9ba2150a',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'What pivotal naval battle of World War II occurred six months after the Japanese attack on Pearl Harbor?',
#   'target': "Quale decisiva battaglia navale, durante la seconda guerra mondiale, si combattè sei mesi dopo l'attacco giapponese a Pearl Harbor?",
#   'entities': {'Q17': {'it': 'Giappone', 'en': 'Japan'},
#    'Q362': {'it': 'seconda guerra mondiale', 'en': 'World War II'}},
#   'from': 'mintaka'},
#  {'id': '41aa2eef',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Which lasted longer, the American Revolutionary War or the Civil War?',
#   'target': "Qual è durata di più, la Guerra d'Indipendenza americana o la Guerra Civile?",
#   'entities': {'Q40949': {'it': "guerra d'indipendenza americana",
#     'en': 'American Revolutionary War'}},
#   'from': 'mintaka'},
#  {'id': 'bc3e6e32',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'When did the first Wheel of Time book come out?',
#   'target': 'Quando è uscito il primo libro La Ruota del Tempo?',
#   'entities': {'Q4470': {'it': 'La Ruota del Tempo',
#     'en': 'The Wheel of Time'}},
#   'from': 'mintaka'},
#  {'id': 'e1fcf7f9',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'How many Super Bowl victories do the Green Bay Packers have?',
#   'target': 'Quanti Super Bowl hanno vinto i Greenbay Packers?',
#   'entities': {'Q213837': {'it': 'Green Bay Packers',
#     'en': 'Green Bay Packers'}},
#   'from': 'mintaka'},
#  {'id': '55a25876',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'In Animal Crossing: New Horizons, who is the sister of the museum curator?',
#   'target': 'Nel gioco Animal Crossing: New Horizon, chi è la sorella del curatore museale?',
#   'entities': {'Q64566657': {'it': 'Animal Crossing: New Horizons',
#     'en': 'Animal Crossing: New Horizons'}},
#   'from': 'mintaka'},
#  {'id': '051bac35',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'How many senators have read "Green eggs and ham" on the senate floor?',
#   'target': 'Quanti senatori hanno letto "Prosciutto e uova verdi" sul pavimento del Senato?',
#   'entities': {'Q2759523': {'it': 'Prosciutto e uova verdi',
#     'en': 'Green Eggs and Ham'}},
#   'from': 'mintaka'},
#  {'id': 'b415a817',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'What Tolkien novel is set in the Lord of the Ring Universe but not a part of the trilogy?',
#   'target': "Quale romanzo di Tolkien è inserito nell'universo del Signore degli anelli ma non fa parte della Trilogia?",
#   'entities': {'Q15228': {'it': 'Il Signore degli Anelli',
#     'en': 'The Lord of the Rings'}},
#   'from': 'mintaka'},
#  {'id': '115379ae',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Is Mount Everest taller than Mount Elbrus?',
#   'target': 'Il Monte Everest è più alto del Monte Elbrus?',
#   'entities': {'Q513': {'it': 'Everest', 'en': 'Mount Everest'},
#    'Q43105': {'it': 'monte Elbrus', 'en': 'Mount Elbrus'}},
#   'from': 'mintaka'},
#  {'id': '33e38cd2',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'What is the capital of the country where the Andes mountain range is located?',
#   'target': 'Qual è la capitale del paese dove si trova la catena montuosa delle Ande?',
#   'entities': {'Q5456': {'it': 'Ande', 'en': 'Andes'}},
#   'from': 'mintaka'},
#  {'id': 'a8808c07',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Who was the second female pharaoh of Egypt?',
#   'target': "Chi fu la seconda donna faraone d'Egitto?",
#   'entities': {'Q79': {'it': 'Egitto', 'en': 'Egypt'}},
#   'from': 'mintaka'},
#  {'id': '6d78dab9',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Who is the leader in France?',
#   'target': 'Chi governa la Francia?',
#   'entities': {'Q142': {'it': 'Francia', 'en': 'France'}},
#   'from': 'mintaka'},
#  {'id': '80d5b7ae',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Is Burj Khalifa the tallest building in China?',
#   'target': "Il Burj Khalifa è l'edificio più alto della Cina?",
#   'entities': {'Q148': {'it': 'Cina', 'en': "People's Republic of China"}},
#   'from': 'mintaka'},
#  {'id': '3045bc57',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'What year was the first Lord of the Rings movie?',
#   'target': 'Di che anno è il primo film de Il Signore Degli Anelli?',
#   'entities': {'Q190214': {'it': 'Il Signore degli Anelli',
#     'en': 'The Lord of the Rings trilogy'}},
#   'from': 'mintaka'},
#  {'id': 'f9abc504',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Who was the first king of Norway?',
#   'target': 'Chi è stato il primo Re di Norvegia?',
#   'entities': {'Q20': {'it': 'Norvegia', 'en': 'Norway'}},
#   'from': 'mintaka'},
#  {'id': 'f8ff6618',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'What is the biggest city by population in China?',
#   'target': 'Quale città è la più grande per popolazione in Cina?',
#   'entities': {'Q148': {'it': 'Cina', 'en': "People's Republic of China"}},
#   'from': 'mintaka'},
#  {'id': 'ae649eaa',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Is the Yellow River longer than Yangtze?',
#   'target': 'Il Fiume Giallo è più lungo del Fiume Azzurro?',
#   'entities': {'Q7355': {'it': 'Fiume Giallo', 'en': 'Yellow River'},
#    'Q5413': {'it': 'Fiume Azzurro', 'en': 'Yangtze'}},
#   'from': 'mintaka'},
#  {'id': 'ebc9b970',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Which native American language was used by the US Marines as a code language during World War II?',
#   'target': "Quale lingua nativa d'America fu utilizzata dai marines come lingua in codice durante la seconda guerra mondiale?",
#   'entities': {'Q362': {'it': 'seconda guerra mondiale',
#     'en': 'World War II'}},
#   'from': 'mintaka'},
#  {'id': '52b6f89c',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': "Who won South Carolina's 2020 GOP Senate Primary?",
#   'target': 'Chi ha vinto le primarie al senato del partito repubblicano in Carolina del Sud?',
#   'entities': {'Q1456': {'it': 'Carolina del Sud', 'en': 'South Carolina'},
#    'Q29468': {'it': 'Partito Repubblicano', 'en': 'Republican Party'}},
#   'from': 'mintaka'},
#  {'id': 'dd13ab84',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Who is supposed to have founded Rome?',
#   'target': 'Chi si crede abbia fondato Roma?',
#   'entities': {'Q220': {'it': 'Roma', 'en': 'Rome'}},
#   'from': 'mintaka'},
#  {'id': 'd70baaf2',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Is Washington, D.C. located in the state of Washington?',
#   'target': 'Washington D.C. si trova nello stato di Washington?',
#   'entities': {'Q61': {'it': 'Washington', 'en': 'Washington, D.C.'}},
#   'from': 'mintaka'},
#  {'id': '6dab62f7',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'What is the largest city in Canada not found outside Saskatchewan?',
#   'target': 'Qual è la città più grande del Saskatchewan canadese?',
#   'entities': {'Q16': {'it': 'Canada', 'en': 'Canada'}},
#   'from': 'mintaka'},
#  {'id': '27820b49',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Did Ireland fight during the Second World War?',
#   'target': "L'Irlanda ha combattuto durante la Seconda Guerra Mondiale?",
#   'entities': {'Q362': {'it': 'seconda guerra mondiale', 'en': 'World War II'},
#    'Q27': {'it': 'Irlanda', 'en': 'Ireland'}},
#   'from': 'mintaka'},
#  {'id': 'cf161d04',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Which book was published first, 1984 or Brave New World?',
#   'target': 'Quale libro è stato pubblicato per primo, "1984" o "Il mondo nuovo"?',
#   'entities': {'Q191949': {'it': 'Il mondo nuovo', 'en': 'Brave New World'}},
#   'from': 'mintaka'},
#  {'id': '44c30f4d',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'What was the name of the third Back to the Future movie?',
#   'target': 'Come si chiama il terzo film di Ritorno al Futuro?',
#   'entities': {'Q91540': {'it': 'Ritorno al futuro',
#     'en': 'Back to the Future'}},
#   'from': 'mintaka'},
#  {'id': '7f529979',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Did Ernest Hemingway write The Old Man and the Sea?',
#   'target': 'Ernest Hemingway ha scritto Il vecchio e il mare?',
#   'entities': {'Q26505': {'it': 'Il vecchio e il mare',
#     'en': 'The Old Man and the Sea'}},
#   'from': 'mintaka'},
#  {'id': 'e13e2305',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Which oceans do not border China?',
#   'target': 'Quali oceani non bagnano la Cina?',
#   'entities': {'Q148': {'it': 'Cina', 'en': "People's Republic of China"}},
#   'from': 'mintaka'},
#  {'id': '37f55556',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Where was the author of The Hobbit born?',
#   'target': 'Dove è nato l\'autore de "Lo Hobbit"?',
#   'entities': {'Q74287': {'it': 'Lo Hobbit', 'en': 'The Hobbit'}},
#   'from': 'mintaka'},
#  {'id': '9b45b657',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'How many U.S. states border the Pacific Ocean?',
#   'target': "Quanti stati americani si affacciano sull'Oceano Pacifico?",
#   'entities': {'Q98': {'it': 'Oceano Pacifico', 'en': 'Pacific Ocean'}},
#   'from': 'mintaka'},
#  {'id': '6f41e0ad',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Is Cuba the largest island in the Caribbean?',
#   'target': 'Cuba è la maggior isola dei Caraibi?',
#   'entities': {'Q664609': {'it': 'Caraibi', 'en': 'Caribbean'}},
#   'from': 'mintaka'},
#  {'id': 'cc815af7',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Who designed The White House?',
#   'target': 'Chi ha progettato la Casa Bianca?',
#   'entities': {'Q35525': {'it': 'Casa Bianca', 'en': 'White House'}},
#   'from': 'mintaka'},
#  {'id': '661382fe',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Which state has more electoral votes, South Carolina or North Carolina?',
#   'target': 'Quale stato ha più voti elettorali, Carolina del Sud o del Nord?',
#   'entities': {'Q1456': {'it': 'Carolina del Sud', 'en': 'South Carolina'}},
#   'from': 'mintaka'},
#  {'id': 'e993d5ec',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Which series has more books, Harry Potter or Lord of the Rings?',
#   'target': 'Quale serie ha più libri: "Harry Potter" o "Il signore degli anelli"?',
#   'entities': {'Q15228': {'it': 'Il Signore degli Anelli',
#     'en': 'The Lord of the Rings'}},
#   'from': 'mintaka'},
#  {'id': '3bb14d10',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Who was the president of the US when the Korean War started?',
#   'target': 'Chi era il presidente degli Stati Uniti quando scoppiò la guerra di Corea?',
#   'entities': {'Q8663': {'it': 'guerra di Corea', 'en': 'Korean War'}},
#   'from': 'mintaka'},
#  {'id': '98bdfdb7',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'In what franchise does Ebony Maw exist?',
#   'target': "In quale franchise è presente Fauce d'Ebano?",
#   'entities': {'Q20979240': {'it': "Fauce d'Ebano", 'en': 'Ebony Maw'}},
#   'from': 'mintaka'},
#  {'id': 'e293e18e',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'What is the tallest building in the capital city of Italy?',
#   'target': "Quale è l'edificio più grande della capitale dell'Italia?",
#   'entities': {'Q38': {'it': 'Italia', 'en': 'Italy'}},
#   'from': 'mintaka'},
#  {'id': '520d285d',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'How many countries conformed "The Big Three" in WW II?',
#   'target': 'Quali Paesi hanno costituito "I Grandi Tre" nella Seconda Guerra Mondiale?',
#   'entities': {'Q362': {'it': 'seconda guerra mondiale',
#     'en': 'World War II'}},
#   'from': 'mintaka'},
#  {'id': '1cb9a9a1',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Which of the Goosebumps books released in 1992, does not have 132 pages?',
#   'target': 'Quali libro di "Piccoli Brividi", pubblicato nel 1992, non ha 132 pagine?',
#   'entities': {'Q3260367': {'it': 'Piccoli brividi', 'en': 'Goosebumps'}},
#   'from': 'mintaka'},
#  {'id': '65d3db2e',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Who was the king of Jerusalem who could not move his limbs due to leprosy?',
#   'target': 'Chi era il re di Gerusalemme che non poteva muovere le braccia per via della lebbra?',
#   'entities': {'Q1218': {'it': 'Gerusalemme', 'en': 'Jerusalem'}},
#   'from': 'mintaka'},
#  {'id': '3232b60a',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Who was a leader of the Progressive movement that proclaimed American entrance into World War I?',
#   'target': "Chi era il leader del Movimento Progressista che proclamò l'entrata in guerra dell'America nella Prima Guerra Mondiale?",
#   'entities': {'Q361': {'it': 'prima guerra mondiale', 'en': 'World War I'}},
#   'from': 'mintaka'},
#  {'id': '0d9b5596',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Is Dr Wiley a character in the Megaman games?',
#   'target': 'Dr Wiley è un personaggio dei giochi di Megaman?',
#   'entities': {'Q7565689': {'it': 'Mega Man', 'en': 'Mega Man'}},
#   'from': 'mintaka'},
#  {'id': '67e572f1',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'How many United States presidents served in the American Civil War?',
#   'target': 'Quanti Presidenti degli Stati Uniti hanno servito nella Guerra di Secessione Americana?',
#   'entities': {'Q8676': {'it': 'guerra di secessione americana',
#     'en': 'American Civil War'}},
#   'from': 'mintaka'},
#  {'id': 'e0f8c56d',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'What river flows through Russia and is the longest river in Europe?',
#   'target': "Quale fiume che attraversa la Russia è il più lungo d'Europa?",
#   'entities': {'Q46': {'it': 'Europa', 'en': 'Europe'}},
#   'from': 'mintaka'},
#  {'id': '7ae6f61f',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Who directed the movie that was based on the first book of the Hobbit?',
#   'target': 'Chi ha diretto il film basato sul primo libro de "Lo Hobbit"?',
#   'entities': {'Q74287': {'it': 'Lo Hobbit', 'en': 'The Hobbit'}},
#   'from': 'mintaka'},
#  {'id': 'c0911157',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'What is the second longest river in Europe?',
#   'target': 'Qual è il secondo fiume più lungo in Europa?',
#   'entities': {'Q46': {'it': 'Europa', 'en': 'Europe'}},
#   'from': 'mintaka'},
#  {'id': '2d0c7738',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'What three countries formed a Grand Alliance during WW II, and who could not agree on how the War should be fought?',
#   'target': 'Quali tre nazioni hanno formato una Grande Alleanza durante la Seconda Guerra Mondiale non riuscirono ad essere in accordo su come la guerra sarebbe dovuta essere combattuta?',
#   'entities': {'Q362': {'it': 'seconda guerra mondiale',
#     'en': 'World War II'}},
#   'from': 'mintaka'},
#  {'id': '6726f18f',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'How many witches were there in the Wizard of Oz?',
#   'target': 'Quante streghe ci sono nel romanzo il Mago di Oz?',
#   'entities': {'Q193695': {'it': 'Il mago di Oz', 'en': 'The Wizard of Oz'}},
#   'from': 'mintaka'},
#  {'id': '9c74edbc',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Which Goosebumps book was released in 1992, but not before October?',
#   'target': 'Quale libro di Piccoli brividi è stato pubblicato nel 1992, ma non prima di ottobre?',
#   'entities': {'Q3260367': {'it': 'Piccoli brividi', 'en': 'Goosebumps'}},
#   'from': 'mintaka'},
#  {'id': '1b70e707',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Which war lasted longer, the American Revolution or the French Revolution?',
#   'target': 'Quale guerra durò di più, la rivoluzione americana o la francese?',
#   'entities': {'Q192769': {'it': 'rivoluzione americana',
#     'en': 'American Revolution'}},
#   'from': 'mintaka'},
#  {'id': '79b95484',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Who wrote The Shining?',
#   'target': 'Chi ha scritto Shining?',
#   'entities': {'Q186341': {'it': 'Shining', 'en': 'The Shining'}},
#   'from': 'mintaka'},
#  {'id': '54859c6c',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'What game in the City Building series takes place in ancient Rome and was released after 2000?',
#   'target': "Quale gioco nella serie City Building è ambientato nell'antica Roma e è uscito dopo il 2000?",
#   'entities': {'Q220': {'it': 'Roma', 'en': 'Rome'}},
#   'from': 'mintaka'},
#  {'id': '2fc6de9d',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'What is the full name of the Hobbit that accompanies Frodo in the Lord of the Rings?',
#   'target': 'Qual è il nome completo dello hobbit che accompagna Frodo nel Signore degli Anelli?',
#   'entities': {'Q15228': {'it': 'Il Signore degli Anelli',
#     'en': 'The Lord of the Rings'}},
#   'from': 'mintaka'},
#  {'id': '3084a49f',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'When was the director of The Sandlot born?',
#   'target': 'Quando è nato il regista di I ragazzi vincenti?',
#   'entities': {'Q2369793': {'it': 'I ragazzi vincenti', 'en': 'The Sandlot'}},
#   'from': 'mintaka'},
#  {'id': '593277bc',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'How many U.S. states border Mexico?',
#   'target': 'Quanti stati americani confinano con il Messico?',
#   'entities': {'Q96': {'it': 'Messico', 'en': 'Mexico'}},
#   'from': 'mintaka'},
#  {'id': 'd7aaa764',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Who was the 35th president of the USA?',
#   'target': "Chi fu il 35° presidente degli Stati Uniti d'America?",
#   'entities': {'Q30': {'it': "Stati Uniti d'America",
#     'en': 'United States of America'}},
#   'from': 'mintaka'},
#  {'id': '56bc050c',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Who led Germany after Adolf Hitler?',
#   'target': 'Chi ha governato la Germania dopo Adolf Hitler?',
#   'entities': {'Q183': {'it': 'Germania', 'en': 'Germany'}},
#   'from': 'mintaka'},
#  {'id': '6bcea5de',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'What kind of political system does Japan have?',
#   'target': 'Che tipo di sistema politico ha il Giappone?',
#   'entities': {'Q17': {'it': 'Giappone', 'en': 'Japan'}},
#   'from': 'mintaka'},
#  {'id': '668fb3b3',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Which country was founded first, Ethiopia or Nigeria?',
#   'target': 'Quale paese è stato fondato per primo, Etiopia o Nigeria?',
#   'entities': {'Q115': {'it': 'Etiopia', 'en': 'Ethiopia'}},
#   'from': 'mintaka'},
#  {'id': '42cfa4ab',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Which US president never lived in the White House?',
#   'target': 'Quale Presidente degli Stati Uniti non ha mai vissuto nella Casa Bianca?',
#   'entities': {'Q35525': {'it': 'Casa Bianca', 'en': 'White House'}},
#   'from': 'mintaka'},
#  {'id': '1dc3ed72',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'What is the name of the first Mario game released on the Nintendo Switch?',
#   'target': 'Come si chiama il primo videogioco "Mario" uscito per Nintento Switch?',
#   'entities': {'Q19610114': {'it': 'Nintendo Switch',
#     'en': 'Nintendo Switch'}},
#   'from': 'mintaka'},
#  {'id': '80b8730a',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Who is the current president of South Africa?',
#   'target': "Chi è l'attuale presidente del Sud Africa?",
#   'entities': {'Q258': {'it': 'Sudafrica', 'en': 'South Africa'}},
#   'from': 'mintaka'},
#  {'id': '47bcf114',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Did Canada participate in World War II?',
#   'target': 'Il Canada ha preso parte alla Seconda Guerra Mondiale?',
#   'entities': {'Q362': {'it': 'seconda guerra mondiale',
#     'en': 'World War II'}},
#   'from': 'mintaka'},
#  {'id': 'bfc8c31b',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Is Rome more populated than Paris?',
#   'target': 'Roma ha più abitanti di Parigi?',
#   'entities': {'Q90': {'it': 'Parigi', 'en': 'Paris'},
#    'Q220': {'it': 'Roma', 'en': 'Rome'}},
#   'from': 'mintaka'},
#  {'id': 'f3430429',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Who was the first African American president of the United States?',
#   'target': 'Chi è stato il primo Presidente afro-americano degli Stati Uniti?',
#   'entities': {'Q49085': {'it': 'afroamericano', 'en': 'African Americans'}},
#   'from': 'mintaka'},
#  {'id': 'a3499bf7',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'What book series has more books, Chronicles of Narnia or Lord of the Rings?',
#   'target': 'Quale serie di libri ha più volumi, Le cronache di Narnia o Il Signore degli anelli?',
#   'entities': {'Q483412': {'it': 'Le cronache di Narnia',
#     'en': 'The Chronicles of Narnia'},
#    'Q15228': {'it': 'Il Signore degli Anelli', 'en': 'The Lord of the Rings'}},
#   'from': 'mintaka'},
#  {'id': 'e6d516e6',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Which book in the Wheel of Time series was released in 1991?',
#   'target': 'Quale libro della serie La Ruota del Tempo è stato pubblicato nel 1991?',
#   'entities': {'Q4470': {'it': 'La Ruota del Tempo',
#     'en': 'The Wheel of Time'}},
#   'from': 'mintaka'},
#  {'id': '2d19c0c3',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'What unit of currency is used in the country where the Eiffel Tower is?',
#   'target': 'Qual è la valuta usata nel paese della Torre Eiffel?',
#   'entities': {'Q243': {'it': 'torre Eiffel', 'en': 'Eiffel Tower'}},
#   'from': 'mintaka'},
#  {'id': '3b66ab40',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Did the United States fight against France to gain its independence in the Revolutionary War?',
#   'target': "Gli Stati Uniti hanno combattuto contro la Francia per rendersi indipendenti durante la Guerra d'Indipendenza?",
#   'entities': {'Q142': {'it': 'Francia', 'en': 'France'}},
#   'from': 'mintaka'},
#  {'id': '1670507e',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Which country suffered more military deaths during World War II, Germany or the Soviet Union?',
#   'target': 'Quale paese ha sofferto più morti in combattimento durante la Seconda Guerra Mondiale, Germania o Unione Sovietica?',
#   'entities': {'Q362': {'it': 'seconda guerra mondiale', 'en': 'World War II'},
#    'Q183': {'it': 'Germania', 'en': 'Germany'},
#    'Q15180': {'it': 'Unione Sovietica', 'en': 'Soviet Union'}},
#   'from': 'mintaka'},
#  {'id': 'e2a44231',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Was The Lord of the Rings published before 1960?',
#   'target': 'Il libro Il Signore degli anelli è stato pubblicato prima del 1960?',
#   'entities': {'Q15228': {'it': 'Il Signore degli Anelli',
#     'en': 'The Lord of the Rings'}},
#   'from': 'mintaka'},
#  {'id': '54b7c51f',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Who is usually the monster that steals Princess Peach in the Mario Bros. series?',
#   'target': 'Chi è solitamente il mostro che rapisce la Principessa Peach nella serie "Mario Bros."?',
#   'entities': {'Q507001': {'it': 'Principessa Peach', 'en': 'Princess Peach'}},
#   'from': 'mintaka'},
#  {'id': '1fc37e2f',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Which mayors of New York City since 1994 have not been Democrats?',
#   'target': 'Dal 1994 in poi, quali sindaci della città di New York non sono stati democratici?',
#   'entities': {'Q60': {'it': 'New York', 'en': 'New York City'}},
#   'from': 'mintaka'},
#  {'id': '6735ddd5',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Is Mount Kilimanjaro located in Africa?',
#   'target': 'Il Monte Kilimangiaro si trova in Africa?',
#   'entities': {'Q7296': {'it': 'Kilimangiaro', 'en': 'Mount Kilimanjaro'}},
#   'from': 'mintaka'},
#  {'id': 'b5a3eb32',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Who led the first Roman invasion of Britain?',
#   'target': 'Chi condusse la prima invasione romana della Gran Bretagna?',
#   'entities': {'Q23666': {'it': 'Gran Bretagna', 'en': 'Great Britain'}},
#   'from': 'mintaka'},
#  {'id': 'c782d153',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Does Germany have a prime minister?',
#   'target': 'La Germania ha un primo ministro?',
#   'entities': {'Q14212': {'it': 'primo ministro', 'en': 'prime minister'},
#    'Q183': {'it': 'Germania', 'en': 'Germany'}},
#   'from': 'mintaka'},
#  {'id': '179480ad',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Which was longer, the American Civil War or the Revolutionary War?',
#   'target': "È durata di più la Guerra Civile Americana o la Guerra d'Indipendenza Americana?",
#   'entities': {'Q40949': {'it': "guerra d'indipendenza americana",
#     'en': 'American Revolutionary War'}},
#   'from': 'mintaka'},
#  {'id': '9e7ac30f',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Was Caligula assassinated?',
#   'target': 'Caligola è stato assassinato?',
#   'entities': {'Q1409': {'it': 'Caligola', 'en': 'Caligula'}},
#   'from': 'mintaka'},
#  {'id': '789cf0fa',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Which Lord of the Rings movies did not feature Gandalf the Grey?',
#   'target': 'In quale film de Il Signore degli Anelli non appare Gandalf?',
#   'entities': {'Q190214': {'it': 'Il Signore degli Anelli',
#     'en': 'The Lord of the Rings trilogy'}},
#   'from': 'mintaka'},
#  {'id': '0bc9b304',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Who was the first ruler of Greece?',
#   'target': 'Chi è stato il primo governatore della Grecia?',
#   'entities': {'Q41': {'it': 'Grecia', 'en': 'Greece'}},
#   'from': 'mintaka'},
#  {'id': 'b89f4687',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Which country is bigger: Russia or Germany?',
#   'target': 'Quale Paese è più grande: Russia o Germania?',
#   'entities': {'Q183': {'it': 'Germania', 'en': 'Germany'}},
#   'from': 'mintaka'},
#  {'id': '95b987e3',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Which former member of NSYNC is not straight?',
#   'target': 'Quale precedente membro degli N Sync non è etero?',
#   'entities': {'Q154454': {'it': 'NSYNC', 'en': 'NSYNC'}},
#   'from': 'mintaka'},
#  {'id': 'bc4e469b',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Which movie had a bigger budget, Lord of The Rings or Ghostbusters?',
#   'target': 'Che film ha avuto un budget più alto, Il Signore degli Anelli o Ghostbusters?',
#   'entities': {'Q190214': {'it': 'Il Signore degli Anelli',
#     'en': 'The Lord of the Rings trilogy'}},
#   'from': 'mintaka'},
#  {'id': '9a82fbf0',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Which Lord of the Rings book did not have less than two movies per title?',
#   'target': 'Quale libro de "Il signore degli anelli" non ha avuto meno di due film per titolo?',
#   'entities': {'Q15228': {'it': 'Il Signore degli Anelli',
#     'en': 'The Lord of the Rings'}},
#   'from': 'mintaka'},
#  {'id': 'df709bc9',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Is the Missouri River the longest river in the United States?',
#   'target': 'Il fiume Missouri è il più lungo degli Stati Uniti?',
#   'entities': {'Q5419': {'it': 'Missouri', 'en': 'Missouri River'}},
#   'from': 'mintaka'},
#  {'id': 'a547d5d7',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'What is the only country that borders the United Kingdom and is an independent country?',
#   'target': "Qual è l'unica nazione che confina con il Regno Unito ed è una nazione indipendente?",
#   'entities': {'Q145': {'it': 'Regno Unito', 'en': 'United Kingdom'}},
#   'from': 'mintaka'},
#  {'id': '05741287',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Which Fire type Pokemon could not be caught in the wild in Pokemon Yellow?',
#   'target': 'Quale Pokemon di tipo fuoco non poteva essere catturato nel bosco in Pokemon giallo?',
#   'entities': {'Q1988120': {'it': 'Pokémon Giallo', 'en': 'Pokémon Yellow'}},
#   'from': 'mintaka'},
#  {'id': '51a1a924',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Who was the first president of the United States of America?',
#   'target': "Chi è stato il primo presidente degli Stati Uniti d'America?",
#   'entities': {'Q30': {'it': "Stati Uniti d'America",
#     'en': 'United States of America'}},
#   'from': 'mintaka'},
#  {'id': '5396a5d4',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Is Harry Potter and the Goblet of Fire the first book in the series?',
#   'target': 'Harry Potter e il calice di fuoco è il primo libro della serie?',
#   'entities': {'Q46751': {'it': 'Harry Potter e il calice di fuoco',
#     'en': 'Harry Potter and the Goblet of Fire'}},
#   'from': 'mintaka'},
#  {'id': '0bbbdb96',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Which South American country that is the closest to Antarctica is also the longest country in the continent?',
#   'target': "Quale Paese dell'America del Sud è il più vicino all'Antartide ed è anche il più lungo del continente?",
#   'entities': {'Q51': {'it': 'Antartide', 'en': 'Antarctica'}},
#   'from': 'mintaka'},
#  {'id': '96377948',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Who was the second president of the United States?',
#   'target': "Chi fu il secondo presidente degli Stati Uniti d'America?",
#   'entities': {'Q30': {'it': "Stati Uniti d'America",
#     'en': 'United States of America'}},
#   'from': 'mintaka'},
#  {'id': 'c5d31018',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'What is the name of the fourth zone in the third Sonic the Hedgehog game?',
#   'target': 'Come si chiama la quarta zona nel terzo gioco della serie Sonic?',
#   'entities': {'Q1046812': {'it': 'Sonic', 'en': 'Sonic the Hedgehog'}},
#   'from': 'mintaka'},
#  {'id': 'c3b7af46',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': "Who was West Virginia's longest serving senator?",
#   'target': 'Chi è stato il senatore più longevo della Virginia Occidentale?',
#   'entities': {'Q1371': {'it': 'Virginia Occidentale', 'en': 'West Virginia'}},
#   'from': 'mintaka'},
#  {'id': 'd10371c5',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Which Lord of the Rings book does not feature the Shire as a setting?',
#   'target': 'In quale libro de "Il signore degli anelli", tra le ambientazioni non c\'é Shire?',
#   'entities': {'Q15228': {'it': 'Il Signore degli Anelli',
#     'en': 'The Lord of the Rings'}},
#   'from': 'mintaka'},
#  {'id': 'f800746d',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'How many Lord of the Rings movies was Gandalf the White in?',
#   'target': 'In quanti film de Il Signore degli Anelli compare Gandalf?',
#   'entities': {'Q190214': {'it': 'Il Signore degli Anelli',
#     'en': 'The Lord of the Rings trilogy'}},
#   'from': 'mintaka'},
#  {'id': '7b8bc91c',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Did George R.R. Martin finish ASOIAF as of 2021?',
#   'target': 'George R.R. Martin ha terminato Le Cronache del ghiaccio e del fuoco nel 2021?',
#   'entities': {'Q45875': {'it': 'Cronache del ghiaccio e del fuoco',
#     'en': 'A Song of Ice and Fire'}},
#   'from': 'mintaka'},
#  {'id': 'dab5d428',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'In what year did the United States enter WW II?',
#   'target': 'In quale anno gli Stati Uniti entrarono nella seconda guerra mondiale?',
#   'entities': {'Q362': {'it': 'seconda guerra mondiale',
#     'en': 'World War II'}},
#   'from': 'mintaka'},
#  {'id': '7aa25fe3',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'What man was a dictator who was responsible for a genocide that killed millions of people and was the leader of an Axis Power during World War II?',
#   'target': "Quale uomo fu il dittatore responsabile di un genocidio che uccise milioni di persone e leader dell'Asse durante la Seconda Guerra Mondiale?",
#   'entities': {'Q362': {'it': 'seconda guerra mondiale',
#     'en': 'World War II'}},
#   'from': 'mintaka'},
#  {'id': '2ecf2719',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Which book in the A Song of Ice And Fire series was released in 2005?',
#   'target': 'Quale libro de "Cronache del ghiaccio e del fuoco" è stato pubblicato nel 2005?',
#   'entities': {'Q45875': {'it': 'Cronache del ghiaccio e del fuoco',
#     'en': 'A Song of Ice and Fire'}},
#   'from': 'mintaka'},
#  {'id': 'd29e2b61',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Which Chronicles of Narnia book was not written before 1955?',
#   'target': 'Quale libro delle Cronache di Narnia non è stato scritto prima del 1995?',
#   'entities': {'Q483412': {'it': 'Le cronache di Narnia',
#     'en': 'The Chronicles of Narnia'}},
#   'from': 'mintaka'},
#  {'id': 'd0c5ccfa',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Which movie took place at a hotel and starred Jack Nicholson?',
#   'target': 'Quale film con Jack Nicholoson è ambientato in un hotel?',
#   'entities': {'Q39792': {'it': 'Jack Nicholson', 'en': 'Jack Nicholson'}},
#   'from': 'mintaka'},
#  {'id': 'f07e3564',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'What landmark in Rome was said to have seated more than 15,000 fans all vying for blood?',
#   'target': 'Quale punto di riferimento a Roma è stato raccontato di aver accolto a sedere più di 50,000 fans tutti in lizza per il sangue?',
#   'entities': {'Q220': {'it': 'Roma', 'en': 'Rome'}},
#   'from': 'mintaka'},
#  {'id': '475661d9',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'What is the size of London?',
#   'target': 'Quanto è grande Londra?',
#   'entities': {'Q84': {'it': 'Londra', 'en': 'London'}},
#   'from': 'mintaka'},
#  {'id': '9a91d95d',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Which Chinese dynasty is known as the Golden Age for Poetry?',
#   'target': "Quale dinastia cinese è conosciuta come l'età d'oro della poesia?",
#   'entities': {'Q148': {'it': 'Cina', 'en': "People's Republic of China"}},
#   'from': 'mintaka'},
#  {'id': '6328c5af',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': "What year was Beyoncé's first solo album released?",
#   'target': 'In quale anno è stato lanciato il primo album solista di Beyonce?',
#   'entities': {'Q36153': {'it': 'Beyoncé', 'en': 'Beyoncé'}},
#   'from': 'mintaka'},
#  {'id': '9244090d',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Who was older when he became the president of the United States of America, Bill Clinton or Barack Obama?',
#   'target': "Chi era più vecchio quando è diventato il Presidente degli Stati Uniti d'America, Bill Clinton o Barack Obama?",
#   'entities': {'Q30': {'it': "Stati Uniti d'America",
#     'en': 'United States of America'}},
#   'from': 'mintaka'},
#  {'id': '1552abe2',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Who wrote the Grapes of Wrath?',
#   'target': 'Chi ha scritto Furore?',
#   'entities': {'Q215983': {'it': 'Furore', 'en': 'The Grapes of Wrath'}},
#   'from': 'mintaka'},
#  {'id': '51cadbae',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'What is the capital of the country with the fifth largest land area in Europe?',
#   'target': "Qual è la capitale del paese con la quinta superficie terrestre più estesa d'Europa?",
#   'entities': {'Q46': {'it': 'Europa', 'en': 'Europe'}},
#   'from': 'mintaka'},
#  {'id': '2d7d56f9',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Which Mass Effect game does not include Commander Shepard as the main character?',
#   'target': 'Quale gioco della serie Mass Effect non include il Comandante Shepard come personaggio principale?',
#   'entities': {'Q3683919': {'it': 'Comandante Shepard',
#     'en': 'Commander Shepard'}},
#   'from': 'mintaka'},
#  {'id': '9896653c',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Did the United Kingdom fight a war against a South American country in the 1990s?',
#   'target': 'Il Regno Unito ha combattuto una guerra contro un nazione Sud Americana negli anni 90?',
#   'entities': {'Q145': {'it': 'Regno Unito', 'en': 'United Kingdom'}},
#   'from': 'mintaka'},
#  {'id': '5f7ee9d3',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Which nation lost World War II, Germany or the United States?',
#   'target': 'Quale nazione ha perso la Seconda Guerra Mondiale, Germania o Stati Uniti?',
#   'entities': {'Q183': {'it': 'Germania', 'en': 'Germany'},
#    'Q362': {'it': 'seconda guerra mondiale', 'en': 'World War II'}},
#   'from': 'mintaka'},
#  {'id': '4d1fccdd',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Which series has more books, The Chronicles of Narnia or Twilight?',
#   'target': 'Quale saga è composta da più libri, Le cronache di Narnia o Twilight?',
#   'entities': {'Q483412': {'it': 'Le cronache di Narnia',
#     'en': 'The Chronicles of Narnia'}},
#   'from': 'mintaka'},
#  {'id': 'd7012a77',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'How many The Chronicles of Narnia movies are there?',
#   'target': 'Quanti film Le cronache di Narnia ci sono?',
#   'entities': {'Q483412': {'it': 'Le cronache di Narnia',
#     'en': 'The Chronicles of Narnia'}},
#   'from': 'mintaka'},
#  {'id': '4ff2bfb7',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Which of the Lord of the Rings books is the shortest?',
#   'target': 'Qual è il libro più breve de Il Signore degli Anelli?',
#   'entities': {'Q15228': {'it': 'Il Signore degli Anelli',
#     'en': 'The Lord of the Rings'}},
#   'from': 'mintaka'},
#  {'id': 'a97ae9d4',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Who built the pyramids in Mexico?',
#   'target': 'Chi ha costruito le piramidi in Messico?',
#   'entities': {'Q96': {'it': 'Messico', 'en': 'Mexico'}},
#   'from': 'mintaka'},
#  {'id': 'fb15deb3',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Which Blackpink members were not from South Korea?',
#   'target': 'Quali componenti delle Blackpink non vengono dalla Corea del Sud?',
#   'entities': {'Q884': {'it': 'Corea del Sud', 'en': 'South Korea'}},
#   'from': 'mintaka'},
#  {'id': '9c568088',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'What series has more books, The Chronicles of Narnia or Diary of a Wimpy Kid?',
#   'target': 'Quale serie ha più libri, Le cronache di Narnia o Diario di una schiappa?',
#   'entities': {'Q1339580': {'it': 'Diario di una schiappa',
#     'en': 'Diary of a Wimpy Kid'},
#    'Q483412': {'it': 'Le cronache di Narnia',
#     'en': 'The Chronicles of Narnia'}},
#   'from': 'mintaka'},
#  {'id': '7398bf1f',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'In how many games has Princess Peach been the only playable character?',
#   'target': "In quanti giochi la Principessa Peach è stata l'unico personaggio giocabile?",
#   'entities': {'Q507001': {'it': 'Principessa Peach', 'en': 'Princess Peach'}},
#   'from': 'mintaka'},
#  {'id': '3adafb4c',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Which contiguous state that borders the Pacific Ocean does not have a northern state on its border?',
#   'target': "Quale stato bagnato dall'Oceano Pacifico non confina con uno stato settentrionale?",
#   'entities': {'Q98': {'it': 'Oceano Pacifico', 'en': 'Pacific Ocean'}},
#   'from': 'mintaka'},
#  {'id': '77b12cdf',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Who was the sixth emperor of Rome?',
#   'target': 'Chi era il sesto imperatore di Roma?',
#   'entities': {'Q220': {'it': 'Roma', 'en': 'Rome'}},
#   'from': 'mintaka'},
#  {'id': 'e983e565',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'How many states does the Mississippi River run though or along the border of?',
#   'target': 'Il fiume Mississipi si estende tra o comunque tocca quanti stati?',
#   'entities': {'Q1497': {'it': 'Mississippi', 'en': 'Mississippi River'}},
#   'from': 'mintaka'},
#  {'id': 'cb66e96b',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Did England and France ever have a war with each other?',
#   'target': "L'Inghilterra e la Francia sono mai state in guerra tra loro?",
#   'entities': {'Q142': {'it': 'Francia', 'en': 'France'},
#    'Q21': {'it': 'Inghilterra', 'en': 'England'}},
#   'from': 'mintaka'},
# ...
#   'source': 'What is the first album by Irish rock band U2?',
#   'target': 'Qual è il primo album della band rock irlandese U2?',
#   'entities': {'Q27': {'it': 'Irlanda', 'en': 'Ireland'}},
#   'from': 'mintaka'},
#  {'id': '5033b17a',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': "Who was Alexander the Great's first wife?",
#   'target': 'Chi fu la prima moglie di Alessandro Magno?',
#   'entities': {'Q8409': {'it': 'Alessandro Magno',
#     'en': 'Alexander the Great'}},
#   'from': 'mintaka'},
#  {'id': '9a4e5526',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Which former Dallas Cowboy quarterback used to play football at UCLA in college?',
#   'target': "Quale ex-quarterback dei Dallas Cowboy giocava a football all'Università della California, quando era al college?",
#   'entities': {'Q174710': {'it': 'Università della California',
#     'en': 'University of California, Los Angeles'}},
#   'from': 'mintaka'},
#  {'id': 'a7bb5df3',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'What Pokémon game has Charizard as a starter Pokémon?',
#   'target': 'Quale gioco dei Pokemon ha Charizard come pokemon iniziale?',
#   'entities': {'Q864': {'it': 'Pokémon', 'en': 'Pokémon'}},
#   'from': 'mintaka'},
#  {'id': '28d6ebbc',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Is Brazil larger than Argentina?',
#   'target': "Il Brasile è più grande dell'Argentina?",
#   'entities': {'Q155': {'it': 'Brasile', 'en': 'Brazil'}},
#   'from': 'mintaka'},
#  {'id': 'ab8a6a63',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'The first African American child to attend a white school did so in what year?',
#   'target': 'In che anno il primo bambino afroamericano frequentò una scuola per bianchi?',
#   'entities': {'Q49085': {'it': 'afroamericano', 'en': 'African Americans'}},
#   'from': 'mintaka'},
#  {'id': '0d3e8130',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Who was the 19th president of the United States of America?',
#   'target': "Chi è stato il 19° presidente degli Stati Uniti d'America?",
#   'entities': {'Q30': {'it': "Stati Uniti d'America",
#     'en': 'United States of America'}},
#   'from': 'mintaka'},
#  {'id': '2f7ea70b',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Which Doja Cat record was nominated for a Record of the Year Grammy but did not win?',
#   'target': "Quale brano di Doja Cat è stato candidato al Grammy Award alla registrazione dell'anno senza vincere?",
#   'entities': {'Q843219': {'it': "Grammy Award alla registrazione dell'anno",
#     'en': 'Grammy Award for Record of the Year'}},
#   'from': 'mintaka'},
#  {'id': '5cbd4e80',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Is Wyoming the least densely populated state in the United States of America?',
#   'target': "Wyoming è lo stato meno densamente popolato degli Stati Uniti d'America?",
#   'entities': {'Q30': {'it': "Stati Uniti d'America",
#     'en': 'United States of America'}},
#   'from': 'mintaka'},
#  {'id': 'eb1f25ab',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Who was the longest surviving child of King Louis XVI of France?',
#   'target': 'Chi è stato il figlio di re Luigi XVI di Francia che è vissuto più a lungo?',
#   'entities': {'Q7732': {'it': 'Luigi XVI di Francia',
#     'en': 'Louis XVI of France'}},
#   'from': 'mintaka'},
#  {'id': 'e0b30737',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Who has been the oldest vice president to step foot in the White House?',
#   'target': 'Chi è stato il vicepresidente più anziano ad entrare alla Casa Bianca?',
#   'entities': {'Q35525': {'it': 'Casa Bianca', 'en': 'White House'}},
#   'from': 'mintaka'},
#  {'id': '05128a46',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Which capital city is located on the southern shores of the Firth of Forth in the United Kingdom?',
#   'target': 'Qual è la capitale che si trova sulle coste meridionali del Firth of Forth nel Regno Unito?',
#   'entities': {'Q145': {'it': 'Regno Unito', 'en': 'United Kingdom'}},
#   'from': 'mintaka'},
#  {'id': 'dd27fa7e',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': "Was Sonic's primary nemesis Dr. Ivo Robotnik originally known as Dr. Eggman in Japan?",
#   'target': 'Il nemico principale di Sonic Dr. Ivo Robotnik era originariamente conosciuto come Dr. Eggman in Giappone?',
#   'entities': {'Q1046812': {'it': 'Sonic', 'en': 'Sonic the Hedgehog'},
#    'Q17': {'it': 'Giappone', 'en': 'Japan'}},
#   'from': 'mintaka'},
#  {'id': '830c55ff',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': "Which Canadian province does not contain more than 0.1% of the country's population?",
#   'target': "Quale provincia canadese non contiene più dell'1% della popolazione nazionale?",
#   'entities': {'Q16': {'it': 'Canada', 'en': 'Canada'}},
#   'from': 'mintaka'},
#  {'id': 'a88d72fd',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Does Italy share a border with France?',
#   'target': "L'Italia confina con la Francia?",
#   'entities': {'Q142': {'it': 'Francia', 'en': 'France'},
#    'Q38': {'it': 'Italia', 'en': 'Italy'}},
#   'from': 'mintaka'},
#  {'id': '4540a215',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Who is the president of Italy?',
#   'target': 'Chi è il presidente italiano?',
#   'entities': {'Q38': {'it': 'Italia', 'en': 'Italy'}},
#   'from': 'mintaka'},
#  {'id': '529a08c0',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Is the Yellow River the longest river in Asia?',
#   'target': "Il Fiume Giallo è il più lungo dell'Asia?",
#   'entities': {'Q7355': {'it': 'Fiume Giallo', 'en': 'Yellow River'}},
#   'from': 'mintaka'},
#  {'id': '1d7c9a02',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'What is the population of the state where Mount Rushmore is?',
#   'target': 'Qual è la popolazione dello stato in cui si trova il Monte Rushmore?',
#   'entities': {'Q83497': {'it': 'Monte Rushmore', 'en': 'Mount Rushmore'}},
#   'from': 'mintaka'},
#  {'id': '4e989288',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'How many movies were made from the Lord of the Rings book series?',
#   'target': 'Quanti film sono stati tratti dalla serie di libri Il Signore degli Anelli?',
#   'entities': {'Q15228': {'it': 'Il Signore degli Anelli',
#     'en': 'The Lord of the Rings'}},
#   'from': 'mintaka'},
#  {'id': '9afa8edd',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Who was in charge of Great Britain during World War 2?',
#   'target': 'Chi era in carica in Gran Bretagna durante la Seconda Guerra Mondiale?',
#   'entities': {'Q362': {'it': 'seconda guerra mondiale', 'en': 'World War II'},
#    'Q23666': {'it': 'Gran Bretagna', 'en': 'Great Britain'}},
#   'from': 'mintaka'},
#  {'id': '14d27e5e',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'How many U.S. states share a border with Mexico?',
#   'target': 'Quanti stati USA confinano con il Messico?',
#   'entities': {'Q96': {'it': 'Messico', 'en': 'Mexico'}},
#   'from': 'mintaka'},
#  {'id': 'e5aa3547',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Which king of England had the most marriages?',
#   'target': 'Quale Re di Inghilterra ha avuto più matrimoni?',
#   'entities': {'Q21': {'it': 'Inghilterra', 'en': 'England'}},
#   'from': 'mintaka'},
#  {'id': '540d0d47',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'What role did Heath Ledger play in the 2008 movie, The Dark Knight?',
#   'target': 'Quale ruolo ha impersonato Heath Ledger nel film "Il cavaliere oscuro" del 2008?',
#   'entities': {'Q163872': {'it': 'Il cavaliere oscuro',
#     'en': 'The Dark Knight'}},
#   'from': 'mintaka'},
#  {'id': '7897a1b6',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': "When was Beyoncé's last album released?",
#   'target': "Quando è uscito l'ultimo album di Beyonce?",
#   'entities': {'Q36153': {'it': 'Beyoncé', 'en': 'Beyoncé'}},
#   'from': 'mintaka'},
#  {'id': '1be2a0a9',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Did Marcel Proust write In Search of Lost Time?',
#   'target': 'Alla ricerca del tempo perduto è stato scritto da Marcel Proust?',
#   'entities': {'Q464928': {'it': 'Alla ricerca del tempo perduto',
#     'en': 'In Search of Lost Time'}},
#   'from': 'mintaka'},
#  {'id': 'f8bd7ead',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Who was the first president of Mexico?',
#   'target': 'Chi è stato il primo presidente del Messico?',
#   'entities': {'Q96': {'it': 'Messico', 'en': 'Mexico'}},
#   'from': 'mintaka'},
#  {'id': 'fe02d7f4',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Is there an emperor of Japan?',
#   'target': 'Esiste un Imperatore del Giappone?',
#   'entities': {'Q17': {'it': 'Giappone', 'en': 'Japan'},
#    'Q39018': {'it': 'imperatore', 'en': 'emperor'}},
#   'from': 'mintaka'},
#  {'id': '68896e4d',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'When did World War Two start?',
#   'target': 'Quando è iniziata la seconda guerra mondiale?',
#   'entities': {'Q362': {'it': 'seconda guerra mondiale',
#     'en': 'World War II'}},
#   'from': 'mintaka'},
#  {'id': '5b4c75ff',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Who ruled Rome for the longest period of time?',
#   'target': 'Chi governò Roma per il più lungo periodo di tempo?',
#   'entities': {'Q220': {'it': 'Roma', 'en': 'Rome'}},
#   'from': 'mintaka'},
#  {'id': 'a322bb20',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Who was the first African American man to become president of the US?',
#   'target': 'Chi è stato il primo afroamericano che è diventato presidente degli Stati Uniti?',
#   'entities': {'Q49085': {'it': 'afroamericano', 'en': 'African Americans'}},
#   'from': 'mintaka'},
#  {'id': '16c4703e',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Is the Eiffel Tower in Spain?',
#   'target': 'La Torre Eiffel si trova in Spagna?',
#   'entities': {'Q29': {'it': 'Spagna', 'en': 'Spain'},
#    'Q243': {'it': 'torre Eiffel', 'en': 'Eiffel Tower'}},
#   'from': 'mintaka'},
#  {'id': '6c58becc',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'How many years has Angela Merkel been a chancellor of Germany?',
#   'target': 'Per quanti anni Angela Merkel è stata cancelliera della Germania?',
#   'entities': {'Q183': {'it': 'Germania', 'en': 'Germany'}},
#   'from': 'mintaka'},
#  {'id': 'd121b432',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Which actress starred in The Wizard of Oz and is the daughter of Liza Minnelli?',
#   'target': 'Quale attrice ha recitato nel Mago di Oz la cui figlia è Liza Minnelli?',
#   'entities': {'Q193695': {'it': 'Il mago di Oz', 'en': 'The Wizard of Oz'}},
#   'from': 'mintaka'},
#  {'id': 'f2107aca',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Who lived longer, Alexander the Great or Julius Ceasar?',
#   'target': 'Chi ha vissuto più a lungo, Alessandro Magno o Giulio Cesare?',
#   'entities': {'Q8409': {'it': 'Alessandro Magno',
#     'en': 'Alexander the Great'}},
#   'from': 'mintaka'},
#  {'id': '79ea6d48',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Which series has more books, Chronicles of Narnia or the Hardy Boys?',
#   'target': 'Quale serie ha più libri: "Le cronache di Narnia" o "Hardy Boys"?',
#   'entities': {'Q483412': {'it': 'Le cronache di Narnia',
#     'en': 'The Chronicles of Narnia'}},
#   'from': 'mintaka'},
#  {'id': '457e360f',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'What is the longest underwater tunnel in Denmark?',
#   'target': 'Qual è il tunnel sottomarino più lungo della Danimarca?',
#   'entities': {'Q35': {'it': 'Danimarca', 'en': 'Denmark'}},
#   'from': 'mintaka'},
#  {'id': 'e3a4d2cd',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Is the Eiffel Tower located in Italy?',
#   'target': 'La Torre Eiffel si trova in Italia?',
#   'entities': {'Q38': {'it': 'Italia', 'en': 'Italy'},
#    'Q243': {'it': 'torre Eiffel', 'en': 'Eiffel Tower'}},
#   'from': 'mintaka'},
#  {'id': '1c6c85f3',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Who was the 3rd president of Brazil?',
#   'target': 'Chi è stato il terzo presidente del Brasile?',
#   'entities': {'Q155': {'it': 'Brasile', 'en': 'Brazil'}},
#   'from': 'mintaka'},
#  {'id': 'a7ef499a',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Did Jay-Z ever make a song with Tupac?',
#   'target': 'jay z ha mai fatto una canzone con tupac?',
#   'entities': {'Q62766': {'it': 'Jay-Z', 'en': 'Jay-Z'}},
#   'from': 'mintaka'},
#  {'id': '5284cebc',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Is the Lord of the Rings series or the Divergent series older?',
#   'target': 'È uscita prima la saga de Il Signore degli Anelli o Divergent?',
#   'entities': {'Q15228': {'it': 'Il Signore degli Anelli',
#     'en': 'The Lord of the Rings'}},
#   'from': 'mintaka'},
#  {'id': 'c5d77ffe',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Is Texas a bigger state than North Carolina?',
#   'target': 'Il Texas è più grande della Carolina del Nord?',
#   'entities': {'Q1454': {'it': 'Carolina del Nord', 'en': 'North Carolina'}},
#   'from': 'mintaka'},
#  {'id': 'a192dac7',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Who is the prime minister of the United Kingdom?',
#   'target': 'Chi è il Primo Ministro del Regno Unito?',
#   'entities': {'Q14212': {'it': 'primo ministro', 'en': 'prime minister'},
#    'Q145': {'it': 'Regno Unito', 'en': 'United Kingdom'}},
#   'from': 'mintaka'},
#  {'id': 'b49155f1',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Who was the 1st emperor of Japan?',
#   'target': 'Chi è stato il primo Imperatore del Giappone?',
#   'entities': {'Q17': {'it': 'Giappone', 'en': 'Japan'}},
#   'from': 'mintaka'},
#  {'id': '2600566f',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': "What is Jay-Z's real name?",
#   'target': 'Qual è il vero nome di Jay Z?',
#   'entities': {'Q62766': {'it': 'Jay-Z', 'en': 'Jay-Z'}},
#   'from': 'mintaka'},
#  {'id': '7398f77c',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'What book did J. K. Rowling write at the age of six?',
#   'target': "Che libro fu scritto da J.K. Rowling all'età di sei anni?",
#   'entities': {'Q34660': {'it': 'J. K. Rowling', 'en': 'J. K. Rowling'}},
#   'from': 'mintaka'},
#  {'id': 'a35e080e',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Did more Americans die in World War II or the American Civil War?',
#   'target': 'Sono morti più americani nella Seconda Guerra Mondiale o nella Guerra civile americana?',
#   'entities': {'Q362': {'it': 'seconda guerra mondiale',
#     'en': 'World War II'}},
#   'from': 'mintaka'},
#  {'id': '039fab2a',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'How many different series of Goosebumps books did R.L. Stine release between 1992 and 2000?',
#   'target': 'Quante serie di "Piccoli brividi" ha pubblicato R.L. Stine tra il 1992 e il 2000?',
#   'entities': {'Q3260367': {'it': 'Piccoli brividi', 'en': 'Goosebumps'}},
#   'from': 'mintaka'},
#  {'id': '87f36c14',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Is Paris the capital of France?',
#   'target': 'Parigi è la capitale della Francia?',
#   'entities': {'Q90': {'it': 'Parigi', 'en': 'Paris'},
#    'Q142': {'it': 'Francia', 'en': 'France'}},
#   'from': 'mintaka'},
#  {'id': '960ed5d6',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Which Lord of the Rings character is a relative to Frodo and originally finds the ring?',
#   'target': 'Quale personaggio de "Il signore degli anelli" è parente di Frodo e trova per primo l\'anello?',
#   'entities': {'Q15228': {'it': 'Il Signore degli Anelli',
#     'en': 'The Lord of the Rings'}},
#   'from': 'mintaka'},
#  {'id': '6fc1dd16',
#   'source_locale': 'en',
#   'target_locale': 'it',
#   'source': 'Who ruled Egypt after Cleopatra, but did not live to 40?',
#   'target': "Chi governò l'Egitto dopo Cleopatra ma non è vissuto fino ai 40 anni?",
#   'entities': {'Q79': {'it': 'Egitto', 'en': 'Egypt'}},
#   'from': 'mintaka'}]

# %%
print("Loading SpanMarker model...")
spanmarker_model = SpanMarkerModel.from_pretrained("tomaarsen/span-marker-mbert-base-multinerd")
ensure_pad_token(spanmarker_model)
# Out:
# Loading SpanMarker model...
# The new embeddings will be initialized from a multivariate normal distribution that has old embeddings' mean and covariance. As described in this article: https://nlp.stanford.edu/~johnhew/vocab-expansion.html. To disable this, use `mean_resizing=False`
# Setting pad_token manually...

# %%
print("Loading M2M100 translation model...")
m2m_model = M2M100ForConditionalGeneration.from_pretrained("facebook/m2m100_418M")
m2m_tokenizer = M2M100Tokenizer.from_pretrained("facebook/m2m100_418M")
# Out:
# Loading M2M100 translation model...

# %%
translated_sentences = []

for idx, entry in enumerate(italian_data):  # Process only the first 10 entries

    # Get source text (English) and target text (Italian)
    eng_text = entry['source']
    itl_text = entry['target']

    # Mask entities in the English text
    masked_eng_text, mapping = mask_entities_with_spanmarker(eng_text, spanmarker_model)
    print(f"Masked English Text: {masked_eng_text}")
    print(f"Entity Mapping: {json.dumps(mapping, indent=4)}")

    # Filter entities by confidence score
    filtered_mapping = {
        key: value for key, value in mapping.items() if value["confidence"] > 0.8
    }
    print(f"Filtered Mapping (Confidence > 0.8): {json.dumps(filtered_mapping, indent=4)}")

    # Translate non-entity parts of the text
    m2m_tokenizer.src_lang = "en"
    tgt_lang = "it"
    translated_text_with_placeholders = translate_with_placeholders_m2m(
        masked_eng_text, filtered_mapping, src_lang="en", tgt_lang="it"
    )
    print(f"Translated Text with Placeholders: {translated_text_with_placeholders}")

    # Reintegrate entities into the translated text
    final_translation = reintegrate_entities(
        translated_text_with_placeholders, filtered_mapping, src_lang="en", tgt_lang="it"
    )
    print(f"Final Translation: {final_translation}")

    # Append final translation to the results
    translated_sentences.append({
        "id": entry["id"],
        "source": eng_text,
        "target": itl_text,
        "masked_source": masked_eng_text,
        "translation": final_translation,
        "filtered_mapping": filtered_mapping
    })

# Save the results
results_path = "data/translated_italian_test.json"
with open(results_path, "w") as results_file:
    json.dump(translated_sentences, results_file, indent=4)

print(f"Translation results for test set saved to {results_path}")
# Out:
# Masked English Text: How old is the author of the [ENTITY_MEDIA_1] series?
# Entity Mapping: {
#     "[ENTITY_MEDIA_1]": {
#         "original_text": "Goosebumps",
#         "type": "MEDIA",
#         "confidence": 0.9521344304084778,
#         "start": 29,
#         "end": 39
#     }
# }
# Filtered Mapping (Confidence > 0.8): {
#     "[ENTITY_MEDIA_1]": {
#         "original_text": "Goosebumps",
#         "type": "MEDIA",
#         "confidence": 0.9521344304084778,
#         "start": 29,
#         "end": 39
#     }
# }
# Translated Text with Placeholders: Quanto è vecchio l'autore della serie [ENTITY_MEDIA_1]?
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
