# %%
from transformers import M2M100ForConditionalGeneration, M2M100Tokenizer
import json

def simple_translate(texts, src_lang, tgt_lang, model, tokenizer):
    """
    Translates a list of texts using M2M100 without any entity masking.

    Args:
        texts (list of str): List of texts to translate.
        src_lang (str): Source language code.
        tgt_lang (str): Target language code.
        model (M2M100ForConditionalGeneration): Pretrained M2M100 model.
        tokenizer (M2M100Tokenizer): Tokenizer for M2M100.

    Returns:
        list of str: Translated texts.
    """
    tokenizer.src_lang = src_lang
    translations = []

    for idx, text in enumerate(texts):
        print(f"Translating text {idx + 1}/{len(texts)}: {text}")
        encoded_text = tokenizer(text, return_tensors="pt")
        generated_tokens = model.generate(
            **encoded_text,
            forced_bos_token_id=tokenizer.get_lang_id(tgt_lang),
            max_length=128,
            early_stopping=True
        )
        translated_text = tokenizer.batch_decode(generated_tokens, skip_special_tokens=True)[0]
        print(f"Translated text {idx + 1}: {translated_text}")
        translations.append(translated_text)

    return translations

# Load the M2M100 model and tokenizer
# model_name = "facebook/m2m100_418M"
m2m_model = M2M100ForConditionalGeneration.from_pretrained("facebook/m2m100_418M")
m2m_tokenizer = M2M100Tokenizer.from_pretrained("facebook/m2m100_418M")

# Example input data (can be replaced with actual data)
data_path = "data/italian_test.json"

# Load the data
with open(data_path, "r") as file:
    italian_data = json.load(file)

# Extract source texts (English)
texts_to_translate = [entry["source"] for entry in italian_data]

# Define source and target languages
src_language = "en"
tgt_language = "it"

# Perform translation
translated_texts = simple_translate(texts_to_translate, src_language, tgt_language, m2m_model, m2m_tokenizer)

# Save the translated results
results = []
for idx, entry in enumerate(italian_data):
    print(f"Processing result {idx + 1}/{len(italian_data)}")
    results.append({
        "id": entry["id"],
        "source": entry["source"],
        "target": entry["target"],
        "translated": translated_texts[idx]
    })

output_path = "data/meta_translation_italian.json"
with open(output_path, "w") as output_file:
    json.dump(results, output_file, indent=4)

print(f"Translated results saved to {output_path}")
# Out:
# Translating text 1/198: How old is the author of the Goosebumps series?
# Translated text 1: Quanto è vecchio l'autore della serie Goosebumps?
# Translating text 2/198: Which of the three largest islands in the Mediterranean Sea is not part of Italy?
# Translated text 2: Quale delle tre isole più grandi del Mediterraneo non fa parte dell'Italia?
# Translating text 3/198: What house did Severus Snape belong to?
# Translated text 3: A quale casa appartiene Severus Snape?
# Translating text 4/198: Who is the current president of Japan?
# Translated text 4: Chi è l’attuale presidente del Giappone?
# Translating text 5/198: What date was the actress born who played Scarlett in "Gone with the Wind"?
# Translated text 5: Quale data è nata l'attrice che ha interpretato Scarlett in "Gone with the Wind"?
# Translating text 6/198: Who is president of Peru?
# Translated text 6: Chi è il presidente del Perù?
# Translating text 7/198: Did Queen Elizabeth I have the longest reign in the UK?
# Translated text 7: La regina Elisabetta ha il regno più lungo del Regno Unito?
# Translating text 8/198: Which dynasty built the Great Wall of China?
# Translated text 8: Quale dinastia ha costruito la Grande Muraglia della Cina?
# Translating text 9/198: Who was the oldest person when they started their reign over the United Kingdom?
# Translated text 9: Chi era la persona più anziana quando iniziarono il loro regno sul Regno Unito?
# Translating text 10/198: Is the Yangtze or Yellow River longer?
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 56
#      53 tgt_language = "it"
#      55 # Perform translation
# ---> 56 translated_texts = simple_translate(texts_to_translate, src_language, tgt_language, m2m_model, m2m_tokenizer)
#      58 # Save the translated results
#      59 results = []
#
# Cell In[2], line 24, in simple_translate(texts, src_lang, tgt_lang, model, tokenizer)
#      22 print(f"Translating text {idx + 1}/{len(texts)}: {text}")
#      23 encoded_text = tokenizer(text, return_tensors="pt")
# ---> 24 generated_tokens = model.generate(
#      25     **encoded_text,
#      26     forced_bos_token_id=tokenizer.get_lang_id(tgt_lang),
#      27     max_length=128,
#      28     early_stopping=True
#      29 )
#      30 translated_text = tokenizer.batch_decode(generated_tokens, skip_special_tokens=True)[0]
#      31 print(f"Translated text {idx + 1}: {translated_text}")
#
# File ~/miniconda3/envs/cs375/lib/python3.11/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File ~/miniconda3/envs/cs375/lib/python3.11/site-packages/transformers/generation/utils.py:2283, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    2275     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    2276         input_ids=input_ids,
#    2277         expand_size=generation_config.num_beams,
#    2278         is_encoder_decoder=self.config.is_encoder_decoder,
#    2279         **model_kwargs,
#    2280     )
#    2282     # 13. run beam sample
# -> 2283     result = self._beam_search(
#    2284         input_ids,
#    2285         beam_scorer,
#    2286         logits_processor=prepared_logits_processor,
#    2287         stopping_criteria=prepared_stopping_criteria,
#    2288         generation_config=generation_config,
#    2289         synced_gpus=synced_gpus,
#    2290         **model_kwargs,
#    2291     )
#    2293 elif generation_mode == GenerationMode.GROUP_BEAM_SEARCH:
#    2294     # 11. prepare beam search scorer
#    2295     beam_scorer = BeamSearchScorer(
#    2296         batch_size=batch_size,
#    2297         num_beams=generation_config.num_beams,
#    (...)
#    2303         max_length=generation_config.max_length,
#    2304     )
#
# File ~/miniconda3/envs/cs375/lib/python3.11/site-packages/transformers/generation/utils.py:3503, in GenerationMixin._beam_search(self, input_ids, beam_scorer, logits_processor, stopping_criteria, generation_config, synced_gpus, **model_kwargs)
#    3500     outputs = stack_model_outputs(outputs_per_sub_batch, self.config.get_text_config())
#    3502 else:  # Unchanged original behavior
# -> 3503     outputs = self(**model_inputs, return_dict=True)
#    3505 # synced_gpus: don't waste resources running the code we don't need; kwargs must be updated before skipping
#    3506 model_kwargs = self._update_model_kwargs_for_generation(
#    3507     outputs,
#    3508     model_kwargs,
#    3509     is_encoder_decoder=self.config.is_encoder_decoder,
#    3510 )
#
# File ~/miniconda3/envs/cs375/lib/python3.11/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/cs375/lib/python3.11/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/cs375/lib/python3.11/site-packages/transformers/models/m2m_100/modeling_m2m_100.py:1582, in M2M100ForConditionalGeneration.forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1577     if decoder_input_ids is None:
#    1578         decoder_input_ids = shift_tokens_right(
#    1579             labels, self.config.pad_token_id, self.config.decoder_start_token_id
#    1580         )
# -> 1582 outputs = self.model(
#    1583     input_ids,
#    1584     attention_mask=attention_mask,
#    1585     decoder_input_ids=decoder_input_ids,
#    1586     encoder_outputs=encoder_outputs,
#    1587     decoder_attention_mask=decoder_attention_mask,
#    1588     head_mask=head_mask,
#    1589     decoder_head_mask=decoder_head_mask,
#    1590     cross_attn_head_mask=cross_attn_head_mask,
#    1591     past_key_values=past_key_values,
#    1592     inputs_embeds=inputs_embeds,
#    1593     decoder_inputs_embeds=decoder_inputs_embeds,
#    1594     use_cache=use_cache,
#    1595     output_attentions=output_attentions,
#    1596     output_hidden_states=output_hidden_states,
#    1597     return_dict=return_dict,
#    1598 )
#    1599 lm_logits = self.lm_head(outputs[0])
#    1601 masked_lm_loss = None
#
# File ~/miniconda3/envs/cs375/lib/python3.11/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/cs375/lib/python3.11/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/cs375/lib/python3.11/site-packages/transformers/models/m2m_100/modeling_m2m_100.py:1487, in M2M100Model.forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#    1480     encoder_outputs = BaseModelOutput(
#    1481         last_hidden_state=encoder_outputs[0],
#    1482         hidden_states=encoder_outputs[1] if len(encoder_outputs) > 1 else None,
#    1483         attentions=encoder_outputs[2] if len(encoder_outputs) > 2 else None,
#    1484     )
#    1486 # decoder outputs consists of (dec_features, past_key_value, dec_hidden, dec_attn)
# -> 1487 decoder_outputs = self.decoder(
#    1488     input_ids=decoder_input_ids,
#    1489     attention_mask=decoder_attention_mask,
#    1490     encoder_hidden_states=encoder_outputs[0],
#    1491     encoder_attention_mask=attention_mask,
#    1492     head_mask=decoder_head_mask,
#    1493     cross_attn_head_mask=cross_attn_head_mask,
#    1494     past_key_values=past_key_values,
#    1495     inputs_embeds=decoder_inputs_embeds,
#    1496     use_cache=use_cache,
#    1497     output_attentions=output_attentions,
#    1498     output_hidden_states=output_hidden_states,
#    1499     return_dict=return_dict,
#    1500 )
#    1502 if not return_dict:
#    1503     return decoder_outputs + encoder_outputs
#
# File ~/miniconda3/envs/cs375/lib/python3.11/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/cs375/lib/python3.11/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/cs375/lib/python3.11/site-packages/transformers/models/m2m_100/modeling_m2m_100.py:1345, in M2M100Decoder.forward(self, input_ids, attention_mask, encoder_hidden_states, encoder_attention_mask, head_mask, cross_attn_head_mask, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#    1332         layer_outputs = self._gradient_checkpointing_func(
#    1333             decoder_layer.__call__,
#    1334             hidden_states,
#    (...)
#    1342             use_cache,
#    1343         )
#    1344     else:
# -> 1345         layer_outputs = decoder_layer(
#    1346             hidden_states,
#    1347             attention_mask=combined_attention_mask,
#    1348             encoder_hidden_states=encoder_hidden_states,
#    1349             encoder_attention_mask=encoder_attention_mask,
#    1350             layer_head_mask=(head_mask[idx] if head_mask is not None else None),
#    1351             cross_attn_layer_head_mask=(
#    1352                 cross_attn_head_mask[idx] if cross_attn_head_mask is not None else None
#    1353             ),
#    1354             past_key_value=past_key_value,
#    1355             output_attentions=output_attentions,
#    1356             use_cache=use_cache,
#    1357         )
#    1359     hidden_states = layer_outputs[0]
#    1361 if skip_the_layer:
#
# File ~/miniconda3/envs/cs375/lib/python3.11/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/cs375/lib/python3.11/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/cs375/lib/python3.11/site-packages/transformers/models/m2m_100/modeling_m2m_100.py:743, in M2M100DecoderLayer.forward(self, hidden_states, attention_mask, encoder_hidden_states, encoder_attention_mask, layer_head_mask, cross_attn_layer_head_mask, past_key_value, output_attentions, use_cache)
#     741 # cross_attn cached key/values tuple is at positions 3,4 of present_key_value tuple
#     742 cross_attn_past_key_value = past_key_value[-2:] if past_key_value is not None else None
# --> 743 hidden_states, cross_attn_weights, cross_attn_present_key_value = self.encoder_attn(
#     744     hidden_states=hidden_states,
#     745     key_value_states=encoder_hidden_states,
#     746     attention_mask=encoder_attention_mask,
#     747     layer_head_mask=cross_attn_layer_head_mask,
#     748     past_key_value=cross_attn_past_key_value,
#     749     output_attentions=output_attentions,
#     750 )
#     751 hidden_states = nn.functional.dropout(hidden_states, p=self.dropout, training=self.training)
#     752 hidden_states = residual + hidden_states
#
# File ~/miniconda3/envs/cs375/lib/python3.11/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/cs375/lib/python3.11/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/cs375/lib/python3.11/site-packages/transformers/models/m2m_100/modeling_m2m_100.py:505, in M2M100SdpaAttention.forward(self, hidden_states, key_value_states, past_key_value, attention_mask, layer_head_mask, output_attentions)
#     502 bsz, tgt_len, _ = hidden_states.size()
#     504 # get query proj
# --> 505 query_states = self.q_proj(hidden_states)
#     506 # get key, value proj
#     507 # `past_key_value[0].shape[2] == key_value_states.shape[1]`
#     508 # is checking that the `sequence_length` of the `past_key_value` is the same as
#     509 # the provided `key_value_states` to support prefix tuning
#     510 if (
#     511     is_cross_attention
#     512     and past_key_value is not None
#     513     and past_key_value[0].shape[2] == key_value_states.shape[1]
#     514 ):
#     515     # reuse k,v, cross_attentions
#
# File ~/miniconda3/envs/cs375/lib/python3.11/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/cs375/lib/python3.11/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/cs375/lib/python3.11/site-packages/torch/nn/modules/linear.py:125, in Linear.forward(self, input)
#     124 def forward(self, input: Tensor) -> Tensor:
# --> 125     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:
