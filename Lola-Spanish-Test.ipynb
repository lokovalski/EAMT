# %%
#$ Entity Masking
import json
from span_marker import SpanMarkerModel


def load_entities_mapping(file_path):
    """
    Loads entities and their translations from the given JSON file, skipping invalid lines.
    Args:
        file_path (str): Path to the JSON file containing entity mappings.
    Returns:
        list: A list of dictionaries representing the JSON data.
    """
    with open(file_path, 'r') as jf:
        try:
            return json.load(jf)  # Load the entire JSON array
        except json.JSONDecodeError as e:
            print(f"Error loading JSON file: {e}")
            return []


def mask_entities_with_spanmarker(text, model):
    """
    Masks named entities in text using predictions from SpanMarkerModel.

    Args:
        text (Union[str, List[str]]): Input text(s). Can be a single string or a list of strings.
        model (SpanMarkerModel): Pretrained SpanMarker model for entity prediction.

    Returns:
        Union[Tuple[str, dict], List[Tuple[str, dict]]]:
            - For a single string:
                - masked_text (str): Text with entities replaced by placeholders.
                - mapping (dict): Mapping of placeholders to original entities.
            - For a list of strings:
                - List of (masked_text, mapping) tuples.
    """
    # Check if input is a single string or a list of strings
    is_single_string = isinstance(text, str)
    if is_single_string:
        text = [text]  # Convert single string to list for uniform processing

    # Perform predictions using the model
    predictions = model.predict(text)  # Handles batch processing

    results = []
    for i, sentence in enumerate(text):
        masked_text = sentence
        mapping = {}
        type_counters = {}
        offset = 0

        # If no predictions for this sentence
        if not predictions[i]:  # Empty list
            print(f"No entities found for text: {sentence}")
            results.append((masked_text, mapping))
            continue

        # Process each entity in the prediction
        for entity in predictions[i]:
            if entity['score'] > 0.7: 
                entity_text = entity['span']
                entity_type = entity['label'].upper()
                start = entity['char_start_index']
                end = entity['char_end_index']

                # Counter for entity type
                if entity_type not in type_counters:
                    type_counters[entity_type] = 1
                else:
                    type_counters[entity_type] += 1

                # Generate a placeholder
                placeholder = f"[ENTITY_{entity_type}_{type_counters[entity_type]}]"

                # Replace entity with placeholder in the text
                start += offset
                end += offset
                masked_text = masked_text[:start] + placeholder + masked_text[end:]
                offset += len(placeholder) - len(entity_text)

                # Add to mapping
                mapping[placeholder] = {
                    "original_text": entity_text,
                    "type": entity_type,
                    "confidence": entity['score'],
                    "start": start,
                    "end": end
                }

        results.append((masked_text, mapping))

    #if text input is a single string
    return results[0] if is_single_string else results

def ensure_pad_token(model):
    if not hasattr(model.tokenizer, "pad_token") or model.tokenizer.pad_token is None:
        print("Setting pad_token manually...")
        model.tokenizer.pad_token = "[PAD]"
        model.tokenizer.pad_token_id = model.tokenizer.convert_tokens_to_ids("[PAD]")

# %%
#$ MT Translation

from transformers import M2M100ForConditionalGeneration, M2M100Tokenizer

# Load the M2M100 model and tokenizer
model_name = "facebook/m2m100_418M"
model = M2M100ForConditionalGeneration.from_pretrained(model_name)
tokenizer = M2M100Tokenizer.from_pretrained(model_name)

def translate_with_placeholders_m2m(masked_text, mapping, src_lang, tgt_lang):
    """
    Translates the non-entity parts of a text and re-inserts placeholders using M2M100.

    Args:
        masked_text (str): Text with placeholders for entities.
        mapping (dict): Mapping of placeholders to entity details.
        src_lang (str): Source language code.
        tgt_lang (str): Target language code.

    Returns:
        str: Translated text with placeholders intact.
    """
    tokenizer.src_lang = src_lang

    # Encode and translate the entire sentence
    encoded_text = tokenizer(masked_text, return_tensors="pt")
    generated_tokens = model.generate(
        **encoded_text,
        forced_bos_token_id=tokenizer.get_lang_id(tgt_lang),
        max_length=128,  # Ensure sufficient length for translation
        early_stopping=True
    )

    # Decode the translated sentence
    translated_text = tokenizer.batch_decode(generated_tokens, skip_special_tokens=True)[0]
    return translated_text

# %%
#$ Entity Reintegration

from transformers import M2M100ForConditionalGeneration, M2M100Tokenizer

def translate_entity(entity, src_lang, tgt_lang):
    """
    Translates an entity if its type requires translation, otherwise returns the original entity.

    Args:
        entity (str): The placeholder or entity to process.
        src_lang (str): Source language code.
        tgt_lang (str): Target language code.

    Returns:
        str: The translated or original entity.
    """
    # types that should not be translated
    non_translatable_types = {"PER", "INST", "MEDIA", "PLANT", "VEHI"}

    # Check if the entity contains one of the non-translatable types
    if any(ntype in entity for ntype in non_translatable_types):
        return entity 

    # Translate the entity using M2M100
    tokenizer = M2M100Tokenizer.from_pretrained("facebook/m2m100_418M")
    model = M2M100ForConditionalGeneration.from_pretrained("facebook/m2m100_418M")
    tokenizer.src_lang = src_lang
    encoded_entity = tokenizer(entity, return_tensors="pt")
    generated_tokens = model.generate(**encoded_entity, forced_bos_token_id=tokenizer.get_lang_id(tgt_lang))
    translated_entity = tokenizer.batch_decode(generated_tokens, skip_special_tokens=True)[0]

    return translated_entity


def reintegrate_entities(translation, mapping, src_lang, tgt_lang):
    """
    Replaces placeholders in the translated text with original or translated entities.

    Args:
        translation (str): Translated text with placeholders.
        mapping (dict): Mapping of placeholders to original entities.
        src_lang (str): Source language code.
        tgt_lang (str): Target language code.

    Returns:
        str: Translation with entities reintegrated.
    """
    for placeholder, entity_info in mapping.items():
        # Get the original entity
        original_entity = entity_info["original_text"]

        # Translate the entity if needed
        translated_entity = translate_entity(original_entity, src_lang, tgt_lang)

        # Replace placeholder with the translated entity
        translation = translation.replace(placeholder, translated_entity)

    return translation

# %%
import os
es_datapath = os.path.abspath('data/spanish_test.json')

    # Step 1: Load the data
print("Loading Spanish data...")
spanish_data = load_entities_mapping(es_datapath)
# Out:
# Loading Spanish data...

# %%
spanish_data
# Out:
# [{'id': '25ed319e',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What is the largest park in the capital city of the UK?',
#   'target': '¿Cuál es el parque más grande en la capital del Reino Unido?',
#   'entities': {'Q145': {'es': 'Reino Unido', 'en': 'United Kingdom'}},
#   'from': 'mintaka'},
#  {'id': 'ff08e26c',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which Twilight books did not include the character Renesmee?',
#   'target': '¿Cuáles de los libros de Crepúsculo no incluyeron el personaje de Renesmee?',
#   'entities': {'Q44523': {'es': 'Crepúsculo', 'en': 'Twilight'}},
#   'from': 'mintaka'},
#  {'id': '8e6811f5',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What is the third smallest country in Africa?',
#   'target': '¿Cuál es el tercer país más pequeño de África?',
#   'entities': {'Q15': {'es': 'África', 'en': 'Africa'}},
#   'from': 'mintaka'},
#  {'id': '75ab165c',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Where was the first all-woman city council in the United States?',
#   'target': '¿Dónde fue el primer ayuntamiento completamente femenino en los Estados Unidos?',
#   'entities': {'Q30': {'es': 'Estados Unidos',
#     'en': 'United States of America'}},
#   'from': 'mintaka'},
#  {'id': '9200a0f9',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What is the population of the most populous country in South America?',
#   'target': '¿Cuál es la población del país más poblado de América del Sur?',
#   'entities': {'Q18': {'es': 'América del Sur', 'en': 'South America'}},
#   'from': 'mintaka'},
#  {'id': '41df65d9',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'How many Supreme Leaders of North Korea have there been?',
#   'target': '¿Cuántos líderes supremos de Corea del Norte hubo?',
#   'entities': {'Q423': {'es': 'Corea del Norte', 'en': 'North Korea'}},
#   'from': 'mintaka'},
#  {'id': '43acecc1',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who became the president of Germany on 1 July 1994?',
#   'target': '¿Quién se convirtió en presidente de Alemania el primero de julio de mil novecientos noventa y cuatro?',
#   'entities': {'Q183': {'es': 'Alemania', 'en': 'Germany'}},
#   'from': 'mintaka'},
#  {'id': '1f137e82',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What is the largest city in England by population?',
#   'target': '¿Cuál es ciudad más grande de Inglaterra por población?',
#   'entities': {'Q21': {'es': 'Inglaterra', 'en': 'England'}},
#   'from': 'mintaka'},
#  {'id': '48fa8e84',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who is the oldest pitcher to throw a no-hitter?',
#   'target': '¿Quién es el lanzador más viejo que lanzó un no hitter?',
#   'entities': {'Q1048902': {'es': 'lanzador', 'en': 'pitcher'}},
#   'from': 'mintaka'},
#  {'id': 'adc66bf5',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': "Which was written first, Fear and Loathing in Las Vegas or Fear and Loathing on the Campaign Trail '72?",
#   'target': "¿Cuál fue escrito primer, Miedo y Asco en Las Vegas o Miedo y Asco en el sendero '72?",
#   'entities': {'Q772435': {'es': 'Miedo y asco en Las Vegas',
#     'en': 'Fear and Loathing in Las Vegas'}},
#   'from': 'mintaka'},
#  {'id': '1210bf99',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which main character in Twilight was not a vampire or werewolf?',
#   'target': '¿Qué protagonista de Crepúsculo no era ni vampiro ni hombre lobo?',
#   'entities': {'Q44523': {'es': 'Crepúsculo', 'en': 'Twilight'}},
#   'from': 'mintaka'},
#  {'id': '18d7dd81',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which war lasted longer, Second Seminole War or World War II?',
#   'target': '¿Cuál guerra duró más, la Segunda Guerra Seminola o la Segunda Guerra Mundial?',
#   'entities': {'Q362': {'es': 'Segunda Guerra Mundial', 'en': 'World War II'},
#    'Q2976715': {'es': 'Segunda guerra semínola', 'en': 'Second Seminole War'}},
#   'from': 'mintaka'},
#  {'id': '3eed41ec',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who was the first pope?',
#   'target': '¿Quién fue el primer Papa?',
#   'entities': {'Q19546': {'es': 'papa', 'en': 'pope'}},
#   'from': 'mintaka'},
#  {'id': '432b3d5e',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What is the last book in the Lord of the Rings series? 4?',
#   'target': '¿Cuál es el último libro de la serie El Señor de los Anillos?',
#   'entities': {'Q15228': {'es': 'El Señor de los Anillos',
#     'en': 'The Lord of the Rings'}},
#   'from': 'mintaka'},
#  {'id': 'cc4a9909',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': "Who is Mitch McConnell's Democratic Party challenger in the 2020 Kentucky Senate Elections?",
#   'target': '¿Quién es el contendiente del partido demócrata de Mitch McConnell en las elecciones del Senado de Kentucky en 2020?',
#   'entities': {'Q29552': {'es': 'Partido Demócrata',
#     'en': 'Democratic Party'}},
#   'from': 'mintaka'},
#  {'id': 'f477742c',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': "Which actor was Stephenie Meyer's first choice to play Edward Cullen in the movie Twilight?",
#   'target': '¿Qué actor fue la primera opción de Stephanie Meyer para interpretar a Edward Cullen en la película Crepúsculo?',
#   'entities': {'Q160219': {'es': 'Stephenie Meyer', 'en': 'Stephenie Meyer'},
#    'Q160071': {'es': 'Crepúsculo', 'en': 'Twilight'}},
#   'from': 'mintaka'},
#  {'id': '19bb6aeb',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which country has a more dense population, Canada or the United States?',
#   'target': '¿Qué país tiene mayor densidad de población, Canadá o Estados Unidos?',
#   'entities': {'Q16': {'es': 'Canadá', 'en': 'Canada'},
#    'Q30': {'es': 'Estados Unidos', 'en': 'United States of America'}},
#   'from': 'mintaka'},
#  {'id': 'a7848241',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'How many queens has England had?',
#   'target': '¿Cuántas reinas ha tenido Inglaterra?',
#   'entities': {'Q21': {'es': 'Inglaterra', 'en': 'England'}},
#   'from': 'mintaka'},
#  {'id': '3c469148',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What is the capital of the state that had the last volcanic eruption in the United States?',
#   'target': '¿Cuál es la capital del estado que tuvo la última erupción volcánica en Estados Unidos?',
#   'entities': {'Q30': {'es': 'Estados Unidos',
#     'en': 'United States of America'}},
#   'from': 'mintaka'},
#  {'id': 'd43eda6e',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'When was the modern Chinese government formed?',
#   'target': '¿Cuándo se formó el gobierno chino moderno?',
#   'entities': {'Q148': {'es': 'República Popular China',
#     'en': "People's Republic of China"}},
#   'from': 'mintaka'},
#  {'id': '5a449509',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What is the largest city in Russia by population?',
#   'target': '¿Cuál es la mayor ciudad de Rusia por población?',
#   'entities': {'Q159': {'es': 'Rusia', 'en': 'Russia'}},
#   'from': 'mintaka'},
#  {'id': 'f0a24474',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What is the population of the state where Mount Rainier is located?',
#   'target': '¿Cuál es la población del estado donde se localiza el Monte Rainier?',
#   'entities': {'Q194057': {'es': 'Monte Rainier', 'en': 'Mount Rainier'}},
#   'from': 'mintaka'},
#  {'id': '9f3762f0',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': "Did the USA men's national soccer team qualify for the last World Cup?",
#   'target': '¿El equipo de fútbol nacional masculino de los Estados Unidos calificó para la última Copa Mundial?',
#   'entities': {'Q30': {'es': 'Estados Unidos',
#     'en': 'United States of America'}},
#   'from': 'mintaka'},
#  {'id': 'af82328a',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which state has less Congressional Districts, Missouri or Illinois?',
#   'target': '¿Qué estado tiene menos distritos congresales, Missouri o Ilinois?',
#   'entities': {'Q1204': {'es': 'Illinois', 'en': 'Illinois'}},
#   'from': 'mintaka'},
#  {'id': '2961df92',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who is the president of South Africa?',
#   'target': '¿Quién es el presidente de Sudáfrica?',
#   'entities': {'Q258': {'es': 'Sudáfrica', 'en': 'South Africa'}},
#   'from': 'mintaka'},
#  {'id': 'f1e17a1d',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who was from Illinois and signed the Emancipation Proclamation?',
#   'target': '¿Quién era de Illinois y firmó la Proclamación de Emancipación?',
#   'entities': {'Q391358': {'es': 'Proclamación de Emancipación',
#     'en': 'Emancipation Proclamation'}},
#   'from': 'mintaka'},
#  {'id': '4a86a12f',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which is the most spoken language in South America?',
#   'target': '¿Cuál es el idioma más hablado en América del Sur?',
#   'entities': {'Q18': {'es': 'América del Sur', 'en': 'South America'}},
#   'from': 'mintaka'},
#  {'id': '7cd29dc9',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What is the tallest mountain in Africa?',
#   'target': '¿Cuál es la montaña más alta de África?',
#   'entities': {'Q15': {'es': 'África', 'en': 'Africa'}},
#   'from': 'mintaka'},
#  {'id': '2d29eb77',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which United States president had the shortest time in office?',
#   'target': '¿Qué presidente de Estados Unidos estuvo menos tiempo en su cargo?',
#   'entities': {'Q30': {'es': 'Estados Unidos',
#     'en': 'United States of America'}},
#   'from': 'mintaka'},
#  {'id': '967098a0',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who ran for president in 2016 and graduated from the University of Pennsylvania?',
#   'target': '¿Quién compitió en las elecciones presidenciales de 2016 y se graduó de la Universidad de Pensilvania?',
#   'entities': {'Q49117': {'es': 'Universidad de Pensilvania',
#     'en': 'University of Pennsylvania'}},
#   'from': 'mintaka'},
#  {'id': '87f36c14',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Is Paris the capital of France?',
#   'target': '¿París es la capital de Francia?',
#   'entities': {'Q90': {'es': 'París', 'en': 'Paris'},
#    'Q142': {'es': 'Francia', 'en': 'France'}},
#   'from': 'mintaka'},
#  {'id': 'e43702ad',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who was the president of the United States when World War II started?',
#   'target': '¿Quién fue presidente de los Estados Unidos cuando inició la Segunda Guerra Mundial?',
#   'entities': {'Q30': {'es': 'Estados Unidos',
#     'en': 'United States of America'},
#    'Q362': {'es': 'Segunda Guerra Mundial', 'en': 'World War II'}},
#   'from': 'mintaka'},
#  {'id': '6d1a3e6f',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'In what year did the author who wrote To Kill a Mockingbird die?',
#   'target': '¿En qué año falleció el autor de Matar un Ruiseñor?',
#   'entities': {'Q212340': {'es': 'Matar un ruiseñor',
#     'en': 'To Kill a Mockingbird'}},
#   'from': 'mintaka'},
#  {'id': 'e1e3808a',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Is Jacinda Ardern the 40th prime minister of New Zealand?',
#   'target': '¿Jacinda Ardern es la 40º primera ministra de Nueva Zelanda?',
#   'entities': {'Q664': {'es': 'Nueva Zelanda', 'en': 'New Zealand'}},
#   'from': 'mintaka'},
#  {'id': 'a97ae9d4',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who built the pyramids in Mexico?',
#   'target': '¿Quién construyó las pirámides en México?',
#   'entities': {'Q96': {'es': 'México', 'en': 'Mexico'}},
#   'from': 'mintaka'},
#  {'id': 'a9063f9a',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Is Mount Everest taller than Denali?',
#   'target': '¿El monte Everest es más alto que el Denali?',
#   'entities': {'Q513': {'es': 'Everest', 'en': 'Mount Everest'}},
#   'from': 'mintaka'},
#  {'id': '9a7aac72',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Is Brazil a democracy?',
#   'target': '¿Brasil es un país democrático?',
#   'entities': {'Q155': {'es': 'Brasil', 'en': 'Brazil'}},
#   'from': 'mintaka'},
#  {'id': '706d3ae1',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Is there a Royal Palace in the United States?',
#   'target': '¿Existe un palacio real en los Estados Unidos?',
#   'entities': {'Q30': {'es': 'Estados Unidos',
#     'en': 'United States of America'}},
#   'from': 'mintaka'},
#  {'id': 'b6c5c17c',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which movie is part of the Marvel Cinematic Universe and has Chadwick Boseman in the titular role?',
#   'target': '¿Qué película es parte de el Universo Cinematográfico de Marvel y tiene a Chadwick Boseman en el papel principal?',
#   'entities': {'Q642878': {'es': 'Universo cinematográfico de Marvel',
#     'en': 'Marvel Cinematic Universe'}},
#   'from': 'mintaka'},
#  {'id': '621d29de',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What is the third largest lake in the United States?',
#   'target': '¿Cuál es el tercer mayor lago en los Estados Unidos?',
#   'entities': {'Q30': {'es': 'Estados Unidos',
#     'en': 'United States of America'}},
#   'from': 'mintaka'},
#  {'id': 'fb15deb3',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which Blackpink members were not from South Korea?',
#   'target': '¿Qué miembros de Blackpink no eran de Corea del sur?',
#   'entities': {'Q884': {'es': 'Corea del Sur', 'en': 'South Korea'}},
#   'from': 'mintaka'},
#  {'id': 'bd7f3fef',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Did the last Lord of the Rings book come out before the year 2000?',
#   'target': '¿El último libro de El señor de los anillos se publicó antes del año 2000?',
#   'entities': {'Q15228': {'es': 'El Señor de los Anillos',
#     'en': 'The Lord of the Rings'}},
#   'from': 'mintaka'},
#  {'id': '031fb164',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What is the population of the smallest country in Europe?',
#   'target': '¿Cuál es la población del país más pequeño en Europa?',
#   'entities': {'Q46': {'es': 'Europa', 'en': 'Europe'}},
#   'from': 'mintaka'},
#  {'id': 'd444c062',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who was the first president to have a Christmas tree at the White House?',
#   'target': '¿Quién fue el primer presidente que tuvo un árbol de navidad en la Casa Blanca?',
#   'entities': {'Q35525': {'es': 'Casa Blanca', 'en': 'White House'}},
#   'from': 'mintaka'},
#  {'id': 'c4461fb3',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which leader of Mongol Empire invaded Japan but did not conquer it?',
#   'target': '¿Cuál líder del Imperio mongol invadió a Japón pero no lo conquistó?',
#   'entities': {'Q12557': {'es': 'Imperio mongol', 'en': 'Mongol Empire'},
#    'Q17': {'es': 'Japón', 'en': 'Japan'}},
#   'from': 'mintaka'},
#  {'id': '856bb298',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What war started first, the Korean War or Vietnam War?',
#   'target': '¿Cuál guerra comenzó primero, la guerra de Corea o la guerra de Vietnam?',
#   'entities': {'Q8663': {'es': 'guerra de Corea', 'en': 'Korean War'},
#    'Q8740': {'es': 'Guerra de Vietnam', 'en': 'Vietnam War'}},
#   'from': 'mintaka'},
#  {'id': '155ddfb0',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'When did James Joyce write Dubliners?',
#   'target': '¿Cuándo escribió James Joyce Dublineses?',
#   'entities': {'Q459592': {'es': 'Dublineses', 'en': 'Dubliners'}},
#   'from': 'mintaka'},
#  {'id': 'bfa873d0',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who served as Canadian prime minister for longer, Kim Campbell or William Mackenzie King?',
#   'target': '¿Quién duró más tiempo como primer ministro de Canadá: Kim Campbell o William Mackenzie King?',
#   'entities': {'Q16': {'es': 'Canadá', 'en': 'Canada'}},
#   'from': 'mintaka'},
#  {'id': '90e0aec7',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Was the Lord of the Rings published before Dune?',
#   'target': '¿El señor de los anillos fue publicado antes de Dune?',
#   'entities': {'Q15228': {'es': 'El Señor de los Anillos',
#     'en': 'The Lord of the Rings'}},
#   'from': 'mintaka'},
#  {'id': '3b66ab40',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Did the United States fight against France to gain its independence in the Revolutionary War?',
#   'target': '¿Los Estados Unidos peleó contra Francia para obtener su independencia en la Guerra Revolucionaria?',
#   'entities': {'Q30': {'es': 'Estados Unidos',
#     'en': 'United States of America'},
#    'Q142': {'es': 'Francia', 'en': 'France'}},
#   'from': 'mintaka'},
#  {'id': '93736bd2',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who served in WW II as the Supreme Commander of the Allied Expeditionary Forces in Europe and later became president of the United States?',
#   'target': '¿Quién fue Comandante Aliado Supremo de las fuerzas Aliadas Expedicionarias durante la Segunda Guerra Mundial y luego se convirtió en presidente de Estados Unidos?',
#   'entities': {'Q30': {'es': 'Estados Unidos',
#     'en': 'United States of America'},
#    'Q362': {'es': 'Segunda Guerra Mundial', 'en': 'World War II'}},
#   'from': 'mintaka'},
#  {'id': '52ba4569',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who directed the movie based on the first Twilight book?',
#   'target': '¿Quién dirigió la película basada en el primer libro Crepúsculo?',
#   'entities': {'Q44523': {'es': 'Crepúsculo', 'en': 'Twilight'}},
#   'from': 'mintaka'},
#  {'id': '4aaa6f8f',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'How many Grammy Awards did Jay-Z win in 2021?',
#   'target': '¿Cuántos Grammys ganó Jay Z en 2021?',
#   'entities': {'Q62766': {'es': 'Jay-Z', 'en': 'Jay-Z'}},
#   'from': 'mintaka'},
#  {'id': '8b8d4b73',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Does China have a larger land area than the United States?',
#   'target': '¿China tiene mayor superficie de tierra que Estados Unidos?',
#   'entities': {'Q30': {'es': 'Estados Unidos',
#     'en': 'United States of America'}},
#   'from': 'mintaka'},
#  {'id': '18a4567d',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What is the continent, besides Antarctica, that has never hosted the Olympics?',
#   'target': '¿Cuál es el continente, sin contar la Antártida, que nunca celebró una Olimpiada?',
#   'entities': {'Q51': {'es': 'Antártida', 'en': 'Antarctica'}},
#   'from': 'mintaka'},
#  {'id': 'c0a6a234',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Was Pride and Prejudice written before or after Sense and Sensibility?',
#   'target': '¿Orgullo y Prejuicio fue escrito antes o después de Sensatez y Sentimientos?',
#   'entities': {'Q170583': {'es': 'Orgullo y prejuicio',
#     'en': 'Pride and Prejudice'}},
#   'from': 'mintaka'},
#  {'id': 'ead5d2b4',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Was Switzerland invaded by Hitler during World War II?',
#   'target': '¿Hitler invadió Suiza durante la Segunda Guerra Mundial?',
#   'entities': {'Q362': {'es': 'Segunda Guerra Mundial', 'en': 'World War II'},
#    'Q39': {'es': 'Suiza', 'en': 'Switzerland'}},
#   'from': 'mintaka'},
#  {'id': '0c3d3404',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who had the longer reign, Peter the Great or Nicholas I?',
#   'target': '¿Quién tuvo el reinado más largo, Pedro el Grande o Nicolás I?',
#   'entities': {'Q8479': {'es': 'Pedro I', 'en': 'Peter the Great'}},
#   'from': 'mintaka'},
#  {'id': 'c60f619b',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who was both a child of Henry VIII and rival of Philip II of Spain?',
#   'target': '¿Quién fue tanto hija de Enrique VIII como rival de Felipe II de España?',
#   'entities': {'Q34417': {'es': 'Felipe II de España',
#     'en': 'Philip II of Spain'}},
#   'from': 'mintaka'},
#  {'id': '55fd2a32',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which French leader tried to invade Russia in 1812, but did not succeed?',
#   'target': '¿Qué líder francés intentó invadir Rusia en 1812, pero no tuvo éxito?',
#   'entities': {'Q159': {'es': 'Rusia', 'en': 'Russia'}},
#   'from': 'mintaka'},
#  {'id': 'f470e9cc',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'How many Democrat governors has Pennsylvania had since the year 2000?',
#   'target': '¿Cuántos gobernadores demócratas han habido en Pensilvania desde el año 2000?',
#   'entities': {'Q1400': {'es': 'Pensilvania', 'en': 'Pennsylvania'}},
#   'from': 'mintaka'},
#  {'id': 'e7568709',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'In what year was the architect who made the Eiffel Tower born?',
#   'target': '¿En qué año nació el arquitecto que creó la Torre Eiffel?',
#   'entities': {'Q243': {'es': 'Torre Eiffel', 'en': 'Eiffel Tower'}},
#   'from': 'mintaka'},
#  {'id': 'ee4c9b21',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who is older, Lana Del Rey or Adele?',
#   'target': '¿Quién es mayor, Lana Del Ray o Adele?',
#   'entities': {'Q37150': {'es': 'Lana Del Rey', 'en': 'Lana Del Rey'}},
#   'from': 'mintaka'},
#  {'id': 'fbd8ca48',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What is the 2nd tallest mountain in the United States?',
#   'target': '¿Cuál es la segunda montaña más alta de los Estados Unidos?',
#   'entities': {'Q30': {'es': 'Estados Unidos',
#     'en': 'United States of America'}},
#   'from': 'mintaka'},
#  {'id': 'c1c941ec',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which pharaoh of Egypt was the youngest?',
#   'target': '¿Qué faraón de Egipto fue el más joven?',
#   'entities': {'Q79': {'es': 'Egipto', 'en': 'Egypt'}},
#   'from': 'mintaka'},
#  {'id': '3d277e5a',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': "Who was France's first president?",
#   'target': '¿Quién fue el primer presidente de Francia?',
#   'entities': {'Q142': {'es': 'Francia', 'en': 'France'}},
#   'from': 'mintaka'},
#  {'id': '094b3d88',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'How many provinces are in Canada?',
#   'target': '¿Cuántas provincias tiene Canadá?',
#   'entities': {'Q16': {'es': 'Canadá', 'en': 'Canada'}},
#   'from': 'mintaka'},
#  {'id': '49acff7c',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which Grammy Award was Always Remember us This Way nominated for but did not win?',
#   'target': '¿Para qué Premio Grammy fue nominada Always Remember us This Way y no ganó?',
#   'entities': {'Q41254': {'es': 'premios Grammy', 'en': 'Grammy Award'}},
#   'from': 'mintaka'},
#  {'id': '30d42682',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which country has a larger population, Brazil or Colombia?',
#   'target': '¿Qué país tiene una mayor población, Brasil o Colombia?',
#   'entities': {'Q155': {'es': 'Brasil', 'en': 'Brazil'}},
#   'from': 'mintaka'},
#  {'id': 'd3e7e19b',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which governor of Washington state since 1980 was not from the Democratic Party?',
#   'target': '¿Qué gobernador del estado de Washington no era miembro del partido demócrata desde 1980?',
#   'entities': {'Q29552': {'es': 'Partido Demócrata',
#     'en': 'Democratic Party'}},
#   'from': 'mintaka'},
#  {'id': '4540a215',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who is the president of Italy?',
#   'target': '¿Quién es el presidente de Italia?',
#   'entities': {'Q38': {'es': 'Italia', 'en': 'Italy'}},
#   'from': 'mintaka'},
#  {'id': '4f2c00ef',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which NFL franchise was located in both St. Louis and Los Angeles?',
#   'target': '¿Qué franquicia de la NFL se ubicaba tanto en St. Louis como Los Ángeles?',
#   'entities': {'Q65': {'es': 'Los Ángeles', 'en': 'Los Angeles'}},
#   'from': 'mintaka'},
#  {'id': '2bf3ec8b',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'How many U.S. states touch the Pacific Ocean?',
#   'target': '¿Cuántos estados de los EE. UU. tocan el Océano Pacífico?',
#   'entities': {'Q98': {'es': 'océano Pacífico', 'en': 'Pacific Ocean'}},
#   'from': 'mintaka'},
#  {'id': 'abf3502c',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'In 2021, who is the emperor of Japan?',
#   'target': '¿Quién es el emperador de Japón en 2021?',
#   'entities': {'Q17': {'es': 'Japón', 'en': 'Japan'}},
#   'from': 'mintaka'},
#  {'id': '43c8fa81',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which country elected its first president earlier, the United States or India?',
#   'target': '¿Qué país eligió a su primer presidente antes, los Estados Unidos o la India?',
#   'entities': {'Q30': {'es': 'Estados Unidos',
#     'en': 'United States of America'}},
#   'from': 'mintaka'},
#  {'id': '8166fd1d',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which president of the United States served the longest as president?',
#   'target': '¿Qué presidente de Estados Unidos fue el que más tiempo estuvo en la presidencia?',
#   'entities': {'Q30': {'es': 'Estados Unidos',
#     'en': 'United States of America'}},
#   'from': 'mintaka'},
#  {'id': '2738f9b7',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What is the largest country in Africa by population?',
#   'target': '¿Cuál es el mayor país en África por población?',
#   'entities': {'Q15': {'es': 'África', 'en': 'Africa'}},
#   'from': 'mintaka'},
#  {'id': '9cf4b2ae',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who flew the VF-51 in the Korean war and walked on the moon?',
#   'target': '¿Quién volaba el VF-51 en la guerra de Corea y caminó en la luna?',
#   'entities': {'Q8663': {'es': 'guerra de Corea', 'en': 'Korean War'}},
#   'from': 'mintaka'},
#  {'id': 'c339a3b5',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'How many main islands does Japan have?',
#   'target': '¿Cuántas islas principales tiene Japón?',
#   'entities': {'Q17': {'es': 'Japón', 'en': 'Japan'}},
#   'from': 'mintaka'},
#  {'id': '7663f949',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'How many countries in Europe are still sovereign monarchies?',
#   'target': '¿Cuántos países de Europa todavía son monarquías?',
#   'entities': {'Q46': {'es': 'Europa', 'en': 'Europe'}},
#   'from': 'mintaka'},
#  {'id': 'baacaa28',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Is Mount Everest the highest in the world?',
#   'target': '¿Es el monte Everest el más alto en el mundo?',
#   'entities': {'Q513': {'es': 'Everest', 'en': 'Mount Everest'}},
#   'from': 'mintaka'},
#  {'id': '9fa85788',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Where is the Easter Island of Moai located?',
#   'target': '¿Dónde están ubicados los moáis de la Isla de Pascua?',
#   'entities': {'Q14452': {'es': 'Isla de Pascua', 'en': 'Easter Island'}},
#   'from': 'mintaka'},
#  {'id': '9bcdff9d',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What is the largest city in the U.S. by population?',
#   'target': '¿Cuál es la ciudad más grande de Estados Unidos por población?',
#   'entities': {'Q30': {'es': 'Estados Unidos',
#     'en': 'United States of America'}},
#   'from': 'mintaka'},
#  {'id': '59d86e55',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which French leader invaded Mexico, but never conquered it?',
#   'target': '¿Qué líder francés invadió México pero nunca lo conquistó?',
#   'entities': {'Q96': {'es': 'México', 'en': 'Mexico'}},
#   'from': 'mintaka'},
#  {'id': '19f43d2b',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Is Damascus the oldest continuously inhabited city in the world?',
#   'target': '¿Es Damasco la ciudad más vieja habitada en el mundo?',
#   'entities': {'Q3766': {'es': 'Damasco', 'en': 'Damascus'}},
#   'from': 'mintaka'},
#  {'id': '71ff7fe4',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What is the longest river in the United States that is not named after the state where it begins?',
#   'target': '¿Cuál es el río más largo en los Estados Unidos que no está nombrado por el Estado en el que comienza?',
#   'entities': {'Q30': {'es': 'Estados Unidos',
#     'en': 'United States of America'}},
#   'from': 'mintaka'},
#  {'id': '5d201dc8',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which president of the United States was responsible for the largest land purchase in United States history?',
#   'target': '¿Qué presidente de los Estados Unidos fue responsable de la compra más grande de territorio en la historia de los Estados Unidos?',
#   'entities': {'Q30': {'es': 'Estados Unidos',
#     'en': 'United States of America'}},
#   'from': 'mintaka'},
#  {'id': 'c6f20865',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'How many times has Joe Biden run for president of the United States and not win?',
#   'target': '¿Cuántas veces Joe Biden contendió para presidente de los Estados Unidos y NO ganó?',
#   'entities': {'Q30': {'es': 'Estados Unidos',
#     'en': 'United States of America'}},
#   'from': 'mintaka'},
#  {'id': '0e392685',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which state was first to secede from the Union in the American Civil War?',
#   'target': '¿Qué estado fue el primero en salir de la Unión en la Guerra Civil Americana?',
#   'entities': {'Q214102': {'es': 'Unión', 'en': 'Union'}},
#   'from': 'mintaka'},
#  {'id': '974b11e6',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'When did the author who wrote the Lord of the Rings series die?',
#   'target': '¿Cuándo murió el autor que escribió la serie El señor de los anillos?',
#   'entities': {'Q15228': {'es': 'El Señor de los Anillos',
#     'en': 'The Lord of the Rings'}},
#   'from': 'mintaka'},
#  {'id': 'af10997c',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who was the last pharaoh of Egypt?',
#   'target': '¿Quién fue el último faraón de Egipto?',
#   'entities': {'Q79': {'es': 'Egipto', 'en': 'Egypt'}},
#   'from': 'mintaka'},
#  {'id': '50acefda',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who was the oldest emperor of Rome?',
#   'target': '¿Quién fue el emperador más viejo de Roma?',
#   'entities': {'Q220': {'es': 'Roma', 'en': 'Rome'}},
#   'from': 'mintaka'},
#  {'id': 'cb302d77',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'How many countries were involved on allies side in WW I?',
#   'target': '¿Cuántas naciones estuvieron del lado de los Aliados en la Primera Guerra Mundial?',
#   'entities': {'Q361': {'es': 'Primera Guerra Mundial', 'en': 'World War I'}},
#   'from': 'mintaka'},
#  {'id': '8cabed09',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': "What Grammy Award was Everything I Wanted nominated for but didn't win?",
#   'target': '¿Para qué Premio Grammy fue nominada Everything I Wanted, pero no ganó?',
#   'entities': {'Q41254': {'es': 'premios Grammy', 'en': 'Grammy Award'}},
#   'from': 'mintaka'},
#  {'id': '24bdf5c4',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which city has the tallest skyscraper in the United States?',
#   'target': '¿Qué ciudad tiene el rascacielos más alto en Estados Unidos?',
#   'entities': {'Q30': {'es': 'Estados Unidos',
#     'en': 'United States of America'}},
#   'from': 'mintaka'},
#  {'id': '8be1ab7c',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which war involved a larger number of countries, World War I or World War II?',
#   'target': '¿Cuál guerra involucró a un mayor número de países, la Primera Guerra Mundial o la Segunda Guerra Mundial?',
#   'entities': {'Q362': {'es': 'Segunda Guerra Mundial', 'en': 'World War II'},
#    'Q361': {'es': 'Primera Guerra Mundial', 'en': 'World War I'}},
#   'from': 'mintaka'},
#  {'id': 'c460b10e',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who was the first leader of the Persian Empire?',
#   'target': '¿Quién fue el primer líder del Imperio persa?',
#   'entities': {'Q83311': {'es': 'Imperio persa', 'en': 'Persian Empire'}},
#   'from': 'mintaka'},
#  {'id': 'ecc80a6a',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What is the largest city in Ireland by population?',
#   'target': '¿Cuál es la ciudad más grande de Irlanda por población?',
#   'entities': {'Q27': {'es': 'Irlanda', 'en': 'Ireland'}},
#   'from': 'mintaka'},
#  {'id': '7707d544',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What is the smallest state by land mass in the U.S.?',
#   'target': '¿Cuál es el estado más pequeño en los Estado Unidos, de acuerdo a masa de tierra?',
#   'entities': {'Q30': {'es': 'Estados Unidos',
#     'en': 'United States of America'}},
#   'from': 'mintaka'},
#  {'id': 'b32440f2',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'How many Grammy Awards did Childish Gambino win in 2019?',
#   'target': '¿Cuántos premios Grammy ganó Childish Gambino en 2019?',
#   'entities': {'Q41254': {'es': 'premios Grammy', 'en': 'Grammy Award'}},
#   'from': 'mintaka'},
#  {'id': '6ff78089',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which book introduced a small hobbit and was loosely based on the Bible?',
#   'target': '¿Qué libro introdujo un pequeño hobbit y estaba basado ligeramente en la Biblia?',
#   'entities': {'Q1845': {'es': 'Biblia', 'en': 'Bible'}},
#   'from': 'mintaka'},
#  {'id': '41903821',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What year did WW I start?',
#   'target': '¿En qué año comenzó la Primera Guerra Mundial?',
#   'entities': {'Q361': {'es': 'Primera Guerra Mundial', 'en': 'World War I'}},
#   'from': 'mintaka'},
#  {'id': 'eef2eca2',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Is Berlin the capital of Germany?',
#   'target': '¿Es Berlín la capital de Alemania?',
#   'entities': {'Q183': {'es': 'Alemania', 'en': 'Germany'},
#    'Q64': {'es': 'Berlín', 'en': 'Berlin'}},
#   'from': 'mintaka'},
#  {'id': '2ba64f93',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which book is longer, The Fellowship of the Ring or The Two Towers?',
#   'target': '¿Cuál libro es más largo, La comunidad del anillo Las dos torres?',
#   'entities': {'Q332388': {'es': 'Las dos torres', 'en': 'The Two Towers'},
#    'Q208002': {'es': 'La Comunidad del Anillo',
#     'en': 'The Fellowship of the Ring'}},
#   'from': 'mintaka'},
#  {'id': 'fa1af2f7',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which river in the United States is nicknamed Old Man River and is also the chief river of the second largest drainage system on the North American continent?',
#   'target': '¿Cuál río de los Estados Unidos se apoda Old Man River y es también el río jefe del sistema de drenaje segundo más grande del continente norteamericano?',
#   'entities': {'Q30': {'es': 'Estados Unidos',
#     'en': 'United States of America'}},
#   'from': 'mintaka'},
#  {'id': '47a0c9cb',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'How many books are in The Lord of the Rings series?',
#   'target': '¿Cuántos libros tiene la saga de El Señor de los Anillos?',
#   'entities': {'Q15228': {'es': 'El Señor de los Anillos',
#     'en': 'The Lord of the Rings'}},
#   'from': 'mintaka'},
#  {'id': '6fa28de6',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which United States territories are not states?',
#   'target': '¿Cuál territorio de los Estados Unidos no es un estado?',
#   'entities': {'Q30': {'es': 'Estados Unidos',
#     'en': 'United States of America'}},
#   'from': 'mintaka'},
#  {'id': '3e4c447d',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who was the last Czar of Russia?',
#   'target': '¿Quién fue el último zar de Rusia?',
#   'entities': {'Q159': {'es': 'Rusia', 'en': 'Russia'}},
#   'from': 'mintaka'},
#  {'id': '5c81fef0',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Is C.S. Lewis a British author?',
#   'target': '¿C.S. Lewis es un autor británico?',
#   'entities': {'Q842438': {'es': 'británicos', 'en': 'Britons'}},
#   'from': 'mintaka'},
#  {'id': 'c8a8b965',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What was the first Smash Bros game to include Princess Peach?',
#   'target': '¿Cuál fue el primer juego de Smash Bros en incluir a la Princesa Peach?',
#   'entities': {'Q507001': {'es': 'Princesa Peach', 'en': 'Princess Peach'}},
#   'from': 'mintaka'},
#  {'id': '17207392',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Was George Washington the first president of the United States?',
#   'target': '¿George Washington fue el primer presidente de los Estados Unidos?',
#   'entities': {'Q30': {'es': 'Estados Unidos',
#     'en': 'United States of America'}},
#   'from': 'mintaka'},
#  {'id': '61b16812',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who is a current senator of New York and was born in 1950?',
#   'target': '¿Quién es senador de Nueva York en la actualidad y nació en 1950?',
#   'entities': {'Q1384': {'es': 'Nueva York', 'en': 'New York'}},
#   'from': 'mintaka'},
#  {'id': '26b65c8b',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What archaeological site in Mexico was made one of the New Seven Wonders of the World in 2007?',
#   'target': '¿Qué sitio arqueológico en México fue nominado como una de las nuevas siete maravillas del mundo en 2007?',
#   'entities': {'Q96': {'es': 'México', 'en': 'Mexico'}},
#   'from': 'mintaka'},
#  {'id': '5fadb2a4',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'How many major rivers are there in Africa?',
#   'target': '¿Cuántos ríos mayores hay en África?',
#   'entities': {'Q15': {'es': 'África', 'en': 'Africa'}},
#   'from': 'mintaka'},
#  {'id': '8fa47086',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'How many states are next to the Pacific Ocean?',
#   'target': '¿Cuántos estados se localizan junto al océano Pacífico?',
#   'entities': {'Q98': {'es': 'océano Pacífico', 'en': 'Pacific Ocean'}},
#   'from': 'mintaka'},
#  {'id': '8c663edf',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Does the Philippines consist of more than 7,000 islands?',
#   'target': '¿Se compone Filipinas de más de 7000 islas?',
#   'entities': {'Q928': {'es': 'Filipinas', 'en': 'Philippines'}},
#   'from': 'mintaka'},
#  {'id': '9b586b9c',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What mountain chain is in France and Italy?',
#   'target': '¿Qué cadena montañosa está en Francia y en Italia?',
#   'entities': {'Q142': {'es': 'Francia', 'en': 'France'},
#    'Q38': {'es': 'Italia', 'en': 'Italy'}},
#   'from': 'mintaka'},
#  {'id': '8dfebfdb',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who is the 3rd president of the United States?',
#   'target': '¿Quién fue el tercer presidente de los Estados Unidos?',
#   'entities': {'Q30': {'es': 'Estados Unidos',
#     'en': 'United States of America'}},
#   'from': 'mintaka'},
#  {'id': '6166828d',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which member of The Wu-Tang Clan passed away in New York City, New York?',
#   'target': '¿Qué miembro de The Wu-Tang Clan falleció en la ciudad de Nueva York, Nueva York?',
#   'entities': {'Q60': {'es': 'Nueva York', 'en': 'New York City'}},
#   'from': 'mintaka'},
#  {'id': 'a2133be6',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Is One Hundred Years of Solitude written by Gabriel Garcia Marquez?',
#   'target': '¿Gabriel García Márquez escribió Cien años de soledad?',
#   'entities': {'Q178869': {'es': 'Cien años de soledad',
#     'en': 'One Hundred Years of Solitude'}},
#   'from': 'mintaka'},
#  {'id': '236462cc',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which state has more electoral votes, Colorado or Utah?',
#   'target': '¿Qué estado tiene más votos electorales, Colorado o Utha?',
#   'entities': {'Q829': {'es': 'Utah', 'en': 'Utah'}},
#   'from': 'mintaka'},
#  {'id': '2b2c4f25',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What was the year in which the lover of Marc Anthony and ruler of Egypt died?',
#   'target': '¿En qué año falleció la amante de Marco Antonio y gobernante de Egipto?',
#   'entities': {'Q79': {'es': 'Egipto', 'en': 'Egypt'}},
#   'from': 'mintaka'},
#  {'id': '0f328387',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What US state was the 26th president of the United States born in?',
#   'target': '¿En qué estado nació el presidente 26º de los Estados Unidos?',
#   'entities': {'Q30': {'es': 'Estados Unidos',
#     'en': 'United States of America'}},
#   'from': 'mintaka'},
#  {'id': '354852c6',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who defeated the Ottoman Empire?',
#   'target': '¿Quién derrotó al imperio otomano?',
#   'entities': {'Q12560': {'es': 'Imperio otomano', 'en': 'Ottoman Empire'}},
#   'from': 'mintaka'},
#  {'id': 'b4d0974d',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What ancient civilization built Chichen Itza?',
#   'target': '¿Qué civilización antigua construyó Chichén Itzá?',
#   'entities': {'Q5859': {'es': 'Chichén Itzá', 'en': 'Chichen Itza'}},
#   'from': 'mintaka'},
#  {'id': '94f453a0',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What Song of Ice and Fire books is Eddard Stark not in?',
#   'target': '¿En cuáles de los libros de Canción de Hielo y Fuego no aparece Eddard Stark?',
#   'entities': {'Q45875': {'es': 'Canción de hielo y fuego',
#     'en': 'A Song of Ice and Fire'}},
#   'from': 'mintaka'},
#  {'id': '52968a44',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What year was Julius Caesar born?',
#   'target': '¿En qué año nació Julio César?',
#   'entities': {'Q1048': {'es': 'Julio César', 'en': 'Julius Caesar'}},
#   'from': 'mintaka'},
#  {'id': 'c0e21f85',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who was the last emperor of Japan?',
#   'target': '¿Quién fue el último emperador de Japón?',
#   'entities': {'Q17': {'es': 'Japón', 'en': 'Japan'}},
#   'from': 'mintaka'},
#  {'id': 'a4e340d1',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who is the former president of the United States and starred in the 1942 movie Kings Row?',
#   'target': '¿Quién es el expresidente de los Estados Unidos y protagonizó la película Abismo de Pasión de 1942?',
#   'entities': {'Q30': {'es': 'Estados Unidos',
#     'en': 'United States of America'}},
#   'from': 'mintaka'},
#  {'id': '07913cf6',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Operation Barbarossa was the code name for the German invasion of what country?',
#   'target': '¿Operación barbarossa fue el nombre código para la invasión alemana de qué país?',
#   'entities': {'Q183': {'es': 'Alemania', 'en': 'Germany'}},
#   'from': 'mintaka'},
#  {'id': 'eb45e07c',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What year was Canada formed?',
#   'target': '¿En qué año se formó Canadá?',
#   'entities': {'Q16': {'es': 'Canadá', 'en': 'Canada'}},
#   'from': 'mintaka'},
#  {'id': '575f43d0',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What country was part of the Allied Powers in WW II and was made up of 15 republics?',
#   'target': '¿Qué país fue parte de los Aliados en la Segunda Guerra Mundial y estaba constituido por 15 repúblicas?',
#   'entities': {'Q362': {'es': 'Segunda Guerra Mundial', 'en': 'World War II'}},
#   'from': 'mintaka'},
#  {'id': '55e7694a',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which country has a larger population, Pakistan or Brazil?',
#   'target': '¿Qué país tiene población más grande? ¿Paquistán o Brasil?',
#   'entities': {'Q155': {'es': 'Brasil', 'en': 'Brazil'}},
#   'from': 'mintaka'},
#  {'id': 'db319851',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': "Who directed the movie that's based on the first of the Lord of Rings book?",
#   'target': '¿Quién dirigió la película basada en el primer libro de El señor de los anillos?',
#   'entities': {'Q15228': {'es': 'El Señor de los Anillos',
#     'en': 'The Lord of the Rings'}},
#   'from': 'mintaka'},
#  {'id': '990c63bd',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who was the leader of the country that invaded Russia in 1812?',
#   'target': '¿Quién fue el líder del país que invadió Rusia en 1812?',
#   'entities': {'Q159': {'es': 'Rusia', 'en': 'Russia'}},
#   'from': 'mintaka'},
#  {'id': '0db78efa',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'The Eiffel Tower can be found in which European capital city?',
#   'target': '¿En qué ciudad y capital europea se encuentra la Torre Eiffel?',
#   'entities': {'Q243': {'es': 'Torre Eiffel', 'en': 'Eiffel Tower'}},
#   'from': 'mintaka'},
#  {'id': '765aba50',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which Lord of the Rings trilogy books do not feature Shelob the giant spider?',
#   'target': '¿Cuáles libros de la trilogía del Señor de los Anillos no contienen a Shelob, la araña gigante?',
#   'entities': {'Q15228': {'es': 'El Señor de los Anillos',
#     'en': 'The Lord of the Rings'}},
#   'from': 'mintaka'},
#  {'id': 'f95b3164',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Has there ever been a female president of the United States?',
#   'target': '¿Alguna vez ha habido una presidenta mujer en los Estados Unidos?',
#   'entities': {'Q30': {'es': 'Estados Unidos',
#     'en': 'United States of America'}},
#   'from': 'mintaka'},
#  {'id': '661a6cf0',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who was the queen of France and also born an archduchess of Austria?',
#   'target': '¿Quién fue la reina de Francia que también nació archiduquesa de Austria?',
#   'entities': {'Q142': {'es': 'Francia', 'en': 'France'}},
#   'from': 'mintaka'},
#  {'id': '3f0bc8bf',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who discovered America first, Amerigo Vespucci or Christopher Columbus?',
#   'target': '¿Quién descubrió América primero: Américo Vespucio o Cristóbal Colón?',
#   'entities': {'Q7322': {'es': 'Cristóbal Colón',
#     'en': 'Christopher Columbus'}},
#   'from': 'mintaka'},
#  {'id': '8238952f',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which is the longest Chronicles of Narnia book?',
#   'target': '¿Cuál es el libro más largo de Las Crónicas de Narnia?',
#   'entities': {'Q483412': {'es': 'Las Crónicas de Narnia',
#     'en': 'The Chronicles of Narnia'}},
#   'from': 'mintaka'},
#  {'id': '8cbbd3d0',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which state is second largest by area and home to the 43rd president of the U.S.?',
#   'target': '¿Cuál es el segundo estado más grande y el hogar del presidente 43º de los Estados Unidos?',
#   'entities': {'Q30': {'es': 'Estados Unidos',
#     'en': 'United States of America'}},
#   'from': 'mintaka'},
#  {'id': 'cd8f5fdd',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who is the governor of New York?',
#   'target': '¿Quién es el gobernador de Nueva York?',
#   'entities': {'Q1384': {'es': 'Nueva York', 'en': 'New York'}},
#   'from': 'mintaka'},
#  {'id': '486b60ea',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Is California the capital of the United States?',
#   'target': '¿Es California la capital de los Estados Unidos?',
#   'entities': {'Q30': {'es': 'Estados Unidos',
#     'en': 'United States of America'}},
#   'from': 'mintaka'},
#  {'id': 'dc2e80b8',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which Roman emperor constructed a wall across Great Britain in the second century AD?',
#   'target': '¿Qué emperador romano construyó un muro en Gran Bretaña en el siglo II a.C.?',
#   'entities': {'Q23666': {'es': 'Gran Bretaña', 'en': 'Great Britain'}},
#   'from': 'mintaka'},
#  {'id': 'bd58b696',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who served in WW I for Imperial Germany and later became dictator of the same country?',
#   'target': '¿Quién estuvo a cargo del Imperio alemán durante la Primera Guerra Mundial y luego se convirtió en el dictador de ese mismo país?',
#   'entities': {'Q361': {'es': 'Primera Guerra Mundial', 'en': 'World War I'}},
#   'from': 'mintaka'},
#  {'id': '1ba6e4ea',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who united Greece?',
#   'target': '¿Quién unió a Grecia?',
# ...
#   'target': '¿Quién fue el padre del 30o presidente de Estados Unidos?',
#   'entities': {'Q30': {'es': 'Estados Unidos',
#     'en': 'United States of America'}},
#   'from': 'mintaka'},
#  {'id': 'dbd09037',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which US state has been the birthplace of the most presidents of the United States?',
#   'target': '¿En qué estado de Estados Unidos nacieron la mayoría de los presidentes?',
#   'entities': {'Q30': {'es': 'Estados Unidos',
#     'en': 'United States of America'}},
#   'from': 'mintaka'},
#  {'id': 'dd5a010a',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What is the shortest river in the United States?',
#   'target': '¿Cuál es el río más corto de Estados Unidos?',
#   'entities': {'Q30': {'es': 'Estados Unidos',
#     'en': 'United States of America'}},
#   'from': 'mintaka'},
#  {'id': '8a46fa92',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'How many states does the United Kingdom have?',
#   'target': '¿Cuántos estados tiene el Reino Unido?',
#   'entities': {'Q145': {'es': 'Reino Unido', 'en': 'United Kingdom'}},
#   'from': 'mintaka'},
#  {'id': '68b39779',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Did Lionel Messi win a cup with his national team this year?',
#   'target': '¿Leonel Messi ganó alguna copa con su selección nacional este año?',
#   'entities': {'Q615': {'es': 'Lionel Messi', 'en': 'Lionel Messi'}},
#   'from': 'mintaka'},
#  {'id': 'c53646eb',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'How many presidents of the United States were actors before they were in office?',
#   'target': '¿Cuántos presidentes de los Estados Unidos han sido actores antes de asumir al cargo?',
#   'entities': {'Q30': {'es': 'Estados Unidos',
#     'en': 'United States of America'}},
#   'from': 'mintaka'},
#  {'id': '603bafa9',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who was the shortest serving prime minister of Canada?',
#   'target': '¿Qué primer ministro de Canadá estuvo en funciones durante menos tiempo?',
#   'entities': {'Q16': {'es': 'Canadá', 'en': 'Canada'}},
#   'from': 'mintaka'},
#  {'id': 'b5cdbdf2',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who was the tenth vice president of the United States?',
#   'target': '¿Quién fue el décimo presidente de Estados Unidos?',
#   'entities': {'Q30': {'es': 'Estados Unidos',
#     'en': 'United States of America'}},
#   'from': 'mintaka'},
#  {'id': 'dc5887f1',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'In 1942 during World War II, what United States operation occurred from March 9th to March 10th in the Pacific theater?',
#   'target': '¿En 1942, durante la Segunda Guerra Mundial, qué operación se llevó a cabo de marzo 9 al 10 en el teatro del Pacífico?',
#   'entities': {'Q362': {'es': 'Segunda Guerra Mundial', 'en': 'World War II'}},
#   'from': 'mintaka'},
#  {'id': '4437442c',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': "What was Margaret Atwood's first novel?",
#   'target': '¿Cuál fue la primera novela de Margaret Atwod?',
#   'entities': {'Q183492': {'es': 'Margaret Atwood', 'en': 'Margaret Atwood'}},
#   'from': 'mintaka'},
#  {'id': 'b93731b4',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who was the first ruler of Egypt during the Ptolemaic period?',
#   'target': '¿Quién fue el primer gobernante de Egipto durante el período ptolemaico?',
#   'entities': {'Q79': {'es': 'Egipto', 'en': 'Egypt'}},
#   'from': 'mintaka'},
#  {'id': '562efa7f',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'How many Americans served in WW II?',
#   'target': '¿Cuántos norteamericanos lucharon en la Segunda Guerra Mundial?',
#   'entities': {'Q362': {'es': 'Segunda Guerra Mundial', 'en': 'World War II'}},
#   'from': 'mintaka'},
#  {'id': 'dfb7e530',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What year was the author who wrote the Lord of the Rings series born?',
#   'target': '¿En qué año nació el autor que escribió la serie El Señor de los Anillos?',
#   'entities': {'Q15228': {'es': 'El Señor de los Anillos',
#     'en': 'The Lord of the Rings'}},
#   'from': 'mintaka'},
#  {'id': '27c7f25d',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Does the cherry come before the strawberry in Pac-Man?',
#   'target': '¿En el Pacman, la cereza viene antes de la fresa?',
#   'entities': {'Q173626': {'es': 'Pac-Man', 'en': 'Pac-Man'}},
#   'from': 'mintaka'},
#  {'id': '9078fd23',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Did America enter World War II before or after the Japanese bombed Pearl Harbor?',
#   'target': '¿América participó en la Segunda Guerra Mundial después de que los japoneses bombardearon Pearl Harbor?',
#   'entities': {'Q362': {'es': 'Segunda Guerra Mundial', 'en': 'World War II'},
#    'Q17': {'es': 'Japón', 'en': 'Japan'}},
#   'from': 'mintaka'},
#  {'id': '378a5af0',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which series sold more books, Twilight or Harry potter?',
#   'target': '¿Qué serie de libros vendió más ejemplares, Crepúsculo o Harry Potter?',
#   'entities': {'Q44523': {'es': 'Crepúsculo', 'en': 'Twilight'}},
#   'from': 'mintaka'},
#  {'id': '944c6d00',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which Judas Priest singer was American?',
#   'target': '¿Qué cantante de Judas Priest era estadounidense?',
#   'entities': {'Q846570': {'es': 'Estadounidense', 'en': 'Americans'}},
#   'from': 'mintaka'},
#  {'id': '91b8fc8c',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What is the nationality of the male world record holder in the 100 meter breaststroke?',
#   'target': '¿De qué nacionalidad es el atleta que tiene el récord mundial masculino en 100m pecho?',
#   'entities': {'Q6581097': {'es': 'masculino', 'en': 'male'}},
#   'from': 'mintaka'},
#  {'id': 'df5907b3',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Was Bill Clinton elected president after Barack Obama?',
#   'target': '¿Bill linton fue elegido presidente después de Barack Obama?',
#   'entities': {'Q1124': {'es': 'Bill Clinton', 'en': 'Bill Clinton'}},
#   'from': 'mintaka'},
#  {'id': '0217671e',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Does LeBron James play for the Los Angeles Lakers?',
#   'target': '¿Lebron James juega para Los Ángeles Lakers?',
#   'entities': {'Q121783': {'es': 'Los Angels Lakers',
#     'en': 'Los Angeles Lakers'}},
#   'from': 'mintaka'},
#  {'id': 'f9aa6540',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What was the first Twilight movie chronologically?',
#   'target': 'En orden cronológico, ¿cuál fue la primera película de Crepúsculo?',
#   'entities': {'Q44523': {'es': 'Crepúsculo', 'en': 'Twilight'}},
#   'from': 'mintaka'},
#  {'id': '9e966d9e',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': "How many times has Germany won the men's World Cup?",
#   'target': '¿Cuántas veces ha ganado Alemania la copa mundial masculina?',
#   'entities': {'Q183': {'es': 'Alemania', 'en': 'Germany'}},
#   'from': 'mintaka'},
#  {'id': '781f9c07',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What is the largest country in Africa by land mass?',
#   'target': '¿Cuál es el país más grande en África en base a territorio?',
#   'entities': {'Q15': {'es': 'África', 'en': 'Africa'}},
#   'from': 'mintaka'},
#  {'id': '84c5405b',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which oceans do not border Russia?',
#   'target': '¿Qué océanos no comparten frontera con Rusia?',
#   'entities': {'Q159': {'es': 'Rusia', 'en': 'Russia'}},
#   'from': 'mintaka'},
#  {'id': '903b74bb',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What river flows through Brazil and is the longest river in South America?',
#   'target': '¿Qué río pasa por Brasil y es el más largo en Sudamérica?',
#   'entities': {'Q155': {'es': 'Brasil', 'en': 'Brazil'}},
#   'from': 'mintaka'},
#  {'id': '6d79e58a',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which country has a larger population, France or Spain?',
#   'target': '¿Qué país tiene una mayor población, Francia o España?',
#   'entities': {'Q142': {'es': 'Francia', 'en': 'France'},
#    'Q29': {'es': 'España', 'en': 'Spain'}},
#   'from': 'mintaka'},
#  {'id': '098fa6a9',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'How many principal pyramids are in Egypt?',
#   'target': '¿Cuántas pirámides principales hay en Egipto?',
#   'entities': {'Q79': {'es': 'Egipto', 'en': 'Egypt'}},
#   'from': 'mintaka'},
#  {'id': 'c8ca668f',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What is the deepest lake in Russia?',
#   'target': '¿Cuál es el lago más profundo de Rusia?',
#   'entities': {'Q159': {'es': 'Rusia', 'en': 'Russia'}},
#   'from': 'mintaka'},
#  {'id': '23c90d2d',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'How many active volcanoes are in Hawaii?',
#   'target': '¿Cuántos volcanes activos hay en Hawái?',
#   'entities': {'Q782': {'es': 'Hawái', 'en': 'Hawaii'}},
#   'from': 'mintaka'},
#  {'id': '5ae2e94e',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What US president made history by becoming the first sitting US president to declare Jerusalem as the capital of Israel?',
#   'target': '¿Qué presidente de EE. UU. hizo historia cuando llegó a ser el primer presidente de EE. UU. en ejercicio que declaró a Jerusalén como la capital de Israel?',
#   'entities': {'Q1218': {'es': 'Jerusalén', 'en': 'Jerusalem'}},
#   'from': 'mintaka'},
#  {'id': '6db6ee80',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which series has more books, Stalking Jack the Ripper or Lord of the Rings?',
#   'target': '¿Cuál saga tiene más libros, A la caza de Jack el Destripador o El señor de los anillos?',
#   'entities': {'Q15228': {'es': 'El Señor de los Anillos',
#     'en': 'The Lord of the Rings'}},
#   'from': 'mintaka'},
#  {'id': 'b9150f60',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who was the first vice president of the United States?',
#   'target': '¿Quién fue el primer vicepresidente de Estados Unidos?',
#   'entities': {'Q30': {'es': 'Estados Unidos',
#     'en': 'United States of America'}},
#   'from': 'mintaka'},
#  {'id': '53a57baf',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Was Donald Trump the governor of New York previous to becoming U.S. president?',
#   'target': '¿Fue Donald Trump gobernador de Nueva York antes de convertirse en presidente de los EE. UU.?',
#   'entities': {'Q1384': {'es': 'Nueva York', 'en': 'New York'}},
#   'from': 'mintaka'},
#  {'id': '13bce9c4',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Was Christopher Columbus married?',
#   'target': '¿Cristóbal Colón estaba casado?',
#   'entities': {'Q7322': {'es': 'Cristóbal Colón',
#     'en': 'Christopher Columbus'}},
#   'from': 'mintaka'},
#  {'id': 'ecfd471d',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'As of 2015, which group held the record for the most Grammy Awards of any group in history?',
#   'target': '¿A partir de 2015, qué grupo tiene el récord de premios Grammy de todos los grupos de la historia?',
#   'entities': {'Q41254': {'es': 'premios Grammy', 'en': 'Grammy Award'}},
#   'from': 'mintaka'},
#  {'id': 'a63ceced',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'How old was the 40th president of the United States before he died?',
#   'target': '¿Qué edad tenía el 40º presidente de Estados Unidos antes de morir?',
#   'entities': {'Q30': {'es': 'Estados Unidos',
#     'en': 'United States of America'}},
#   'from': 'mintaka'},
#  {'id': '9ec50e04',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Is Rome the capital of China?',
#   'target': '¿Roma es la capital de China?',
#   'entities': {'Q220': {'es': 'Roma', 'en': 'Rome'}},
#   'from': 'mintaka'},
#  {'id': 'a2836aff',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who is the first child of the 44th president of the United States?',
#   'target': '¿Quién es el primer hijo del 44º presidente de Estados Unidos?',
#   'entities': {'Q30': {'es': 'Estados Unidos',
#     'en': 'United States of America'}},
#   'from': 'mintaka'},
#  {'id': 'c27755e6',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who was an Attorney General of the United States and also assassinated?',
#   'target': '¿Quién era abogado general de Estados Unidos y también fue asesinado?',
#   'entities': {'Q30': {'es': 'Estados Unidos',
#     'en': 'United States of America'}},
#   'from': 'mintaka'},
#  {'id': '3c727839',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'How many times has the actress Bella from Twilight been married?',
#   'target': '¿Cuántas veces se casó la actriz Bella de Crepúsculo?',
#   'entities': {'Q160071': {'es': 'Crepúsculo', 'en': 'Twilight'}},
#   'from': 'mintaka'},
#  {'id': '2f9f7225',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which country is larger in size, Russia or Canada?',
#   'target': '¿Qué país es mayor en superficie, Rusia o Canadá?',
#   'entities': {'Q159': {'es': 'Rusia', 'en': 'Russia'},
#    'Q16': {'es': 'Canadá', 'en': 'Canada'}},
#   'from': 'mintaka'},
#  {'id': '8efc069f',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What is the 4th longest river in North America?',
#   'target': '¿Cuál es el cuarto río más largo en América del Norte?',
#   'entities': {'Q49': {'es': 'América del Norte', 'en': 'North America'}},
#   'from': 'mintaka'},
#  {'id': '5c475704',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which Confederate general fought in the Battle for Gettysburg in 1863, but did not win?',
#   'target': '¿Qué General confederado combatió en la batalla de Gettysburg en 1863, pero no ganó?',
#   'entities': {'Q33132': {'es': 'Batalla de Gettysburg',
#     'en': 'Battle of Gettysburg'}},
#   'from': 'mintaka'},
#  {'id': 'fe0786f8',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who is the governor of New Jersey?',
#   'target': '¿Quién es el gobernador de Nueva Jersey?',
#   'entities': {'Q1408': {'es': 'Nueva Jersey', 'en': 'New Jersey'}},
#   'from': 'mintaka'},
#  {'id': '6a750d5e',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which state has more electoral votes, Virginia or West Virginia?',
#   'target': '¿Qué estado cuenta con más votos electorales, Virginia o Virginia Occidental?',
#   'entities': {'Q1371': {'es': 'Virginia Occidental', 'en': 'West Virginia'}},
#   'from': 'mintaka'},
#  {'id': '7c586891',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who was the wife of the last king of France?',
#   'target': '¿Quién fue la esposa del último rey de Francia?',
#   'entities': {'Q142': {'es': 'Francia', 'en': 'France'}},
#   'from': 'mintaka'},
#  {'id': '13d4e828',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What year did NSYNC form?',
#   'target': '¿En qué año se formó N Sync?',
#   'entities': {'Q154454': {'es': 'NSYNC', 'en': 'NSYNC'}},
#   'from': 'mintaka'},
#  {'id': '494fd927',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which war lasted longer, Vietnam War or Korean War?',
#   'target': '¿Qué guerra duró más tiempo, la guerra de Vietnam o la de Corea?',
#   'entities': {'Q8740': {'es': 'Guerra de Vietnam', 'en': 'Vietnam War'}},
#   'from': 'mintaka'},
#  {'id': '97d738cb',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who is the WW II era Soviet leader that was born to a poor family in Gori?',
#   'target': '¿Quién es el líder soviético de la Segunda Guerra Mundial que nació en una familia pobre de Gori?',
#   'entities': {'Q362': {'es': 'Segunda Guerra Mundial', 'en': 'World War II'}},
#   'from': 'mintaka'},
#  {'id': 'cc3037c7',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which war caused the most deaths, World War I or II?',
#   'target': '¿Qué guerra causó más muertes, la Primera o la Segunda Guerra Mundial?',
#   'entities': {'Q362': {'es': 'Segunda Guerra Mundial', 'en': 'World War II'}},
#   'from': 'mintaka'}]

# %%
print("Loading SpanMarker model...")
spanmarker_model = SpanMarkerModel.from_pretrained("tomaarsen/span-marker-mbert-base-multinerd")
ensure_pad_token(spanmarker_model)
# Out:
# Loading SpanMarker model...
# The new embeddings will be initialized from a multivariate normal distribution that has old embeddings' mean and covariance. As described in this article: https://nlp.stanford.edu/~johnhew/vocab-expansion.html. To disable this, use `mean_resizing=False`

# %%
print("Loading M2M100 translation model...")
m2m_model = M2M100ForConditionalGeneration.from_pretrained("facebook/m2m100_418M")
m2m_tokenizer = M2M100Tokenizer.from_pretrained("facebook/m2m100_418M")
# Out:
# Loading M2M100 translation model...

# %%
translated_sentences = []

for idx, entry in enumerate(spanish_data):  # Process only the first 10 entries

    # Get source text (English) and target text (Italian)
    eng_text = entry['source']
    esp_text = entry['target']

    # Mask entities in the English text
    masked_eng_text, mapping = mask_entities_with_spanmarker(eng_text, spanmarker_model)
    print(f"Masked English Text: {masked_eng_text}")
    print(f"Entity Mapping: {json.dumps(mapping, indent=4)}")

    # # Filter entities by confidence score
    # filtered_mapping = {
    #     key: value for key, value in mapping.items() if value["confidence"] > 0.8
    # }
    # print(f"Filtered Mapping (Confidence > 0.8): {json.dumps(filtered_mapping, indent=4)}")

    # Translate non-entity parts of the text
    m2m_tokenizer.src_lang = "en"
    tgt_lang = "it"
    translated_text_with_placeholders = translate_with_placeholders_m2m(
        masked_eng_text, mapping, src_lang="en", tgt_lang="es"
    )
    print(f"Translated Text with Placeholders: {translated_text_with_placeholders}")

    # Reintegrate entities into the translated text
    final_translation = reintegrate_entities(
        translated_text_with_placeholders, mapping, src_lang="en", tgt_lang="es"
    )
    print(f"Final Translation: {final_translation}")

    # Append final translation to the results
    translated_sentences.append({
        "id": entry["id"],
        "source": eng_text,
        "target": esp_text,
        "masked_source": masked_eng_text,
        "translation": final_translation,
        "mapping": mapping
    })

# Save the results
results_path = "data/translated_spanish_test.json"
with open(results_path, "w") as results_file:
    json.dump(translated_sentences, results_file, indent=4)

print(f"Translation results for test set saved to {results_path}")
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Masked English Text: What is the largest park in the capital city of the [ENTITY_LOC_1]?
# Entity Mapping: {
#     "[ENTITY_LOC_1]": {
#         "original_text": "UK",
#         "type": "LOC",
#         "confidence": 0.9993182420730591,
#         "start": 52,
#         "end": 54
#     }
# }
# Filtered Mapping (Confidence > 0.8): {
#     "[ENTITY_LOC_1]": {
#         "original_text": "UK",
#         "type": "LOC",
#         "confidence": 0.9993182420730591,
#         "start": 52,
#         "end": 54
#     }
# }
# Translated Text with Placeholders: ¿Cuál es el parque más grande en la ciudad capital de [ENTITY_LOC_1]?
# Final Translation: ¿Cuál es el parque más grande en la ciudad capital de Reino Unido?
# Masked English Text: Which Twilight books did not include the character [ENTITY_PER_1]?
# Entity Mapping: {
#     "[ENTITY_PER_1]": {
#         "original_text": "Renesmee",
#         "type": "PER",
#         "confidence": 0.33614975214004517,
#         "start": 51,
#         "end": 59
#     }
# }
# Filtered Mapping (Confidence > 0.8): {}
# Translated Text with Placeholders: ¿Qué libros de Twilight no incluyeron el personaje [ENTITY_PER_1]?
# Final Translation: ¿Qué libros de Twilight no incluyeron el personaje [ENTITY_PER_1]?
# Masked English Text: What is the third smallest country in [ENTITY_LOC_1]?
# Entity Mapping: {
#     "[ENTITY_LOC_1]": {
#         "original_text": "Africa",
#         "type": "LOC",
#         "confidence": 0.9999145269393921,
#         "start": 38,
#         "end": 44
#     }
# }
# Filtered Mapping (Confidence > 0.8): {
#     "[ENTITY_LOC_1]": {
#         "original_text": "Africa",
#         "type": "LOC",
#         "confidence": 0.9999145269393921,
#         "start": 38,
#         "end": 44
#     }
# }
# Translated Text with Placeholders: ¿Cuál es el tercer país más pequeño en [ENTITY_LOC_1]?
# Final Translation: ¿Cuál es el tercer país más pequeño en África?
# Masked English Text: Where was the first all-woman city council in the [ENTITY_LOC_1]?
# Entity Mapping: {
#     "[ENTITY_LOC_1]": {
#         "original_text": "United States",
#         "type": "LOC",
#         "confidence": 0.9999184608459473,
#         "start": 50,
#         "end": 63
#     }
# }
# Filtered Mapping (Confidence > 0.8): {
#     "[ENTITY_LOC_1]": {
#         "original_text": "United States",
#         "type": "LOC",
#         "confidence": 0.9999184608459473,
#         "start": 50,
#         "end": 63
#     }
# }
# Translated Text with Placeholders: ¿Dónde fue el primer consejo de la ciudad de todas las mujeres en la [ENTITY_LOC_1]?
# Final Translation: ¿Dónde fue el primer consejo de la ciudad de todas las mujeres en la Estados Unidos?
# Masked English Text: What is the population of the most populous country in [ENTITY_LOC_1]?
# Entity Mapping: {
#     "[ENTITY_LOC_1]": {
#         "original_text": "South America",
#         "type": "LOC",
#         "confidence": 0.9999457597732544,
#         "start": 55,
#         "end": 68
#     }
# }
# Filtered Mapping (Confidence > 0.8): {
#     "[ENTITY_LOC_1]": {
#         "original_text": "South America",
#         "type": "LOC",
#         "confidence": 0.9999457597732544,
#         "start": 55,
#         "end": 68
#     }
# }
# Translated Text with Placeholders: ¿Cuál es la población del país más poblado en [ENTITY_LOC_1]?
# Final Translation: ¿Cuál es la población del país más poblado en Sudamérica?
# Masked English Text: How many Supreme Leaders of [ENTITY_LOC_1] have there been?
# Entity Mapping: {
#     "[ENTITY_LOC_1]": {
#         "original_text": "North Korea",
#         "type": "LOC",
#         "confidence": 0.9996556043624878,
#         "start": 28,
#         "end": 39
#     }
# }
# Filtered Mapping (Confidence > 0.8): {
#     "[ENTITY_LOC_1]": {
#         "original_text": "North Korea",
#         "type": "LOC",
#         "confidence": 0.9996556043624878,
#         "start": 28,
#         "end": 39
#     }
# }
# Translated Text with Placeholders: ¿Cuántos líderes superiores de [ENTITY_LOC_1] han existido?
# Final Translation: ¿Cuántos líderes superiores de Corea del Norte han existido?
# Masked English Text: Who became the president of [ENTITY_LOC_1] on 1 July 1994?
# Entity Mapping: {
#     "[ENTITY_LOC_1]": {
#         "original_text": "Germany",
#         "type": "LOC",
#         "confidence": 0.9999053478240967,
#         "start": 28,
#         "end": 35
#     }
# }
# Filtered Mapping (Confidence > 0.8): {
#     "[ENTITY_LOC_1]": {
#         "original_text": "Germany",
#         "type": "LOC",
#         "confidence": 0.9999053478240967,
#         "start": 28,
#         "end": 35
#     }
# }
# Translated Text with Placeholders: ¿Quién fue presidente de [ENTITY_LOC_1] el 1 de julio de 1994?
# Final Translation: ¿Quién fue presidente de Alemania el 1 de julio de 1994?
# Masked English Text: What is the largest city in [ENTITY_LOC_1] by population?
# Entity Mapping: {
#     "[ENTITY_LOC_1]": {
#         "original_text": "England",
#         "type": "LOC",
#         "confidence": 0.9999372959136963,
#         "start": 28,
#         "end": 35
#     }
# }
# Filtered Mapping (Confidence > 0.8): {
#     "[ENTITY_LOC_1]": {
#         "original_text": "England",
#         "type": "LOC",
#         "confidence": 0.9999372959136963,
#         "start": 28,
#         "end": 35
#     }
# }
# Translated Text with Placeholders: ¿Cuál es la ciudad más grande en [ENTITY_LOC_1] por población?
# Final Translation: ¿Cuál es la ciudad más grande en Inglaterra por población?
# No entities found for text: Who is the oldest pitcher to throw a no-hitter?
# Masked English Text: Who is the oldest pitcher to throw a no-hitter?
# Entity Mapping: {}
# Filtered Mapping (Confidence > 0.8): {}
# Translated Text with Placeholders: ¿Quién es el pitcher más antiguo para lanzar un no-hitter?
# Final Translation: ¿Quién es el pitcher más antiguo para lanzar un no-hitter?
# Masked English Text: Which was written first, [ENTITY_MEDIA_1] or Fear and Loathing on the Campaign Trail '72?
# Entity Mapping: {
#     "[ENTITY_MEDIA_1]": {
#         "original_text": "Fear and Loathing in Las Vegas",
#         "type": "MEDIA",
#         "confidence": 0.4930110573768616,
#         "start": 25,
#         "end": 55
#     }
# }
# Filtered Mapping (Confidence > 0.8): {}
# Translated Text with Placeholders: ¿Quién fue escrito primero, [ENTITY_MEDIA_1] o El miedo y el engaño en el Camino de Campaña '72?
# Final Translation: ¿Quién fue escrito primero, [ENTITY_MEDIA_1] o El miedo y el engaño en el Camino de Campaña '72?
# Masked English Text: Which main character in [ENTITY_MEDIA_1] was not a vampire or werewolf?
# Entity Mapping: {
#     "[ENTITY_MEDIA_1]": {
#         "original_text": "Twilight",
#         "type": "MEDIA",
#         "confidence": 0.9854694604873657,
#         "start": 24,
#         "end": 32
#     }
# }
# Filtered Mapping (Confidence > 0.8): {
#     "[ENTITY_MEDIA_1]": {
#         "original_text": "Twilight",
#         "type": "MEDIA",
#         "confidence": 0.9854694604873657,
#         "start": 24,
#         "end": 32
#     }
# }
# Translated Text with Placeholders: ¿Qué personaje principal en [ENTITY_MEDIA_1] no era un vampiro o serpiente?
# Final Translation: ¿Qué personaje principal en El Twilight no era un vampiro o serpiente?
# Masked English Text: Which war lasted longer, [ENTITY_EVE_1] or [ENTITY_EVE_2]?
# Entity Mapping: {
#     "[ENTITY_EVE_1]": {
#         "original_text": "Second Seminole War",
#         "type": "EVE",
#         "confidence": 0.9998520612716675,
#         "start": 25,
#         "end": 44
#     },
#     "[ENTITY_EVE_2]": {
#         "original_text": "World War II",
#         "type": "EVE",
#         "confidence": 0.9999513626098633,
#         "start": 43,
#         "end": 55
#     }
# }
# Filtered Mapping (Confidence > 0.8): {
#     "[ENTITY_EVE_1]": {
#         "original_text": "Second Seminole War",
#         "type": "EVE",
#         "confidence": 0.9998520612716675,
#         "start": 25,
#         "end": 44
#     },
#     "[ENTITY_EVE_2]": {
#         "original_text": "World War II",
#         "type": "EVE",
#         "confidence": 0.9999513626098633,
#         "start": 43,
#         "end": 55
#     }
# }
# Translated Text with Placeholders: ¿Qué guerra duró más tiempo, [ENTITY_EVE_1] o [ENTITY_EVE_2]?
# Final Translation: ¿Qué guerra duró más tiempo, Segunda Guerra Seminola o Segunda Guerra Mundial?
# No entities found for text: Who was the first pope?
# Masked English Text: Who was the first pope?
# Entity Mapping: {}
# Filtered Mapping (Confidence > 0.8): {}
# Translated Text with Placeholders: ¿Quién fue el primer Papa?
# Final Translation: ¿Quién fue el primer Papa?
# Masked English Text: What is the last book in the [ENTITY_MEDIA_1] series? 4?
# Entity Mapping: {
#     "[ENTITY_MEDIA_1]": {
#         "original_text": "Lord of the Rings",
#         "type": "MEDIA",
#         "confidence": 0.9935672879219055,
#         "start": 29,
#         "end": 46
#     }
# }
# Filtered Mapping (Confidence > 0.8): {
#     "[ENTITY_MEDIA_1]": {
#         "original_text": "Lord of the Rings",
#         "type": "MEDIA",
#         "confidence": 0.9935672879219055,
#         "start": 29,
#         "end": 46
#     }
# }
# Translated Text with Placeholders: ¿Cuál es el último libro en la serie [ENTITY_MEDIA_1]?
# Final Translation: ¿Cuál es el último libro en la serie Señor de los anillos?
# Masked English Text: Who is [ENTITY_PER_1]'s [ENTITY_ORG_1] challenger in the 2020 Kentucky Senate Elections?
# Entity Mapping: {
#     "[ENTITY_PER_1]": {
#         "original_text": "Mitch McConnell",
#         "type": "PER",
#         "confidence": 0.9999611377716064,
#         "start": 7,
#         "end": 22
#     },
#     "[ENTITY_ORG_1]": {
#         "original_text": "Democratic Party",
#         "type": "ORG",
#         "confidence": 0.9999420642852783,
#         "start": 24,
#         "end": 40
#     }
# }
# Filtered Mapping (Confidence > 0.8): {
#     "[ENTITY_PER_1]": {
#         "original_text": "Mitch McConnell",
#         "type": "PER",
#         "confidence": 0.9999611377716064,
#         "start": 7,
#         "end": 22
#     },
#     "[ENTITY_ORG_1]": {
#         "original_text": "Democratic Party",
#         "type": "ORG",
#         "confidence": 0.9999420642852783,
#         "start": 24,
#         "end": 40
#     }
# }
# Translated Text with Placeholders: ¿Quién es el desafío de [ENTITY_PER_1] en las elecciones del Senado de Kentucky 2020?
# Final Translation: ¿Quién es el desafío de de Mitch McConnell en las elecciones del Senado de Kentucky 2020?
# Masked English Text: Which actor was [ENTITY_PER_1]'s first choice to play [ENTITY_MEDIA_1] in the movie Twilight?
# Entity Mapping: {
#     "[ENTITY_PER_1]": {
#         "original_text": "Stephenie Meyer",
#         "type": "PER",
#         "confidence": 0.9999791383743286,
#         "start": 16,
#         "end": 31
#     },
#     "[ENTITY_MEDIA_1]": {
#         "original_text": "Edward Cullen",
#         "type": "MEDIA",
#         "confidence": 0.4770957827568054,
#         "start": 54,
#         "end": 67
#     }
# }
# Filtered Mapping (Confidence > 0.8): {
#     "[ENTITY_PER_1]": {
#         "original_text": "Stephenie Meyer",
#         "type": "PER",
#         "confidence": 0.9999791383743286,
#         "start": 16,
#         "end": 31
#     }
# }
# Translated Text with Placeholders: ¿Cuál fue la primera opción de [ENTITY_PER_1] para interpretar [ENTITY_MEDIA_1] en la película Twilight?
# Final Translation: ¿Cuál fue la primera opción de de Stephenie Meyer para interpretar [ENTITY_MEDIA_1] en la película Twilight?
# Masked English Text: Which country has a more dense population, [ENTITY_LOC_1] or the [ENTITY_LOC_2]?
# Entity Mapping: {
#     "[ENTITY_LOC_1]": {
#         "original_text": "Canada",
#         "type": "LOC",
#         "confidence": 0.9999648332595825,
#         "start": 43,
#         "end": 49
#     },
#     "[ENTITY_LOC_2]": {
#         "original_text": "United States",
#         "type": "LOC",
#         "confidence": 0.9999004602432251,
#         "start": 65,
#         "end": 78
#     }
# }
# Filtered Mapping (Confidence > 0.8): {
#     "[ENTITY_LOC_1]": {
#         "original_text": "Canada",
#         "type": "LOC",
#         "confidence": 0.9999648332595825,
#         "start": 43,
#         "end": 49
#     },
#     "[ENTITY_LOC_2]": {
#         "original_text": "United States",
#         "type": "LOC",
#         "confidence": 0.9999004602432251,
#         "start": 65,
#         "end": 78
#     }
# }
# Translated Text with Placeholders: ¿Qué país tiene una población más densa, [ENTITY_LOC_1] o la [ENTITY_LOC_2]?
# Final Translation: ¿Qué país tiene una población más densa, Canadá o la Estados Unidos?
# Masked English Text: How many queens has [ENTITY_LOC_1] had?
# Entity Mapping: {
#     "[ENTITY_LOC_1]": {
#         "original_text": "England",
#         "type": "LOC",
#         "confidence": 0.9999120235443115,
#         "start": 20,
#         "end": 27
#     }
# }
# Filtered Mapping (Confidence > 0.8): {
#     "[ENTITY_LOC_1]": {
#         "original_text": "England",
#         "type": "LOC",
#         "confidence": 0.9999120235443115,
#         "start": 20,
#         "end": 27
#     }
# }
# Translated Text with Placeholders: ¿Cuántas reinas ha tenido [ENTITY_LOC_1]?
# Final Translation: ¿Cuántas reinas ha tenido Inglaterra?
# Masked English Text: What is the capital of the state that had the last volcanic eruption in the [ENTITY_LOC_1]?
# Entity Mapping: {
#     "[ENTITY_LOC_1]": {
#         "original_text": "United States",
#         "type": "LOC",
#         "confidence": 0.9998794794082642,
#         "start": 76,
#         "end": 89
#     }
# }
# Filtered Mapping (Confidence > 0.8): {
#     "[ENTITY_LOC_1]": {
#         "original_text": "United States",
#         "type": "LOC",
#         "confidence": 0.9998794794082642,
#         "start": 76,
#         "end": 89
#     }
# }
# Translated Text with Placeholders: ¿Cuál es la capital del estado que tuvo la última erupción volcánica en la [ENTITY_LOC_1]?
# Final Translation: ¿Cuál es la capital del estado que tuvo la última erupción volcánica en la Estados Unidos?
# No entities found for text: When was the modern Chinese government formed?
# Masked English Text: When was the modern Chinese government formed?
# Entity Mapping: {}
# Filtered Mapping (Confidence > 0.8): {}
# Translated Text with Placeholders: ¿Cuándo se formó el gobierno chino moderno?
# Final Translation: ¿Cuándo se formó el gobierno chino moderno?
# Masked English Text: What is the largest city in [ENTITY_LOC_1] by population?
# Entity Mapping: {
#     "[ENTITY_LOC_1]": {
#         "original_text": "Russia",
#         "type": "LOC",
#         "confidence": 0.9999593496322632,
#         "start": 28,
#         "end": 34
#     }
# }
# Filtered Mapping (Confidence > 0.8): {
#     "[ENTITY_LOC_1]": {
#         "original_text": "Russia",
#         "type": "LOC",
#         "confidence": 0.9999593496322632,
#         "start": 28,
#         "end": 34
#     }
# }
# Translated Text with Placeholders: ¿Cuál es la ciudad más grande en [ENTITY_LOC_1] por población?
# Final Translation: ¿Cuál es la ciudad más grande en Rusia por población?
# Masked English Text: What is the population of the state where [ENTITY_LOC_1] is located?
# Entity Mapping: {
#     "[ENTITY_LOC_1]": {
#         "original_text": "Mount Rainier",
#         "type": "LOC",
#         "confidence": 0.9999648332595825,
#         "start": 42,
#         "end": 55
#     }
# }
# Filtered Mapping (Confidence > 0.8): {
#     "[ENTITY_LOC_1]": {
#         "original_text": "Mount Rainier",
#         "type": "LOC",
#         "confidence": 0.9999648332595825,
#         "start": 42,
#         "end": 55
#     }
# }
# Translated Text with Placeholders: ¿Cuál es la población del estado en el que se encuentra [ENTITY_LOC_1]?
# Final Translation: ¿Cuál es la población del estado en el que se encuentra El Monte Rainier?
# Masked English Text: Did the [ENTITY_LOC_1] men's national soccer team qualify for the last [ENTITY_EVE_1]?
# Entity Mapping: {
#     "[ENTITY_LOC_1]": {
#         "original_text": "USA",
#         "type": "LOC",
#         "confidence": 0.8592104315757751,
#         "start": 8,
#         "end": 11
#     },
#     "[ENTITY_EVE_1]": {
#         "original_text": "World Cup",
#         "type": "EVE",
#         "confidence": 0.993354320526123,
#         "start": 71,
#         "end": 80
#     }
# }
# Filtered Mapping (Confidence > 0.8): {
#     "[ENTITY_LOC_1]": {
#         "original_text": "USA",
#         "type": "LOC",
#         "confidence": 0.8592104315757751,
#         "start": 8,
#         "end": 11
#     },
#     "[ENTITY_EVE_1]": {
#         "original_text": "World Cup",
#         "type": "EVE",
#         "confidence": 0.993354320526123,
#         "start": 71,
#         "end": 80
#     }
# }
# Translated Text with Placeholders: ¿El equipo nacional de fútbol masculino [ENTITY_LOC_1] se calificó para el último [ENTITY_EVE_1]?
# Final Translation: ¿El equipo nacional de fútbol masculino Estados Unidos se calificó para el último Copa del Mundo?
# Masked English Text: Which state has less Congressional Districts, [ENTITY_LOC_1] or [ENTITY_LOC_2]?
# Entity Mapping: {
#     "[ENTITY_LOC_1]": {
#         "original_text": "Missouri",
#         "type": "LOC",
#         "confidence": 0.9999675750732422,
#         "start": 46,
#         "end": 54
#     },
#     "[ENTITY_LOC_2]": {
#         "original_text": "Illinois",
#         "type": "LOC",
#         "confidence": 0.9999630451202393,
#         "start": 64,
#         "end": 72
#     }
# }
# Filtered Mapping (Confidence > 0.8): {
#     "[ENTITY_LOC_1]": {
#         "original_text": "Missouri",
#         "type": "LOC",
#         "confidence": 0.9999675750732422,
#         "start": 46,
#         "end": 54
#     },
#     "[ENTITY_LOC_2]": {
#         "original_text": "Illinois",
#         "type": "LOC",
#         "confidence": 0.9999630451202393,
#         "start": 64,
#         "end": 72
#     }
# }
# Translated Text with Placeholders: ¿Qué estado tiene menos distritos del Congreso, [ENTITY_LOC_1] o [ENTITY_LOC_2]?
# Final Translation: ¿Qué estado tiene menos distritos del Congreso, El Missouri o El Illinois?
# Masked English Text: Who is the president of [ENTITY_LOC_1]?
# Entity Mapping: {
#     "[ENTITY_LOC_1]": {
#         "original_text": "South Africa",
#         "type": "LOC",
#         "confidence": 0.9999617338180542,
#         "start": 24,
#         "end": 36
#     }
# }
# Filtered Mapping (Confidence > 0.8): {
#     "[ENTITY_LOC_1]": {
#         "original_text": "South Africa",
#         "type": "LOC",
#         "confidence": 0.9999617338180542,
#         "start": 24,
#         "end": 36
#     }
# }
# Translated Text with Placeholders: ¿Quién es el presidente de [ENTITY_LOC_1]?
# Final Translation: ¿Quién es el presidente de Sudáfrica?
# Masked English Text: Who was from [ENTITY_LOC_1] and signed the [ENTITY_MEDIA_1]?
# Entity Mapping: {
#     "[ENTITY_LOC_1]": {
#         "original_text": "Illinois",
#         "type": "LOC",
#         "confidence": 0.9999542236328125,
#         "start": 13,
#         "end": 21
#     },
#     "[ENTITY_MEDIA_1]": {
#         "original_text": "Emancipation Proclamation",
#         "type": "MEDIA",
#         "confidence": 0.7058993577957153,
#         "start": 43,
#         "end": 68
#     }
# }
# Filtered Mapping (Confidence > 0.8): {
#     "[ENTITY_LOC_1]": {
#         "original_text": "Illinois",
#         "type": "LOC",
#         "confidence": 0.9999542236328125,
#         "start": 13,
#         "end": 21
#     }
# }
# Translated Text with Placeholders: ¿Quién fue de [ENTITY_LOC_1] y firmó [ENTITY_MEDIA_1]?
# Final Translation: ¿Quién fue de El Illinois y firmó [ENTITY_MEDIA_1]?
# Masked English Text: Which is the most spoken language in [ENTITY_LOC_1]?
# Entity Mapping: {
#     "[ENTITY_LOC_1]": {
#         "original_text": "South America",
#         "type": "LOC",
#         "confidence": 0.9999591112136841,
#         "start": 37,
#         "end": 50
#     }
# }
# Filtered Mapping (Confidence > 0.8): {
#     "[ENTITY_LOC_1]": {
#         "original_text": "South America",
#         "type": "LOC",
#         "confidence": 0.9999591112136841,
#         "start": 37,
#         "end": 50
#     }
# }
# Translated Text with Placeholders: ¿Cuál es el idioma más hablado en [ENTITY_LOC_1]?
# Final Translation: ¿Cuál es el idioma más hablado en Sudamérica?
# Masked English Text: What is the tallest mountain in [ENTITY_LOC_1]?
# Entity Mapping: {
#     "[ENTITY_LOC_1]": {
#         "original_text": "Africa",
#         "type": "LOC",
#         "confidence": 0.9997287392616272,
#         "start": 32,
#         "end": 38
#     }
# }
# Filtered Mapping (Confidence > 0.8): {
#     "[ENTITY_LOC_1]": {
#         "original_text": "Africa",
#         "type": "LOC",
#         "confidence": 0.9997287392616272,
#         "start": 32,
#         "end": 38
#     }
# }
# Translated Text with Placeholders: ¿Cuál es la montaña más alta en [ENTITY_LOC_1]?
# Final Translation: ¿Cuál es la montaña más alta en África?
# Masked English Text: Which [ENTITY_LOC_1] president had the shortest time in office?
# Entity Mapping: {
#     "[ENTITY_LOC_1]": {
#         "original_text": "United States",
#         "type": "LOC",
#         "confidence": 0.9981216788291931,
#         "start": 6,
#         "end": 19
#     }
# }
# Filtered Mapping (Confidence > 0.8): {
#     "[ENTITY_LOC_1]": {
#         "original_text": "United States",
#         "type": "LOC",
#         "confidence": 0.9981216788291931,
#         "start": 6,
#         "end": 19
#     }
# }
# Translated Text with Placeholders: ¿Cuál [ENTITY_LOC_1] presidente tuvo el tiempo más corto en el cargo?
# Final Translation: ¿Cuál Estados Unidos presidente tuvo el tiempo más corto en el cargo?
# Masked English Text: Who ran for president in 2016 and graduated from the [ENTITY_ORG_1]?
# Entity Mapping: {
#     "[ENTITY_ORG_1]": {
#         "original_text": "University of Pennsylvania",
#         "type": "ORG",
#         "confidence": 0.999987006187439,
#         "start": 53,
#         "end": 79
#     }
# }
# Filtered Mapping (Confidence > 0.8): {
#     "[ENTITY_ORG_1]": {
#         "original_text": "University of Pennsylvania",
#         "type": "ORG",
#         "confidence": 0.999987006187439,
#         "start": 53,
#         "end": 79
#     }
# }
# Translated Text with Placeholders: ¿Quién fue presidente en 2016 y se graduó de la [ENTITY_ORG_1]?
# Final Translation: ¿Quién fue presidente en 2016 y se graduó de la Universidad de Pensilvania?
# Masked English Text: Is [ENTITY_LOC_1] the capital of [ENTITY_LOC_2]?
# Entity Mapping: {
#     "[ENTITY_LOC_1]": {
#         "original_text": "Paris",
#         "type": "LOC",
#         "confidence": 0.9999644756317139,
#         "start": 3,
#         "end": 8
#     },
#     "[ENTITY_LOC_2]": {
#         "original_text": "France",
#         "type": "LOC",
#         "confidence": 0.9998855590820312,
#         "start": 33,
#         "end": 39
#     }
# }
# Filtered Mapping (Confidence > 0.8): {
#     "[ENTITY_LOC_1]": {
#         "original_text": "Paris",
#         "type": "LOC",
#         "confidence": 0.9999644756317139,
#         "start": 3,
#         "end": 8
#     },
#     "[ENTITY_LOC_2]": {
#         "original_text": "France",
#         "type": "LOC",
#         "confidence": 0.9998855590820312,
#         "start": 33,
#         "end": 39
#     }
# }
# Translated Text with Placeholders: ¿Es [ENTITY_LOC_1] el capital de [ENTITY_LOC_2]?
# Final Translation: ¿Es París el capital de Francia?
# Masked English Text: Who was the president of the [ENTITY_LOC_1] when [ENTITY_EVE_1] started?
# Entity Mapping: {
#     "[ENTITY_LOC_1]": {
#         "original_text": "United States",
#         "type": "LOC",
#         "confidence": 0.9998915195465088,
#         "start": 29,
#         "end": 42
#     },
#     "[ENTITY_EVE_1]": {
#         "original_text": "World War II",
#         "type": "EVE",
#         "confidence": 0.9999586343765259,
#         "start": 49,
#         "end": 61
#     }
# }
# Filtered Mapping (Confidence > 0.8): {
#     "[ENTITY_LOC_1]": {
#         "original_text": "United States",
#         "type": "LOC",
#         "confidence": 0.9998915195465088,
#         "start": 29,
#         "end": 42
#     },
#     "[ENTITY_EVE_1]": {
#         "original_text": "World War II",
#         "type": "EVE",
#         "confidence": 0.9999586343765259,
#         "start": 49,
#         "end": 61
#     }
# }
# Translated Text with Placeholders: ¿Quién fue el presidente de [ENTITY_LOC_1] cuando [ENTITY_EVE_1] comenzó?
# Final Translation: ¿Quién fue el presidente de Estados Unidos cuando Segunda Guerra Mundial comenzó?
# Masked English Text: In what year did the author who wrote [ENTITY_MEDIA_1] die?
# Entity Mapping: {
#     "[ENTITY_MEDIA_1]": {
#         "original_text": "To Kill a Mockingbird",
#         "type": "MEDIA",
#         "confidence": 0.9752559065818787,
#         "start": 38,
#         "end": 59
#     }
# }
# Filtered Mapping (Confidence > 0.8): {
#     "[ENTITY_MEDIA_1]": {
#         "original_text": "To Kill a Mockingbird",
#         "type": "MEDIA",
#         "confidence": 0.9752559065818787,
#         "start": 38,
#         "end": 59
#     }
# }
# Translated Text with Placeholders: ¿En qué año murió el autor que escribió [ENTITY_MEDIA_1]?
# Final Translation: ¿En qué año murió el autor que escribió Para matar a un mosquito?
# Masked English Text: Is [ENTITY_PER_1] the 40th prime minister of [ENTITY_LOC_1]?
# Entity Mapping: {
#     "[ENTITY_PER_1]": {
#         "original_text": "Jacinda Ardern",
#         "type": "PER",
#         "confidence": 0.9999723434448242,
#         "start": 3,
#         "end": 17
#     },
#     "[ENTITY_LOC_1]": {
#         "original_text": "New Zealand",
#         "type": "LOC",
#         "confidence": 0.9999016523361206,
#         "start": 45,
#         "end": 56
#     }
# }
# Filtered Mapping (Confidence > 0.8): {
#     "[ENTITY_PER_1]": {
#         "original_text": "Jacinda Ardern",
#         "type": "PER",
#         "confidence": 0.9999723434448242,
#         "start": 3,
#         "end": 17
#     },
#     "[ENTITY_LOC_1]": {
#         "original_text": "New Zealand",
#         "type": "LOC",
#         "confidence": 0.9999016523361206,
#         "start": 45,
#         "end": 56
#     }
# }
# Translated Text with Placeholders: ¿Es [ENTITY_PER_1] el 40o primer ministro de [ENTITY_LOC_1]?
# Final Translation: ¿Es de Jacinda Ardern el 40o primer ministro de Nueva Zelanda?
# Masked English Text: Who built the pyramids in [ENTITY_LOC_1]?
# Entity Mapping: {
#     "[ENTITY_LOC_1]": {
#         "original_text": "Mexico",
#         "type": "LOC",
#         "confidence": 0.9999696016311646,
#         "start": 26,
#         "end": 32
#     }
# }
# Filtered Mapping (Confidence > 0.8): {
#     "[ENTITY_LOC_1]": {
#         "original_text": "Mexico",
#         "type": "LOC",
#         "confidence": 0.9999696016311646,
#         "start": 26,
#         "end": 32
#     }
# }
# Translated Text with Placeholders: ¿Quién construyó las pirámides en [ENTITY_LOC_1]?
# Final Translation: ¿Quién construyó las pirámides en México?
# Masked English Text: Is [ENTITY_LOC_1] taller than [ENTITY_LOC_2]?
# Entity Mapping: {
#     "[ENTITY_LOC_1]": {
#         "original_text": "Mount Everest",
#         "type": "LOC",
#         "confidence": 0.9995884299278259,
#         "start": 3,
#         "end": 16
#     },
#     "[ENTITY_LOC_2]": {
#         "original_text": "Denali",
#         "type": "LOC",
#         "confidence": 0.9954426288604736,
#         "start": 30,
#         "end": 36
#     }
# }
# Filtered Mapping (Confidence > 0.8): {
#     "[ENTITY_LOC_1]": {
#         "original_text": "Mount Everest",
#         "type": "LOC",
#         "confidence": 0.9995884299278259,
#         "start": 3,
#         "end": 16
#     },
#     "[ENTITY_LOC_2]": {
#         "original_text": "Denali",
#         "type": "LOC",
#         "confidence": 0.9954426288604736,
#         "start": 30,
#         "end": 36
#     }
# }
# Translated Text with Placeholders: ¿Es [ENTITY_LOC_1] más alto que [ENTITY_LOC_2]?
# Final Translation: ¿Es El Monte Everest más alto que Denis?
# Masked English Text: Is [ENTITY_LOC_1] a democracy?
# Entity Mapping: {
#     "[ENTITY_LOC_1]": {
#         "original_text": "Brazil",
#         "type": "LOC",
#         "confidence": 0.9999735355377197,
#         "start": 3,
#         "end": 9
#     }
# }
# Filtered Mapping (Confidence > 0.8): {
#     "[ENTITY_LOC_1]": {
#         "original_text": "Brazil",
#         "type": "LOC",
#         "confidence": 0.9999735355377197,
#         "start": 3,
#         "end": 9
#     }
# }
# Translated Text with Placeholders: ¿Es [ENTITY_LOC_1] una democracia?
# Final Translation: ¿Es Brasil una democracia?
# Masked English Text: Is there a [ENTITY_LOC_1] in the [ENTITY_LOC_2]?
# Entity Mapping: {
#     "[ENTITY_LOC_1]": {
#         "original_text": "Royal Palace",
#         "type": "LOC",
#         "confidence": 0.9831064939498901,
#         "start": 11,
#         "end": 23
#     },
#     "[ENTITY_LOC_2]": {
#         "original_text": "United States",
#         "type": "LOC",
#         "confidence": 0.9817450642585754,
#         "start": 33,
#         "end": 46
#     }
# }
# Filtered Mapping (Confidence > 0.8): {
#     "[ENTITY_LOC_1]": {
#         "original_text": "Royal Palace",
#         "type": "LOC",
#         "confidence": 0.9831064939498901,
#         "start": 11,
#         "end": 23
#     },
#     "[ENTITY_LOC_2]": {
#         "original_text": "United States",
#         "type": "LOC",
#         "confidence": 0.9817450642585754,
#         "start": 33,
#         "end": 46
#     }
# }
# Translated Text with Placeholders: ¿Hay [ENTITY_LOC_1] en el [ENTITY_LOC_2]?
# Final Translation: ¿Hay El Palacio Real en el Estados Unidos?
# Masked English Text: Which movie is part of the [ENTITY_MEDIA_1] and has [ENTITY_PER_1] in the titular role?
# Entity Mapping: {
#     "[ENTITY_MEDIA_1]": {
#         "original_text": "Marvel Cinematic Universe",
#         "type": "MEDIA",
#         "confidence": 0.9948816299438477,
#         "start": 27,
#         "end": 52
#     },
#     "[ENTITY_PER_1]": {
#         "original_text": "Chadwick Boseman",
#         "type": "PER",
#         "confidence": 0.9999455213546753,
#         "start": 52,
#         "end": 68
#     }
# }
# Filtered Mapping (Confidence > 0.8): {
#     "[ENTITY_MEDIA_1]": {
#         "original_text": "Marvel Cinematic Universe",
#         "type": "MEDIA",
#         "confidence": 0.9948816299438477,
#         "start": 27,
#         "end": 52
#     },
#     "[ENTITY_PER_1]": {
#         "original_text": "Chadwick Boseman",
#         "type": "PER",
#         "confidence": 0.9999455213546753,
#         "start": 52,
#         "end": 68
#     }
# }
# Translated Text with Placeholders: ¿Qué película forma parte de [ENTITY_MEDIA_1] y tiene [ENTITY_PER_1] en el papel titular?
# Final Translation: ¿Qué película forma parte de El universo cinematográfico de Marvel y tiene El Chadwick Boseman en el papel titular?
# Masked English Text: What is the third largest lake in the [ENTITY_LOC_1]?
# Entity Mapping: {
#     "[ENTITY_LOC_1]": {
#         "original_text": "United States",
#         "type": "LOC",
#         "confidence": 0.9999326467514038,
#         "start": 38,
#         "end": 51
#     }
# }
# Filtered Mapping (Confidence > 0.8): {
#     "[ENTITY_LOC_1]": {
#         "original_text": "United States",
#         "type": "LOC",
#         "confidence": 0.9999326467514038,
#         "start": 38,
#         "end": 51
#     }
# }
# Translated Text with Placeholders: ¿Cuál es el tercer lago más grande en [ENTITY_LOC_1]?
# Final Translation: ¿Cuál es el tercer lago más grande en Estados Unidos?
# Masked English Text: Which Blackpink members were not from [ENTITY_LOC_1]?
# Entity Mapping: {
#     "[ENTITY_LOC_1]": {
#         "original_text": "South Korea",
#         "type": "LOC",
#         "confidence": 0.9999485015869141,
#         "start": 38,
#         "end": 49
#     }
# }
# Filtered Mapping (Confidence > 0.8): {
#     "[ENTITY_LOC_1]": {
#         "original_text": "South Korea",
#         "type": "LOC",
#         "confidence": 0.9999485015869141,
#         "start": 38,
#         "end": 49
#     }
# }
# Translated Text with Placeholders: ¿Qué miembros de Blackpink no eran de [ENTITY_LOC_1]?
# Final Translation: ¿Qué miembros de Blackpink no eran de Corea del Sur?
# Masked English Text: Did the last [ENTITY_PER_1] book come out before the year 2000?
# Entity Mapping: {
#     "[ENTITY_PER_1]": {
#         "original_text": "Lord of the Rings",
#         "type": "PER",
#         "confidence": 0.3965599834918976,
#         "start": 13,
#         "end": 30
#     }
# }
# Filtered Mapping (Confidence > 0.8): {}
# Translated Text with Placeholders: ¿El último libro [ENTITY_PER_1] salió antes del año 2000?
# Final Translation: ¿El último libro [ENTITY_PER_1] salió antes del año 2000?
# Masked English Text: What is the population of the smallest country in [ENTITY_LOC_1]?
# Entity Mapping: {
#     "[ENTITY_LOC_1]": {
#         "original_text": "Europe",
#         "type": "LOC",
#         "confidence": 0.9999476671218872,
#         "start": 50,
#         "end": 56
#     }
# }
# Filtered Mapping (Confidence > 0.8): {
#     "[ENTITY_LOC_1]": {
#         "original_text": "Europe",
#         "type": "LOC",
#         "confidence": 0.9999476671218872,
#         "start": 50,
#         "end": 56
#     }
# }
# Translated Text with Placeholders: ¿Cuál es la población del país más pequeño en [ENTITY_LOC_1]?
# Final Translation: ¿Cuál es la población del país más pequeño en Europa?
# Masked English Text: Who was the first president to have a [ENTITY_PLANT_1] at the [ENTITY_LOC_1]?
# Entity Mapping: {
#     "[ENTITY_PLANT_1]": {
#         "original_text": "Christmas tree",
#         "type": "PLANT",
#         "confidence": 0.8482248783111572,
#         "start": 38,
#         "end": 52
#     },
#     "[ENTITY_LOC_1]": {
#         "original_text": "White House",
#         "type": "LOC",
#         "confidence": 0.999538779258728,
#         "start": 62,
#         "end": 73
#     }
# }
# Filtered Mapping (Confidence > 0.8): {
#     "[ENTITY_PLANT_1]": {
#         "original_text": "Christmas tree",
#         "type": "PLANT",
#         "confidence": 0.8482248783111572,
#         "start": 38,
#         "end": 52
#     },
#     "[ENTITY_LOC_1]": {
#         "original_text": "White House",
#         "type": "LOC",
#         "confidence": 0.999538779258728,
#         "start": 62,
#         "end": 73
#     }
# }
# Translated Text with Placeholders: ¿Quién fue el primer presidente en tener una [ENTITY_PLANT_1] en la [ENTITY_LOC_1]?
# Final Translation: ¿Quién fue el primer presidente en tener una árbol de Navidad en la Casa Blanca?
# Masked English Text: Which leader of [ENTITY_LOC_1] invaded [ENTITY_LOC_2] but did not conquer it?
# Entity Mapping: {
#     "[ENTITY_LOC_1]": {
#         "original_text": "Mongol Empire",
#         "type": "LOC",
#         "confidence": 0.9988658428192139,
#         "start": 16,
#         "end": 29
#     },
#     "[ENTITY_LOC_2]": {
#         "original_text": "Japan",
#         "type": "LOC",
#         "confidence": 0.9998080134391785,
#         "start": 39,
#         "end": 44
#     }
# }
# Filtered Mapping (Confidence > 0.8): {
#     "[ENTITY_LOC_1]": {
#         "original_text": "Mongol Empire",
#         "type": "LOC",
#         "confidence": 0.9988658428192139,
#         "start": 16,
#         "end": 29
#     },
#     "[ENTITY_LOC_2]": {
#         "original_text": "Japan",
#         "type": "LOC",
#         "confidence": 0.9998080134391785,
#         "start": 39,
#         "end": 44
#     }
# }
# Translated Text with Placeholders: ¿Qué líder de [ENTITY_LOC_1] invadió [ENTITY_LOC_2] pero no lo conquistó?
# Final Translation: ¿Qué líder de El Imperio Mongol invadió Japón pero no lo conquistó?
# Masked English Text: What war started first, the [ENTITY_EVE_1] or [ENTITY_EVE_2]?
# Entity Mapping: {
#     "[ENTITY_EVE_1]": {
#         "original_text": "Korean War",
#         "type": "EVE",
#         "confidence": 0.9999638795852661,
#         "start": 28,
#         "end": 38
#     },
#     "[ENTITY_EVE_2]": {
#         "original_text": "Vietnam War",
#         "type": "EVE",
#         "confidence": 0.9999115467071533,
#         "start": 46,
#         "end": 57
#     }
# }
# Filtered Mapping (Confidence > 0.8): {
#     "[ENTITY_EVE_1]": {
#         "original_text": "Korean War",
#         "type": "EVE",
#         "confidence": 0.9999638795852661,
#         "start": 28,
#         "end": 38
#     },
#     "[ENTITY_EVE_2]": {
#         "original_text": "Vietnam War",
#         "type": "EVE",
#         "confidence": 0.9999115467071533,
#         "start": 46,
#         "end": 57
#     }
# }
# Translated Text with Placeholders: ¿Qué guerra comenzó primero, la [ENTITY_EVE_1] o [ENTITY_EVE_2]?
# Final Translation: ¿Qué guerra comenzó primero, la Guerra de Corea o Guerra de Vietnam?
# Masked English Text: When did [ENTITY_PER_1] write Dubliners?
# Entity Mapping: {
#     "[ENTITY_PER_1]": {
#         "original_text": "James Joyce",
#         "type": "PER",
#         "confidence": 0.999976396560669,
#         "start": 9,
#         "end": 20
#     }
# }
# Filtered Mapping (Confidence > 0.8): {
#     "[ENTITY_PER_1]": {
#         "original_text": "James Joyce",
#         "type": "PER",
#         "confidence": 0.999976396560669,
#         "start": 9,
#         "end": 20
#     }
# }
# Translated Text with Placeholders: ¿Cuándo [ENTITY_PER_1] escribió a los Dubliners?
# Final Translation: ¿Cuándo James Joyce escribió a los Dubliners?
# Masked English Text: Who served as Canadian prime minister for longer, [ENTITY_PER_1] or [ENTITY_PER_2]?
# Entity Mapping: {
#     "[ENTITY_PER_1]": {
#         "original_text": "Kim Campbell",
#         "type": "PER",
#         "confidence": 0.999984622001648,
#         "start": 50,
#         "end": 62
#     },
#     "[ENTITY_PER_2]": {
#         "original_text": "William Mackenzie King",
#         "type": "PER",
#         "confidence": 0.9999749660491943,
#         "start": 68,
#         "end": 90
#     }
# }
# Filtered Mapping (Confidence > 0.8): {
#     "[ENTITY_PER_1]": {
#         "original_text": "Kim Campbell",
#         "type": "PER",
#         "confidence": 0.999984622001648,
#         "start": 50,
#         "end": 62
#     },
#     "[ENTITY_PER_2]": {
#         "original_text": "William Mackenzie King",
#         "type": "PER",
#         "confidence": 0.9999749660491943,
#         "start": 68,
#         "end": 90
#     }
# }
# Translated Text with Placeholders: ¿Quién sirvió como primer ministro de Canadá por más tiempo, [ENTITY_PER_1] o [ENTITY_PER_2]?
# Final Translation: ¿Quién sirvió como primer ministro de Canadá por más tiempo, de Kim Campbell o El rey William Mackenzie?
# Masked English Text: Was the [ENTITY_MEDIA_1] published before [ENTITY_LOC_1]?
# Entity Mapping: {
#     "[ENTITY_MEDIA_1]": {
#         "original_text": "Lord of the Rings",
#         "type": "MEDIA",
#         "confidence": 0.3254334330558777,
#         "start": 8,
#         "end": 25
#     },
#     "[ENTITY_LOC_1]": {
#         "original_text": "Dune",
#         "type": "LOC",
#         "confidence": 0.6115233302116394,
#         "start": 42,
#         "end": 46
#     }
# }
# Filtered Mapping (Confidence > 0.8): {}
# Translated Text with Placeholders: ¿Había [ENTITY_MEDIA_1] publicado antes de [ENTITY_LOC_1]?
# Final Translation: ¿Había [ENTITY_MEDIA_1] publicado antes de [ENTITY_LOC_1]?
# Masked English Text: Did the [ENTITY_LOC_1] fight against [ENTITY_LOC_2] to gain its independence in the [ENTITY_EVE_1]?
# Entity Mapping: {
#     "[ENTITY_LOC_1]": {
#         "original_text": "United States",
#         "type": "LOC",
#         "confidence": 0.9998701810836792,
#         "start": 8,
#         "end": 21
#     },
#     "[ENTITY_LOC_2]": {
#         "original_text": "France",
#         "type": "LOC",
#         "confidence": 0.999524712562561,
#         "start": 37,
#         "end": 43
#     },
#     "[ENTITY_EVE_1]": {
#         "original_text": "Revolutionary War",
#         "type": "EVE",
#         "confidence": 0.9990345239639282,
#         "start": 84,
#         "end": 101
#     }
# }
# Filtered Mapping (Confidence > 0.8): {
#     "[ENTITY_LOC_1]": {
#         "original_text": "United States",
#         "type": "LOC",
#         "confidence": 0.9998701810836792,
#         "start": 8,
#         "end": 21
#     },
#     "[ENTITY_LOC_2]": {
#         "original_text": "France",
#         "type": "LOC",
#         "confidence": 0.999524712562561,
#         "start": 37,
#         "end": 43
#     },
#     "[ENTITY_EVE_1]": {
#         "original_text": "Revolutionary War",
#         "type": "EVE",
#         "confidence": 0.9990345239639282,
#         "start": 84,
#         "end": 101
#     }
# }
# Translated Text with Placeholders: ¿Había [ENTITY_LOC_1] luchado contra [ENTITY_LOC_2] para obtener su independencia en [ENTITY_EVE_1]?
# Final Translation: ¿Había Estados Unidos luchado contra Francia para obtener su independencia en Guerra Revolucionaria?
# Masked English Text: Who served in [ENTITY_ORG_1] as the Supreme Commander of the [ENTITY_ORG_2] in [ENTITY_LOC_1] and later became president of the [ENTITY_LOC_2]?
# Entity Mapping: {
#     "[ENTITY_ORG_1]": {
#         "original_text": "WW II",
#         "type": "ORG",
#         "confidence": 0.9412964582443237,
#         "start": 14,
#         "end": 19
#     },
#     "[ENTITY_ORG_2]": {
#         "original_text": "Allied Expeditionary Forces",
#         "type": "ORG",
#         "confidence": 0.9994547963142395,
#         "start": 61,
#         "end": 88
#     },
#     "[ENTITY_LOC_1]": {
#         "original_text": "Europe",
#         "type": "LOC",
#         "confidence": 0.9960746765136719,
#         "start": 79,
#         "end": 85
#     },
#     "[ENTITY_LOC_2]": {
#         "original_text": "United States",
#         "type": "LOC",
#         "confidence": 0.9997746348381042,
#         "start": 128,
#         "end": 141
#     }
# }
# Filtered Mapping (Confidence > 0.8): {
#     "[ENTITY_ORG_1]": {
#         "original_text": "WW II",
#         "type": "ORG",
#         "confidence": 0.9412964582443237,
#         "start": 14,
#         "end": 19
#     },
#     "[ENTITY_ORG_2]": {
#         "original_text": "Allied Expeditionary Forces",
#         "type": "ORG",
#         "confidence": 0.9994547963142395,
#         "start": 61,
#         "end": 88
#     },
#     "[ENTITY_LOC_1]": {
#         "original_text": "Europe",
#         "type": "LOC",
#         "confidence": 0.9960746765136719,
#         "start": 79,
#         "end": 85
#     },
#     "[ENTITY_LOC_2]": {
#         "original_text": "United States",
#         "type": "LOC",
#         "confidence": 0.9997746348381042,
#         "start": 128,
#         "end": 141
#     }
# }
# Translated Text with Placeholders: ¿Quién sirvió en [ENTITY_ORG_1] como comandante supremo de [ENTITY_ORG_2] en [ENTITY_LOC_1] y más tarde se convirtió en presidente de [ENTITY_LOC_2]?
# Final Translation: ¿Quién sirvió en WW II como comandante supremo de Fuerzas de expedición aliadas en Europa y más tarde se convirtió en presidente de Estados Unidos?
# Masked English Text: Who directed the movie based on the first [ENTITY_MEDIA_1] book?
# Entity Mapping: {
#     "[ENTITY_MEDIA_1]": {
#         "original_text": "Twilight",
#         "type": "MEDIA",
#         "confidence": 0.37651482224464417,
#         "start": 42,
#         "end": 50
#     }
# }
# Filtered Mapping (Confidence > 0.8): {}
# Translated Text with Placeholders: ¿Quién dirigió la película basada en el primer libro [ENTITY_MEDIA_1]?
# Final Translation: ¿Quién dirigió la película basada en el primer libro [ENTITY_MEDIA_1]?
# Masked English Text: How many Grammy Awards did [ENTITY_PER_1] win in 2021?
# Entity Mapping: {
#     "[ENTITY_PER_1]": {
#         "original_text": "Jay-Z",
#         "type": "PER",
#         "confidence": 0.9989476799964905,
#         "start": 27,
#         "end": 32
#     }
# }
# Filtered Mapping (Confidence > 0.8): {
#     "[ENTITY_PER_1]": {
#         "original_text": "Jay-Z",
#         "type": "PER",
#         "confidence": 0.9989476799964905,
#         "start": 27,
#         "end": 32
#     }
# }
# Translated Text with Placeholders: ¿Cuántos premios Grammy ganaron [ENTITY_PER_1] en 2021?
# Final Translation: ¿Cuántos premios Grammy ganaron El Jay-Z en 2021?
# Masked English Text: Does [ENTITY_LOC_1] have a larger land area than the [ENTITY_LOC_2]?
# Entity Mapping: {
#     "[ENTITY_LOC_1]": {
#         "original_text": "China",
#         "type": "LOC",
#         "confidence": 0.999640941619873,
#         "start": 5,
#         "end": 10
#     },
#     "[ENTITY_LOC_2]": {
#         "original_text": "United States",
#         "type": "LOC",
#         "confidence": 0.9999521970748901,
#         "start": 53,
#         "end": 66
#     }
# }
# Filtered Mapping (Confidence > 0.8): {
#     "[ENTITY_LOC_1]": {
#         "original_text": "China",
#         "type": "LOC",
#         "confidence": 0.999640941619873,
#         "start": 5,
#         "end": 10
#     },
#     "[ENTITY_LOC_2]": {
#         "original_text": "United States",
#         "type": "LOC",
#         "confidence": 0.9999521970748901,
#         "start": 53,
#         "end": 66
#     }
# }
# Translated Text with Placeholders: ¿Tiene [ENTITY_LOC_1] una superficie de tierra más grande que [ENTITY_LOC_2]?
# Final Translation: ¿Tiene China una superficie de tierra más grande que Estados Unidos?
# Masked English Text: What is the continent, besides [ENTITY_LOC_1], that has never hosted the [ENTITY_EVE_1]?
# Entity Mapping: {
#     "[ENTITY_LOC_1]": {
#         "original_text": "Antarctica",
#         "type": "LOC",
#         "confidence": 0.9999020099639893,
#         "start": 31,
#         "end": 41
#     },
#     "[ENTITY_EVE_1]": {
#         "original_text": "Olympics",
#         "type": "EVE",
#         "confidence": 0.5761883854866028,
#         "start": 73,
#         "end": 81
#     }
# }
# Filtered Mapping (Confidence > 0.8): {
#     "[ENTITY_LOC_1]": {
#         "original_text": "Antarctica",
#         "type": "LOC",
#         "confidence": 0.9999020099639893,
#         "start": 31,
#         "end": 41
#     }
# }
# Translated Text with Placeholders: ¿Cuál es el continente, además de [ENTITY_LOC_1], que nunca ha acogido [ENTITY_EVE_1]?
# Final Translation: ¿Cuál es el continente, además de Antártida, que nunca ha acogido [ENTITY_EVE_1]?
# Masked English Text: Was [ENTITY_MEDIA_1] written before or after [ENTITY_MEDIA_2]?
# Entity Mapping: {
#     "[ENTITY_MEDIA_1]": {
#         "original_text": "Pride and Prejudice",
#         "type": "MEDIA",
#         "confidence": 0.5329461097717285,
#         "start": 4,
#         "end": 23
#     },
#     "[ENTITY_MEDIA_2]": {
#         "original_text": "Sense and Sensibility",
#         "type": "MEDIA",
#         "confidence": 0.5153542160987854,
#         "start": 45,
#         "end": 66
#     }
# }
# Filtered Mapping (Confidence > 0.8): {}
# Translated Text with Placeholders: ¿Fue [ENTITY_MEDIA_1] escrito antes o después de [ENTITY_MEDIA_2]?
# Final Translation: ¿Fue [ENTITY_MEDIA_1] escrito antes o después de [ENTITY_MEDIA_2]?
# Masked English Text: Was [ENTITY_LOC_1] invaded by [ENTITY_PER_1] during [ENTITY_EVE_1]?
# Entity Mapping: {
#     "[ENTITY_LOC_1]": {
#         "original_text": "Switzerland",
#         "type": "LOC",
#         "confidence": 0.9998637437820435,
#         "start": 4,
#         "end": 15
#     },
#     "[ENTITY_PER_1]": {
#         "original_text": "Hitler",
#         "type": "PER",
#         "confidence": 0.9998942613601685,
#         "start": 30,
#         "end": 36
#     },
#     "[ENTITY_EVE_1]": {
#         "original_text": "World War II",
#         "type": "EVE",
#         "confidence": 0.999958872795105,
#         "start": 52,
#         "end": 64
#     }
# }
# Filtered Mapping (Confidence > 0.8): {
#     "[ENTITY_LOC_1]": {
#         "original_text": "Switzerland",
#         "type": "LOC",
#         "confidence": 0.9998637437820435,
#         "start": 4,
#         "end": 15
#     },
#     "[ENTITY_PER_1]": {
#         "original_text": "Hitler",
#         "type": "PER",
#         "confidence": 0.9998942613601685,
#         "start": 30,
#         "end": 36
#     },
#     "[ENTITY_EVE_1]": {
#         "original_text": "World War II",
#         "type": "EVE",
#         "confidence": 0.999958872795105,
#         "start": 52,
#         "end": 64
#     }
# }
# Translated Text with Placeholders: ¿Fue [ENTITY_LOC_1] invadido por [ENTITY_PER_1] durante [ENTITY_EVE_1]?
# Final Translation: ¿Fue Suiza invadido por Hitler durante Segunda Guerra Mundial?
# Masked English Text: Who had the longer reign, [ENTITY_PER_1] or [ENTITY_PER_2]?
# Entity Mapping: {
#     "[ENTITY_PER_1]": {
#         "original_text": "Peter the Great",
#         "type": "PER",
#         "confidence": 0.9565780758857727,
#         "start": 26,
#         "end": 41
#     },
#     "[ENTITY_PER_2]": {
#         "original_text": "Nicholas I",
#         "type": "PER",
#         "confidence": 0.9916421175003052,
#         "start": 44,
#         "end": 54
#     }
# }
# Filtered Mapping (Confidence > 0.8): {
#     "[ENTITY_PER_1]": {
#         "original_text": "Peter the Great",
#         "type": "PER",
#         "confidence": 0.9565780758857727,
#         "start": 26,
#         "end": 41
#     },
#     "[ENTITY_PER_2]": {
#         "original_text": "Nicholas I",
#         "type": "PER",
#         "confidence": 0.9916421175003052,
#         "start": 44,
#         "end": 54
#     }
# }
# Translated Text with Placeholders: ¿Quién tenía el reino más largo, [ENTITY_PER_1] o [ENTITY_PER_2]?
# Final Translation: ¿Quién tenía el reino más largo, Pedro el Gran o Nicolás I?
# Masked English Text: Who was both a child of [ENTITY_PER_1] and rival of [ENTITY_PER_2]?
# Entity Mapping: {
#     "[ENTITY_PER_1]": {
#         "original_text": "Henry VIII",
#         "type": "PER",
#         "confidence": 0.9995895028114319,
#         "start": 24,
#         "end": 34
#     },
#     "[ENTITY_PER_2]": {
#         "original_text": "Philip II of Spain",
#         "type": "PER",
#         "confidence": 0.9969125986099243,
#         "start": 52,
#         "end": 70
#     }
# }
# Filtered Mapping (Confidence > 0.8): {
#     "[ENTITY_PER_1]": {
#         "original_text": "Henry VIII",
#         "type": "PER",
# ...
# Final Translation: ¿Qué presidente de los Estados Unidos hizo la historia al convertirse en el primer presidente de los Estados Unidos sentado en declarar Jerusalén como la capital de Israel?
# Masked English Text: Which series has more books, [ENTITY_MEDIA_1] or [ENTITY_MEDIA_2]?
# Entity Mapping: {
#     "[ENTITY_MEDIA_1]": {
#         "original_text": "Stalking Jack the Ripper",
#         "type": "MEDIA",
#         "confidence": 0.9531696438789368,
#         "start": 29,
#         "end": 53
#     },
#     "[ENTITY_MEDIA_2]": {
#         "original_text": "Lord of the Rings",
#         "type": "MEDIA",
#         "confidence": 0.9713501334190369,
#         "start": 49,
#         "end": 66
#     }
# }
# Filtered Mapping (Confidence > 0.8): {
#     "[ENTITY_MEDIA_1]": {
#         "original_text": "Stalking Jack the Ripper",
#         "type": "MEDIA",
#         "confidence": 0.9531696438789368,
#         "start": 29,
#         "end": 53
#     },
#     "[ENTITY_MEDIA_2]": {
#         "original_text": "Lord of the Rings",
#         "type": "MEDIA",
#         "confidence": 0.9713501334190369,
#         "start": 49,
#         "end": 66
#     }
# }
# Translated Text with Placeholders: ¿Qué serie tiene más libros, [ENTITY_MEDIA_1] o [ENTITY_MEDIA_2]?
# Final Translation: ¿Qué serie tiene más libros, Siguiente Jack The Ripper o Señor de los anillos?
# Masked English Text: Who was the first vice president of the [ENTITY_LOC_1]?
# Entity Mapping: {
#     "[ENTITY_LOC_1]": {
#         "original_text": "United States",
#         "type": "LOC",
#         "confidence": 0.9998267292976379,
#         "start": 40,
#         "end": 53
#     }
# }
# Filtered Mapping (Confidence > 0.8): {
#     "[ENTITY_LOC_1]": {
#         "original_text": "United States",
#         "type": "LOC",
#         "confidence": 0.9998267292976379,
#         "start": 40,
#         "end": 53
#     }
# }
# Translated Text with Placeholders: ¿Quién fue el primer vicepresidente de la [ENTITY_LOC_1]?
# Final Translation: ¿Quién fue el primer vicepresidente de la Estados Unidos?
# Masked English Text: Was [ENTITY_PER_1] the governor of [ENTITY_LOC_1] previous to becoming [ENTITY_LOC_2] president?
# Entity Mapping: {
#     "[ENTITY_PER_1]": {
#         "original_text": "Donald Trump",
#         "type": "PER",
#         "confidence": 0.9999716281890869,
#         "start": 4,
#         "end": 16
#     },
#     "[ENTITY_LOC_1]": {
#         "original_text": "New York",
#         "type": "LOC",
#         "confidence": 0.9993608593940735,
#         "start": 35,
#         "end": 43
#     },
#     "[ENTITY_LOC_2]": {
#         "original_text": "U.S.",
#         "type": "LOC",
#         "confidence": 0.9794092774391174,
#         "start": 71,
#         "end": 75
#     }
# }
# Filtered Mapping (Confidence > 0.8): {
#     "[ENTITY_PER_1]": {
#         "original_text": "Donald Trump",
#         "type": "PER",
#         "confidence": 0.9999716281890869,
#         "start": 4,
#         "end": 16
#     },
#     "[ENTITY_LOC_1]": {
#         "original_text": "New York",
#         "type": "LOC",
#         "confidence": 0.9993608593940735,
#         "start": 35,
#         "end": 43
#     },
#     "[ENTITY_LOC_2]": {
#         "original_text": "U.S.",
#         "type": "LOC",
#         "confidence": 0.9794092774391174,
#         "start": 71,
#         "end": 75
#     }
# }
# Translated Text with Placeholders: ¿Fue [ENTITY_PER_1] el gobernador de [ENTITY_LOC_1] antes de convertirse en [ENTITY_LOC_2] presidente?
# Final Translation: ¿Fue Donaldo Trump el gobernador de Nueva York antes de convertirse en Estados Unidos presidente?
# Masked English Text: Was [ENTITY_PER_1] married?
# Entity Mapping: {
#     "[ENTITY_PER_1]": {
#         "original_text": "Christopher Columbus",
#         "type": "PER",
#         "confidence": 0.99996018409729,
#         "start": 4,
#         "end": 24
#     }
# }
# Filtered Mapping (Confidence > 0.8): {
#     "[ENTITY_PER_1]": {
#         "original_text": "Christopher Columbus",
#         "type": "PER",
#         "confidence": 0.99996018409729,
#         "start": 4,
#         "end": 24
#     }
# }
# Translated Text with Placeholders: ¿Fue [ENTITY_PER_1] casado?
# Final Translation: ¿Fue Cristóbal Colón casado?
# No entities found for text: As of 2015, which group held the record for the most Grammy Awards of any group in history?
# Masked English Text: As of 2015, which group held the record for the most Grammy Awards of any group in history?
# Entity Mapping: {}
# Filtered Mapping (Confidence > 0.8): {}
# Translated Text with Placeholders: En 2015, ¿cuál grupo tuvo el récord de los más premios Grammy de cualquier grupo en la historia?
# Final Translation: En 2015, ¿cuál grupo tuvo el récord de los más premios Grammy de cualquier grupo en la historia?
# Masked English Text: How old was the 40th president of the [ENTITY_LOC_1] before he died?
# Entity Mapping: {
#     "[ENTITY_LOC_1]": {
#         "original_text": "United States",
#         "type": "LOC",
#         "confidence": 0.9997445940971375,
#         "start": 38,
#         "end": 51
#     }
# }
# Filtered Mapping (Confidence > 0.8): {
#     "[ENTITY_LOC_1]": {
#         "original_text": "United States",
#         "type": "LOC",
#         "confidence": 0.9997445940971375,
#         "start": 38,
#         "end": 51
#     }
# }
# Translated Text with Placeholders: ¿Cuánto viejo fue el 40o presidente del [ENTITY_LOC_1] antes de que murió?
# Final Translation: ¿Cuánto viejo fue el 40o presidente del Estados Unidos antes de que murió?
# Masked English Text: Is [ENTITY_LOC_1] the capital of [ENTITY_LOC_2]?
# Entity Mapping: {
#     "[ENTITY_LOC_1]": {
#         "original_text": "Rome",
#         "type": "LOC",
#         "confidence": 0.9999521970748901,
#         "start": 3,
#         "end": 7
#     },
#     "[ENTITY_LOC_2]": {
#         "original_text": "China",
#         "type": "LOC",
#         "confidence": 0.9996781349182129,
#         "start": 33,
#         "end": 38
#     }
# }
# Filtered Mapping (Confidence > 0.8): {
#     "[ENTITY_LOC_1]": {
#         "original_text": "Rome",
#         "type": "LOC",
#         "confidence": 0.9999521970748901,
#         "start": 3,
#         "end": 7
#     },
#     "[ENTITY_LOC_2]": {
#         "original_text": "China",
#         "type": "LOC",
#         "confidence": 0.9996781349182129,
#         "start": 33,
#         "end": 38
#     }
# }
# Translated Text with Placeholders: ¿Es [ENTITY_LOC_1] el capital de [ENTITY_LOC_2]?
# Final Translation: ¿Es Roma el capital de China?
# Masked English Text: Who is the first child of the 44th president of the [ENTITY_LOC_1]?
# Entity Mapping: {
#     "[ENTITY_LOC_1]": {
#         "original_text": "United States",
#         "type": "LOC",
#         "confidence": 0.9960427284240723,
#         "start": 52,
#         "end": 65
#     }
# }
# Filtered Mapping (Confidence > 0.8): {
#     "[ENTITY_LOC_1]": {
#         "original_text": "United States",
#         "type": "LOC",
#         "confidence": 0.9960427284240723,
#         "start": 52,
#         "end": 65
#     }
# }
# Translated Text with Placeholders: ¿Quién es el primer hijo del 44o presidente de la [ENTITY_LOC_1]?
# Final Translation: ¿Quién es el primer hijo del 44o presidente de la Estados Unidos?
# Masked English Text: Who was an Attorney General of the [ENTITY_LOC_1] and also assassinated?
# Entity Mapping: {
#     "[ENTITY_LOC_1]": {
#         "original_text": "United States",
#         "type": "LOC",
#         "confidence": 0.9961052536964417,
#         "start": 35,
#         "end": 48
#     }
# }
# Filtered Mapping (Confidence > 0.8): {
#     "[ENTITY_LOC_1]": {
#         "original_text": "United States",
#         "type": "LOC",
#         "confidence": 0.9961052536964417,
#         "start": 35,
#         "end": 48
#     }
# }
# Translated Text with Placeholders: ¿Quién fue el Procurador General de la [ENTITY_LOC_1] y también asesinado?
# Final Translation: ¿Quién fue el Procurador General de la Estados Unidos y también asesinado?
# No entities found for text: How many times has the actress Bella from Twilight been married?
# Masked English Text: How many times has the actress Bella from Twilight been married?
# Entity Mapping: {}
# Filtered Mapping (Confidence > 0.8): {}
# Translated Text with Placeholders: ¿Cuántas veces se ha casado la actriz Bella de Twilight?
# Final Translation: ¿Cuántas veces se ha casado la actriz Bella de Twilight?
# Masked English Text: Which country is larger in size, [ENTITY_LOC_1] or [ENTITY_LOC_2]?
# Entity Mapping: {
#     "[ENTITY_LOC_1]": {
#         "original_text": "Russia",
#         "type": "LOC",
#         "confidence": 0.9999629259109497,
#         "start": 33,
#         "end": 39
#     },
#     "[ENTITY_LOC_2]": {
#         "original_text": "Canada",
#         "type": "LOC",
#         "confidence": 0.9999392032623291,
#         "start": 51,
#         "end": 57
#     }
# }
# Filtered Mapping (Confidence > 0.8): {
#     "[ENTITY_LOC_1]": {
#         "original_text": "Russia",
#         "type": "LOC",
#         "confidence": 0.9999629259109497,
#         "start": 33,
#         "end": 39
#     },
#     "[ENTITY_LOC_2]": {
#         "original_text": "Canada",
#         "type": "LOC",
#         "confidence": 0.9999392032623291,
#         "start": 51,
#         "end": 57
#     }
# }
# Translated Text with Placeholders: ¿Qué país es más grande en tamaño, [ENTITY_LOC_1] o [ENTITY_LOC_2]?
# Final Translation: ¿Qué país es más grande en tamaño, Rusia o Canadá?
# Masked English Text: What is the 4th longest river in [ENTITY_LOC_1]?
# Entity Mapping: {
#     "[ENTITY_LOC_1]": {
#         "original_text": "North America",
#         "type": "LOC",
#         "confidence": 0.9999496936798096,
#         "start": 33,
#         "end": 46
#     }
# }
# Filtered Mapping (Confidence > 0.8): {
#     "[ENTITY_LOC_1]": {
#         "original_text": "North America",
#         "type": "LOC",
#         "confidence": 0.9999496936798096,
#         "start": 33,
#         "end": 46
#     }
# }
# Translated Text with Placeholders: ¿Cuál es el 4o río más largo en [ENTITY_LOC_1]?
# Final Translation: ¿Cuál es el 4o río más largo en América del Norte?
# Masked English Text: Which Confederate general fought in the [ENTITY_EVE_1] in 1863, but did not win?
# Entity Mapping: {
#     "[ENTITY_EVE_1]": {
#         "original_text": "Battle for Gettysburg",
#         "type": "EVE",
#         "confidence": 0.9989725351333618,
#         "start": 40,
#         "end": 61
#     }
# }
# Filtered Mapping (Confidence > 0.8): {
#     "[ENTITY_EVE_1]": {
#         "original_text": "Battle for Gettysburg",
#         "type": "EVE",
#         "confidence": 0.9989725351333618,
#         "start": 40,
#         "end": 61
#     }
# }
# Translated Text with Placeholders: ¿Qué general confederado luchó en la [ENTITY_EVE_1] en 1863, pero no ganó?
# Final Translation: ¿Qué general confederado luchó en la La batalla de Gettysburg en 1863, pero no ganó?
# Masked English Text: Who is the governor of [ENTITY_LOC_1]?
# Entity Mapping: {
#     "[ENTITY_LOC_1]": {
#         "original_text": "New Jersey",
#         "type": "LOC",
#         "confidence": 0.9999285936355591,
#         "start": 23,
#         "end": 33
#     }
# }
# Filtered Mapping (Confidence > 0.8): {
#     "[ENTITY_LOC_1]": {
#         "original_text": "New Jersey",
#         "type": "LOC",
#         "confidence": 0.9999285936355591,
#         "start": 23,
#         "end": 33
#     }
# }
# Translated Text with Placeholders: ¿Quién es el gobernador de [ENTITY_LOC_1]?
# Final Translation: ¿Quién es el gobernador de Nueva Jersey?
# Masked English Text: Which state has more electoral votes, [ENTITY_LOC_1] or [ENTITY_LOC_2]?
# Entity Mapping: {
#     "[ENTITY_LOC_1]": {
#         "original_text": "Virginia",
#         "type": "LOC",
#         "confidence": 0.9999651908874512,
#         "start": 38,
#         "end": 46
#     },
#     "[ENTITY_LOC_2]": {
#         "original_text": "West Virginia",
#         "type": "LOC",
#         "confidence": 0.9999490976333618,
#         "start": 56,
#         "end": 69
#     }
# }
# Filtered Mapping (Confidence > 0.8): {
#     "[ENTITY_LOC_1]": {
#         "original_text": "Virginia",
#         "type": "LOC",
#         "confidence": 0.9999651908874512,
#         "start": 38,
#         "end": 46
#     },
#     "[ENTITY_LOC_2]": {
#         "original_text": "West Virginia",
#         "type": "LOC",
#         "confidence": 0.9999490976333618,
#         "start": 56,
#         "end": 69
#     }
# }
# Translated Text with Placeholders: ¿Qué estado tiene más votos electorales, [ENTITY_LOC_1] o [ENTITY_LOC_2]?
# Final Translation: ¿Qué estado tiene más votos electorales, Virginia o Virginia Occidental?
# Masked English Text: Who was the wife of the last king of [ENTITY_LOC_1]?
# Entity Mapping: {
#     "[ENTITY_LOC_1]": {
#         "original_text": "France",
#         "type": "LOC",
#         "confidence": 0.987589955329895,
#         "start": 37,
#         "end": 43
#     }
# }
# Filtered Mapping (Confidence > 0.8): {
#     "[ENTITY_LOC_1]": {
#         "original_text": "France",
#         "type": "LOC",
#         "confidence": 0.987589955329895,
#         "start": 37,
#         "end": 43
#     }
# }
# Translated Text with Placeholders: ¿Quién fue la esposa del último rey de [ENTITY_LOC_1]?
# Final Translation: ¿Quién fue la esposa del último rey de Francia?
# Masked English Text: What year did [ENTITY_ORG_1] form?
# Entity Mapping: {
#     "[ENTITY_ORG_1]": {
#         "original_text": "NSYNC",
#         "type": "ORG",
#         "confidence": 0.9473742842674255,
#         "start": 14,
#         "end": 19
#     }
# }
# Filtered Mapping (Confidence > 0.8): {
#     "[ENTITY_ORG_1]": {
#         "original_text": "NSYNC",
#         "type": "ORG",
#         "confidence": 0.9473742842674255,
#         "start": 14,
#         "end": 19
#     }
# }
# Translated Text with Placeholders: ¿Qué año se formó [ENTITY_ORG_1]?
# Final Translation: ¿Qué año se formó Nuevos?
# Masked English Text: Which war lasted longer, [ENTITY_EVE_1] or [ENTITY_EVE_2]?
# Entity Mapping: {
#     "[ENTITY_EVE_1]": {
#         "original_text": "Vietnam War",
#         "type": "EVE",
#         "confidence": 0.9999550580978394,
#         "start": 25,
#         "end": 36
#     },
#     "[ENTITY_EVE_2]": {
#         "original_text": "Korean War",
#         "type": "EVE",
#         "confidence": 0.9999055862426758,
#         "start": 43,
#         "end": 53
#     }
# }
# Filtered Mapping (Confidence > 0.8): {
#     "[ENTITY_EVE_1]": {
#         "original_text": "Vietnam War",
#         "type": "EVE",
#         "confidence": 0.9999550580978394,
#         "start": 25,
#         "end": 36
#     },
#     "[ENTITY_EVE_2]": {
#         "original_text": "Korean War",
#         "type": "EVE",
#         "confidence": 0.9999055862426758,
#         "start": 43,
#         "end": 53
#     }
# }
# Translated Text with Placeholders: ¿Qué guerra duró más tiempo, [ENTITY_EVE_1] o [ENTITY_EVE_2]?
# Final Translation: ¿Qué guerra duró más tiempo, Guerra de Vietnam o Guerra de Corea?
# Masked English Text: Who is the [ENTITY_EVE_1] era Soviet leader that was born to a poor family in [ENTITY_LOC_1]?
# Entity Mapping: {
#     "[ENTITY_EVE_1]": {
#         "original_text": "WW II",
#         "type": "EVE",
#         "confidence": 0.4129140377044678,
#         "start": 11,
#         "end": 16
#     },
#     "[ENTITY_LOC_1]": {
#         "original_text": "Gori",
#         "type": "LOC",
#         "confidence": 0.999841570854187,
#         "start": 78,
#         "end": 82
#     }
# }
# Filtered Mapping (Confidence > 0.8): {
#     "[ENTITY_LOC_1]": {
#         "original_text": "Gori",
#         "type": "LOC",
#         "confidence": 0.999841570854187,
#         "start": 78,
#         "end": 82
#     }
# }
# Translated Text with Placeholders: ¿Quién es el líder soviético de la era [ENTITY_EVE_1] que nació a una familia pobre en [ENTITY_LOC_1]?
# Final Translation: ¿Quién es el líder soviético de la era [ENTITY_EVE_1] que nació a una familia pobre en Guión?
# Masked English Text: Which war caused the most deaths, [ENTITY_EVE_1] or II?
# Entity Mapping: {
#     "[ENTITY_EVE_1]": {
#         "original_text": "World War I",
#         "type": "EVE",
#         "confidence": 0.999569833278656,
#         "start": 34,
#         "end": 45
#     }
# }
# Filtered Mapping (Confidence > 0.8): {
#     "[ENTITY_EVE_1]": {
#         "original_text": "World War I",
#         "type": "EVE",
#         "confidence": 0.999569833278656,
#         "start": 34,
#         "end": 45
#     }
# }
# Translated Text with Placeholders: ¿Qué guerra causó la mayor cantidad de muertes, [ENTITY_EVE_1] o II?
# Final Translation: ¿Qué guerra causó la mayor cantidad de muertes, Guerra Mundial I o II?
# Translation results for test set saved to data/translated_spanish_test.json
