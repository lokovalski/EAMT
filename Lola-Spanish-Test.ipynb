# %%
#$ Entity Masking
import json
from span_marker import SpanMarkerModel


def load_entities_mapping(file_path):
    """
    Loads entities and their translations from the given JSON file, skipping invalid lines.
    Args:
        file_path (str): Path to the JSON file containing entity mappings.
    Returns:
        list: A list of dictionaries representing the JSON data.
    """
    with open(file_path, 'r') as jf:
        try:
            return json.load(jf)  # Load the entire JSON array
        except json.JSONDecodeError as e:
            print(f"Error loading JSON file: {e}")
            return []


def mask_entities_with_spanmarker(text, model):
    """
    Masks named entities in text using predictions from SpanMarkerModel.

    Args:
        text (Union[str, List[str]]): Input text(s). Can be a single string or a list of strings.
        model (SpanMarkerModel): Pretrained SpanMarker model for entity prediction.

    Returns:
        Union[Tuple[str, dict], List[Tuple[str, dict]]]:
            - For a single string:
                - masked_text (str): Text with entities replaced by placeholders.
                - mapping (dict): Mapping of placeholders to original entities.
            - For a list of strings:
                - List of (masked_text, mapping) tuples.
    """
    # Check if input is a single string or a list of strings
    is_single_string = isinstance(text, str)
    if is_single_string:
        text = [text]  # Convert single string to list for uniform processing

    # Perform predictions using the model
    predictions = model.predict(text)  # Handles batch processing

    results = []
    for i, sentence in enumerate(text):
        masked_text = sentence
        mapping = {}
        type_counters = {}
        offset = 0

        # If no predictions for this sentence
        if not predictions[i]:  # Empty list
            print(f"No entities found for text: {sentence}")
            results.append((masked_text, mapping))
            continue

        # Process each entity in the prediction
        for entity in predictions[i]:
            entity_text = entity['span']
            entity_type = entity['label'].upper()
            start = entity['char_start_index']
            end = entity['char_end_index']

            # Counter for entity type
            if entity_type not in type_counters:
                type_counters[entity_type] = 1
            else:
                type_counters[entity_type] += 1

            # Generate a placeholder
            placeholder = f"[ENTITY_{entity_type}_{type_counters[entity_type]}]"

            # Replace entity with placeholder in the text
            start += offset
            end += offset
            masked_text = masked_text[:start] + placeholder + masked_text[end:]
            offset += len(placeholder) - len(entity_text)

            # Add to mapping
            mapping[placeholder] = {
                "original_text": entity_text,
                "type": entity_type,
                "confidence": entity['score'],
                "start": start,
                "end": end
            }

        results.append((masked_text, mapping))

    #if text input is a single string
    return results[0] if is_single_string else results

def ensure_pad_token(model):
    if not hasattr(model.tokenizer, "pad_token") or model.tokenizer.pad_token is None:
        print("Setting pad_token manually...")
        model.tokenizer.pad_token = "[PAD]"
        model.tokenizer.pad_token_id = model.tokenizer.convert_tokens_to_ids("[PAD]")

# %%
#$ MT Translation

from transformers import M2M100ForConditionalGeneration, M2M100Tokenizer

# Load the M2M100 model and tokenizer
model_name = "facebook/m2m100_418M"
model = M2M100ForConditionalGeneration.from_pretrained(model_name)
tokenizer = M2M100Tokenizer.from_pretrained(model_name)

def translate_with_placeholders_m2m(masked_text, mapping, src_lang, tgt_lang):
    """
    Translates the non-entity parts of a text and re-inserts placeholders using M2M100.

    Args:
        masked_text (str): Text with placeholders for entities.
        mapping (dict): Mapping of placeholders to entity details.
        src_lang (str): Source language code.
        tgt_lang (str): Target language code.

    Returns:
        str: Translated text with placeholders intact.
    """
    tokenizer.src_lang = src_lang

    # Encode and translate the entire sentence
    encoded_text = tokenizer(masked_text, return_tensors="pt")
    generated_tokens = model.generate(
        **encoded_text,
        forced_bos_token_id=tokenizer.get_lang_id(tgt_lang),
        max_length=128,  # Ensure sufficient length for translation
        early_stopping=True
    )

    # Decode the translated sentence
    translated_text = tokenizer.batch_decode(generated_tokens, skip_special_tokens=True)[0]
    return translated_text

# %%
#$ Entity Reintegration

from transformers import M2M100ForConditionalGeneration, M2M100Tokenizer

def translate_entity(entity, src_lang, tgt_lang):
    """
    Translates an entity if its type requires translation, otherwise returns the original entity.

    Args:
        entity (str): The placeholder or entity to process.
        src_lang (str): Source language code.
        tgt_lang (str): Target language code.

    Returns:
        str: The translated or original entity.
    """
    # types that should not be translated
    non_translatable_types = {"PER", "INST", "MEDIA", "PLANT", "VEHI"}

    # Check if the entity contains one of the non-translatable types
    if any(ntype in entity for ntype in non_translatable_types):
        return entity 

    # Translate the entity using M2M100
    tokenizer = M2M100Tokenizer.from_pretrained("facebook/m2m100_418M")
    model = M2M100ForConditionalGeneration.from_pretrained("facebook/m2m100_418M")
    tokenizer.src_lang = src_lang
    encoded_entity = tokenizer(entity, return_tensors="pt")
    generated_tokens = model.generate(**encoded_entity, forced_bos_token_id=tokenizer.get_lang_id(tgt_lang))
    translated_entity = tokenizer.batch_decode(generated_tokens, skip_special_tokens=True)[0]

    return translated_entity


def reintegrate_entities(translation, mapping, src_lang, tgt_lang):
    """
    Replaces placeholders in the translated text with original or translated entities.

    Args:
        translation (str): Translated text with placeholders.
        mapping (dict): Mapping of placeholders to original entities.
        src_lang (str): Source language code.
        tgt_lang (str): Target language code.

    Returns:
        str: Translation with entities reintegrated.
    """
    for placeholder, entity_info in mapping.items():
        # Get the original entity
        original_entity = entity_info["original_text"]

        # Translate the entity if needed
        translated_entity = translate_entity(original_entity, src_lang, tgt_lang)

        # Replace placeholder with the translated entity
        translation = translation.replace(placeholder, translated_entity)

    return translation

# %%
import os
es_datapath = os.path.abspath('data/spanish_test.json')

    # Step 1: Load the data
print("Loading Spanish data...")
spanish_data = load_entities_mapping(es_datapath)
# Out:
# Loading Spanish data...

# %%
spanish_data
# Out:
# [{'id': '32fd2909',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': "Who was the first son of Peter the Great's second wife?",
#   'target': '¿Cuál fue el primer hijo de la segunda esposa de Pedro el Grande?',
#   'entities': {'Q8479': {'es': 'Pedro I', 'en': 'Peter the Great'}},
#   'from': 'mintaka'},
#  {'id': '71a18e1d',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who is considered the founder of the Xia dynasty in ancient China?',
#   'target': '¿Quién es considerado como el fundador de la dinastía Xia en China antigua?',
#   'entities': {'Q169705': {'es': 'dinastía Xia', 'en': 'Xia dynasty'}},
#   'from': 'mintaka'},
#  {'id': '9afa8edd',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who was in charge of Great Britain during World War 2?',
#   'target': '¿Quién estaba a cargo de Gran Bretaña durante la Segunda Guerra Mundial?',
#   'entities': {'Q362': {'es': 'Segunda Guerra Mundial', 'en': 'World War II'},
#    'Q23666': {'es': 'Gran Bretaña', 'en': 'Great Britain'}},
#   'from': 'mintaka'},
#  {'id': '2b9e0b50',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What is the longest river in the UK that also flows through Wales and England?',
#   'target': '¿Cuál es el río más largo de Reino Unido y también atraviesa Gales e Inglaterra?',
#   'entities': {'Q21': {'es': 'Inglaterra', 'en': 'England'},
#    'Q25': {'es': 'Gales', 'en': 'Wales'},
#    'Q145': {'es': 'Reino Unido', 'en': 'United Kingdom'}},
#   'from': 'mintaka'},
#  {'id': '076a2300',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'How many states are in the United States?',
#   'target': '¿Cuántos países hay en Estados Unidos?',
#   'entities': {'Q30': {'es': 'Estados Unidos',
#     'en': 'United States of America'}},
#   'from': 'mintaka'},
#  {'id': '853a4508',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What is the tallest point in the 3rd smallest country in Europe?',
#   'target': '¿Cuál es el punto más alto del tercer menor país de Europa?',
#   'entities': {'Q46': {'es': 'Europa', 'en': 'Europe'}},
#   'from': 'mintaka'},
#  {'id': '22b9504f',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': "Which Wheel of Time novels were not completed before Robert Jordan's death?",
#   'target': '¿Cuáles novelas de La rueda del tiempo no fueron terminadas antes de que Robert Jordan muriera?',
#   'entities': {'Q4470': {'es': 'La rueda del tiempo',
#     'en': 'The Wheel of Time'}},
#   'from': 'mintaka'},
#  {'id': 'deaf829e',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Did World War II happen after World War I?',
#   'target': '¿La Segunda Guerra Mundial tuvo lugar luego de la Primera Guerra Mundial?',
#   'entities': {'Q361': {'es': 'Primera Guerra Mundial', 'en': 'World War I'},
#    'Q362': {'es': 'Segunda Guerra Mundial', 'en': 'World War II'}},
#   'from': 'mintaka'},
#  {'id': '6c58203c',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What is the first largest lake in North America?',
#   'target': '¿Cuál es el primer lago más grande de América del Norte?',
#   'entities': {'Q49': {'es': 'América del Norte', 'en': 'North America'}},
#   'from': 'mintaka'},
#  {'id': 'd539103c',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who was king of France for the shortest amount of time?',
#   'target': '¿Quién fue rey de Francia durante menor tiempo?',
#   'entities': {'Q142': {'es': 'Francia', 'en': 'France'}},
#   'from': 'mintaka'},
#  {'id': '7cefb323',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Did Robert Pattinson appear in Harry Potter and the Chamber of Secrets?',
#   'target': '¿Apareció Robert Pattison en Harry Potter y la Cámara de los Secretos?',
#   'entities': {'Q36767': {'es': 'Robert Pattinson', 'en': 'Robert Pattinson'}},
#   'from': 'mintaka'},
#  {'id': 'b7dfdd1c',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Are there five Twilight books?',
#   'target': '¿Hay cinco libros de Crepúsculo?',
#   'entities': {'Q44523': {'es': 'Crepúsculo', 'en': 'Twilight'}},
#   'from': 'mintaka'},
#  {'id': 'f30187f3',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who won the most Grammy Awards in 2018?',
#   'target': '¿Quién ganó más premios Grammy en 2018?',
#   'entities': {'Q41254': {'es': 'premios Grammy', 'en': 'Grammy Award'}},
#   'from': 'mintaka'},
#  {'id': '3adafb4c',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which contiguous state that borders the Pacific Ocean does not have a northern state on its border?',
#   'target': '¿Cuál de los estados contiguos con acceso al océano Pacífico no tiene frontera al norte con ningún otro estado?',
#   'entities': {'Q98': {'es': 'océano Pacífico', 'en': 'Pacific Ocean'}},
#   'from': 'mintaka'},
#  {'id': '0032f67e',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which rapper has the most Grammys?',
#   'target': '¿Qué rapero tiene la mayor cantidad de premios Grammy?',
#   'entities': {'Q41254': {'es': 'premios Grammy', 'en': 'Grammy Award'}},
#   'from': 'mintaka'},
#  {'id': '082d556c',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'How many books are in the original Twilight series?',
#   'target': '¿Cuántos libros hay en la serie original Crepúsculo?',
#   'entities': {'Q44523': {'es': 'Crepúsculo', 'en': 'Twilight'}},
#   'from': 'mintaka'},
#  {'id': 'bef619b6',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Was Augustus the first emperor of Rome?',
#   'target': '¿Fue Augusto el primer emperador de Roma?',
#   'entities': {'Q220': {'es': 'Roma', 'en': 'Rome'},
#    'Q1405': {'es': 'Augusto', 'en': 'Augustus'}},
#   'from': 'mintaka'},
#  {'id': '61243433',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Was John Quincy Adams the fifth president of the United States of America?',
#   'target': '¿Fue John Quincy Adams el quinto presidente de los Estados Unidos de América?',
#   'entities': {'Q30': {'es': 'Estados Unidos',
#     'en': 'United States of America'}},
#   'from': 'mintaka'},
#  {'id': '5ecc32bd',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'How many years did Augustus serve as emperor of Rome?',
#   'target': '¿Cuántos años sirvió Augusto como emperador de Roma?',
#   'entities': {'Q1405': {'es': 'Augusto', 'en': 'Augustus'},
#    'Q220': {'es': 'Roma', 'en': 'Rome'}},
#   'from': 'mintaka'},
#  {'id': '3f2c1ad4',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'How many soldiers died in the Vietnam war?',
#   'target': '¿Cuántos soldados murieron en la guerra de Vietnam?',
#   'entities': {'Q8740': {'es': 'Guerra de Vietnam', 'en': 'Vietnam War'}},
#   'from': 'mintaka'},
#  {'id': '1e64a53f',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'How many reigning queens has England had?',
#   'target': '¿Cuántas reinas ha tenido Inglaterra?',
#   'entities': {'Q21': {'es': 'Inglaterra', 'en': 'England'}},
#   'from': 'mintaka'},
#  {'id': 'b4fa41e3',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'How tall is the actor who played Captain Jack Sparrow?',
#   'target': '¿Cuán alto es el actor que interpretó al Capitán Jack Sparrow?',
#   'entities': {'Q202857': {'es': 'Jack Sparrow',
#     'en': 'Captain Jack Sparrow'}},
#   'from': 'mintaka'},
#  {'id': 'fa7e4282',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'How many wives did the author of "The Old Man and the Sea" have?',
#   'target': '¿Cuántas esposas tuvo el autor de El viejo y el mar?',
#   'entities': {'Q26505': {'es': 'El viejo y el mar',
#     'en': 'The Old Man and the Sea'}},
#   'from': 'mintaka'},
#  {'id': '7721231f',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What is the armed wing of the African National Congress?',
#   'target': '¿Cuál es el brazo armado del Congreso Nacional Africano?',
#   'entities': {'Q83162': {'es': 'Congreso Nacional Africano',
#     'en': 'African National Congress'}},
#   'from': 'mintaka'},
#  {'id': 'e293e18e',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What is the tallest building in the capital city of Italy?',
#   'target': '¿Cuál es el edificio más alto en la ciudad capital de Italia?',
#   'entities': {'Q38': {'es': 'Italia', 'en': 'Italy'}},
#   'from': 'mintaka'},
#  {'id': '4206582b',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What is the Brazilian island that has no human population and is administered by Itanhaem?',
#   'target': '¿Cuál es la isla brasileña que no tiene población humana y es administrada por Itanhaem?',
#   'entities': {'Q155': {'es': 'Brasil', 'en': 'Brazil'}},
#   'from': 'mintaka'},
#  {'id': '138df71c',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What was the first capital of ancient Egypt?',
#   'target': '¿Cuál fue la primera capital del antiguo Egipto?',
#   'entities': {'Q79': {'es': 'Egipto', 'en': 'Egypt'}},
#   'from': 'mintaka'},
#  {'id': '79c4b6fc',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Did the Republican Party win the Senate in 2016?',
#   'target': '¿El partido republicano ganó el Senado en 2016?',
#   'entities': {'Q29468': {'es': 'Partido Republicano',
#     'en': 'Republican Party'}},
#   'from': 'mintaka'},
#  {'id': 'eef06f35',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What was the primary weapon used by Legolas?',
#   'target': '¿Cuál era la principal arma utilizada por Légolas?',
#   'entities': {'Q213480': {'es': 'Legolas', 'en': 'Legolas'}},
#   'from': 'mintaka'},
#  {'id': 'b2d8d95b',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What party did the U.S. president belong to when the United States left Vietnam during the Vietnam war?',
#   'target': '¿A qué partido pertenecía el presidente cuando los EE. UU. dejaron Vietnam durante la guerra de Vietnam?',
#   'entities': {'Q8740': {'es': 'Guerra de Vietnam', 'en': 'Vietnam War'}},
#   'from': 'mintaka'},
#  {'id': 'e5462786',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which American war lasted longer, Vietnam or Iraq?',
#   'target': '¿Cuál guerra estadounidense duró más tiempo, Vietnam o Irak?',
#   'entities': {'Q796': {'es': 'Irak', 'en': 'Iraq'}},
#   'from': 'mintaka'},
#  {'id': '9c13fbe6',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who has won more Grammy Awards, Korn or Tool?',
#   'target': '¿Quién ganó más premios Grammy: Korn o Tool?',
#   'entities': {'Q41254': {'es': 'premios Grammy', 'en': 'Grammy Award'}},
#   'from': 'mintaka'},
#  {'id': '0afe4b48',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'How many federated states are located in the Southern Region of Brazil?',
#   'target': '¿Cuántos estados federados no se encuentran en la región sur de Brasil?',
#   'entities': {'Q155': {'es': 'Brasil', 'en': 'Brazil'}},
#   'from': 'mintaka'},
#  {'id': '6ff78089',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which book introduced a small hobbit and was loosely based on the Bible?',
#   'target': '¿Qué libro introdujo un pequeño hobbit y estaba basado ligeramente en la Biblia?',
#   'entities': {'Q1845': {'es': 'Biblia', 'en': 'Bible'}},
#   'from': 'mintaka'},
#  {'id': 'c607ed62',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who was the first tsar of Russia?',
#   'target': '¿Quién fue el primer Zar de Rusia?',
#   'entities': {'Q159': {'es': 'Rusia', 'en': 'Russia'}},
#   'from': 'mintaka'},
#  {'id': '12b557a7',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': "How many Assassin's Creed games are set in ancient Egypt?",
#   'target': "¿Cuántos juegos de Assassin's Creed están ambientados en el antiguo Egipto?",
#   'entities': {'Q79': {'es': 'Egipto', 'en': 'Egypt'}},
#   'from': 'mintaka'},
#  {'id': '2e952aff',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'How many states do not share any borders with any other U.S. state?',
#   'target': '¿Cuántos estados no comparten frontera con ningún otro estado de Estados Unidos?',
#   'entities': {'Q30': {'es': 'Estados Unidos',
#     'en': 'United States of America'}},
#   'from': 'mintaka'},
#  {'id': '359691ae',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'How many counties are in Africa?',
#   'target': '¿Cuántos países hay en África?',
#   'entities': {'Q15': {'es': 'África', 'en': 'Africa'}},
#   'from': 'mintaka'},
#  {'id': '336fc84b',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who was the second president of Mexico?',
#   'target': '¿Quién fue el segundo presidente de México?',
#   'entities': {'Q96': {'es': 'México', 'en': 'Mexico'}},
#   'from': 'mintaka'},
#  {'id': 'a043881e',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Did the Treaty of Ghent end the War of 1812?',
#   'target': '¿Terminó el Tratado de Gante la guerra de 1812?',
#   'entities': {'Q1324198': {'es': 'Tratado de Gante',
#     'en': 'Treaty of Ghent'}},
#   'from': 'mintaka'},
#  {'id': '813d1d29',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What state has existed longer, Delaware or Mississippi?',
#   'target': '¿Qué estado existe desde hace más tiempo: Delaware o Misisipi?',
#   'entities': {'Q1494': {'es': 'Misisipi', 'en': 'Mississippi'}},
#   'from': 'mintaka'},
#  {'id': '52562cc5',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': "Which US state isn't the most visited?",
#   'target': '¿Cuál estado de Estados Unidos no es el más visitado?',
#   'entities': {'Q30': {'es': 'Estados Unidos',
#     'en': 'United States of America'}},
#   'from': 'mintaka'},
#  {'id': '26d6d309',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which member of The Police was not British?',
#   'target': '¿Qué miembro de The Police no era británico?',
#   'entities': {'Q842438': {'es': 'británicos', 'en': 'Britons'}},
#   'from': 'mintaka'},
#  {'id': '99dbd28d',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which country has a larger population, Brazil or Pakistan?',
#   'target': '¿Cuál de estos países tiene una mayor población: Brasil o Pakistán?',
#   'entities': {'Q155': {'es': 'Brasil', 'en': 'Brazil'},
#    'Q843': {'es': 'Pakistán', 'en': 'Pakistan'}},
#   'from': 'mintaka'},
#  {'id': '2738f9b7',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What is the largest country in Africa by population?',
#   'target': '¿Cuál es el mayor país en África por población?',
#   'entities': {'Q15': {'es': 'África', 'en': 'Africa'}},
#   'from': 'mintaka'},
#  {'id': 'd334c2e9',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which is the last book in the Lord of the Rings series?',
#   'target': '¿Cuál es el último libro de la serie El señor de los anillos?',
#   'entities': {'Q15228': {'es': 'El Señor de los Anillos',
#     'en': 'The Lord of the Rings'}},
#   'from': 'mintaka'},
#  {'id': 'c1f6cc96',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who was the second United States president to be assassinated while in office?',
#   'target': '¿Quién fue el segundo Presidente de los Estados Unidos asesinado durante su mandato?',
#   'entities': {'Q30': {'es': 'Estados Unidos',
#     'en': 'United States of America'}},
#   'from': 'mintaka'},
#  {'id': 'befc7eea',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What NC governors since 2012 have not been Republican?',
#   'target': '¿Qué gobernadores de Carolina del Norte no han sido republicanos desde el año 2012?',
#   'entities': {'Q1454': {'es': 'Carolina del Norte', 'en': 'North Carolina'}},
#   'from': 'mintaka'},
#  {'id': '0744457d',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What man was US president and also Chief Justice of the Supreme Court?',
#   'target': '¿Quién fue Presidente de los Estados Unidos y también Juez Presidente de la Corte Suprema?',
#   'entities': {'Q11696': {'es': 'presidente de Estados Unidos',
#     'en': 'President of the United States'}},
#   'from': 'mintaka'},
#  {'id': 'bee1c7fb',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What was the name of the television character in 1981 to 1990 that was played by the divorced first wife of the first United States president?',
#   'target': '¿Cuál fue el nombre del personaje de televisión interpretado de 1981 a 1990 por la primera esposa del primer presidente de Estados Unidos que se divorció?',
#   'entities': {'Q30': {'es': 'Estados Unidos',
#     'en': 'United States of America'}},
#   'from': 'mintaka'},
#  {'id': '65796545',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Was the Second World War in the 1950s?',
#   'target': '¿La Segunda Guerra Mundial fue en los 1950?',
#   'entities': {'Q362': {'es': 'Segunda Guerra Mundial', 'en': 'World War II'}},
#   'from': 'mintaka'},
#  {'id': 'bb3c6802',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'The tallest waterfall in the United States, how tall is it?',
#   'target': 'La cascada más alta de los Estados Unidos, ¿qué tan alta es?',
#   'entities': {'Q30': {'es': 'Estados Unidos',
#     'en': 'United States of America'}},
#   'from': 'mintaka'},
#  {'id': '3130bb4d',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': "Was 24K Magic Bruno Mars' first album?",
#   'target': '¿24k Magik fue el primer álbum de Bruno Mars?',
#   'entities': {'Q27133229': {'es': '24K Magic', 'en': '24K Magic'}},
#   'from': 'mintaka'},
#  {'id': 'c3c9ea65',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which American suffragist never got married?',
#   'target': '¿Qué sufragista estadounidense nunca se casó?',
#   'entities': {'Q846570': {'es': 'Estadounidense', 'en': 'Americans'}},
#   'from': 'mintaka'},
#  {'id': '2c33e140',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Has the United States ever had a non-white president?',
#   'target': '¿Los Estados Unidos han tenido un presidente no blanco?',
#   'entities': {'Q30': {'es': 'Estados Unidos',
#     'en': 'United States of America'}},
#   'from': 'mintaka'},
#  {'id': '344ad093',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which 2020 Grammy Award was Black Pumas nominated for but did not win?',
#   'target': '¿A qué premio Grammy 2020 fueron nominados Black Pumas pero no ganó?',
#   'entities': {'Q41254': {'es': 'premios Grammy', 'en': 'Grammy Award'}},
#   'from': 'mintaka'},
#  {'id': 'd1cdb707',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Has there ever been a U.S. president who was a practicing Muslim?',
#   'target': '¿Alguna vez ha habido un presidente de los Estados Unidos que practicara el islamismo?',
#   'entities': {'Q30': {'es': 'Estados Unidos',
#     'en': 'United States of America'}},
#   'from': 'mintaka'},
#  {'id': 'bc9c51b1',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Has Taylor Swift won a Grammy Award?',
#   'target': '¿Ganó un premio Grammy Taylor Swift?',
#   'entities': {'Q41254': {'es': 'premios Grammy', 'en': 'Grammy Award'}},
#   'from': 'mintaka'},
#  {'id': '56fa4ecd',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who lived longer, Alexander the Great or his father Philip II of Macedon?',
#   'target': '¿Quién vivió más, Alejandro Magno o su padre, Filipo II de Macedonia?',
#   'entities': {'Q8409': {'es': 'Alejandro Magno', 'en': 'Alexander the Great'},
#    'Q130650': {'es': 'Filipo II de Macedonia', 'en': 'Philip II of Macedon'}},
#   'from': 'mintaka'},
#  {'id': 'eb370592',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What is the largest city in Canada by population?',
#   'target': '¿Cuál es la ciudad más grande de Canadá por población?',
#   'entities': {'Q16': {'es': 'Canadá', 'en': 'Canada'}},
#   'from': 'mintaka'},
#  {'id': '440191d2',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'In what year did World War II end?',
#   'target': '¿En qué año terminó la Segunda Guerra Mundial?',
#   'entities': {'Q362': {'es': 'Segunda Guerra Mundial', 'en': 'World War II'}},
#   'from': 'mintaka'},
#  {'id': '1ffea70d',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Did Japan surrender in World War 2?',
#   'target': '¿Japón se dio por vencido en la Segunda Guerra Mundial?',
#   'entities': {'Q362': {'es': 'Segunda Guerra Mundial', 'en': 'World War II'},
#    'Q17': {'es': 'Japón', 'en': 'Japan'}},
#   'from': 'mintaka'},
#  {'id': 'b44df782',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What is the second movie in the Hobbit series?',
#   'target': '¿Cuál es la segunda película en la serie del Hobbit?',
#   'entities': {'Q74331': {'es': 'El hobbit', 'en': 'The Hobbit trilogy'}},
#   'from': 'mintaka'},
#  {'id': 'e5b27973',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who was prime minister of the United Kingdom during most of World War II?',
#   'target': '¿Quién fue el Primer Ministro del Reino Unido durante la mayor parte de la Segunda Guerra Mundial?',
#   'entities': {'Q145': {'es': 'Reino Unido', 'en': 'United Kingdom'},
#    'Q362': {'es': 'Segunda Guerra Mundial', 'en': 'World War II'}},
#   'from': 'mintaka'},
#  {'id': 'e9d94136',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who is the president of Japan?',
#   'target': '¿Quién es el presidente de Japón?',
#   'entities': {'Q17': {'es': 'Japón', 'en': 'Japan'}},
#   'from': 'mintaka'},
#  {'id': '6bd6bb4e',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'How tall is the singer of "Baby One More Time"?',
#   'target': '¿Cuán alta es la cantante de Baby one More Time?',
#   'entities': {'Q155016': {'es': '...Baby One More Time',
#     'en': '...Baby One More Time'}},
#   'from': 'mintaka'},
#  {'id': '0efbf764',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Did Jaws get 4 Academy Award nominations?',
#   'target': '¿Tiburón 4 obtuvo nominaciones de los Premios de la Academia?',
#   'entities': {'Q189505': {'es': 'Tiburón', 'en': 'Jaws'}},
#   'from': 'mintaka'},
#  {'id': '05e10f57',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Where was the first president of the United States born?',
#   'target': '¿Dónde nació el primer presidente de los Estados Unidos?',
#   'entities': {'Q30': {'es': 'Estados Unidos',
#     'en': 'United States of America'}},
#   'from': 'mintaka'},
#  {'id': '5270e80f',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which river is longer, the Nile or the Amazon?',
#   'target': '¿Qué río es más largo, el Nilo o el Amazonas?',
#   'entities': {'Q3392': {'es': 'Nilo', 'en': 'Nile'}},
#   'from': 'mintaka'},
#  {'id': '78480426',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which Agatha Christie novel was published in 1930 and is a part of the Miss Marple series?',
#   'target': '¿Qué novela de Ágatha Christie fue publicada en 1930 y forma parte de la saga de Miss Marple?',
#   'entities': {'Q35064': {'es': 'Agatha Christie', 'en': 'Agatha Christie'}},
#   'from': 'mintaka'},
#  {'id': 'af7d1ec3',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who is the current prime minister of Bahrain?',
#   'target': '¿Quién es el actual primer ministro de Baréin?',
#   'entities': {'Q398': {'es': 'Baréin', 'en': 'Bahrain'}},
#   'from': 'mintaka'},
#  {'id': 'e2a44231',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Was The Lord of the Rings published before 1960?',
#   'target': '¿El señor de los anillos fue publicado antes de 1960?',
#   'entities': {'Q15228': {'es': 'El Señor de los Anillos',
#     'en': 'The Lord of the Rings'}},
#   'from': 'mintaka'},
#  {'id': 'ba0d6da8',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What was the tallest building in New York City in 1920?',
#   'target': '¿Cuál era el edificio más alto de la ciudad de Nueva York en 1920?',
#   'entities': {'Q60': {'es': 'Nueva York', 'en': 'New York City'}},
#   'from': 'mintaka'},
#  {'id': '4c0bf07d',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'How many Grammy Awards has Tupac won?',
#   'target': '¿Cuántos premios Grammy ganó Tupac?',
#   'entities': {'Q41254': {'es': 'premios Grammy', 'en': 'Grammy Award'}},
#   'from': 'mintaka'},
#  {'id': '139b94e0',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Was Athelstan the first king of England?',
#   'target': '¿Fue Atelstán el primer rey de Inglaterra?',
#   'entities': {'Q21': {'es': 'Inglaterra', 'en': 'England'}},
#   'from': 'mintaka'},
#  {'id': 'dc7d1947',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'How many none white males have been president of the United States as of 2020?',
#   'target': '¿Cuántos hombres no blancos han sido presidentes de los Estados Unidos desde el 2020?',
#   'entities': {'Q30': {'es': 'Estados Unidos',
#     'en': 'United States of America'}},
#   'from': 'mintaka'},
#  {'id': '65141012',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who was the youngest artist to win a Grammy Award?',
#   'target': '¿Quién fue el artista más joven en ganar un premio Grammy?',
#   'entities': {'Q41254': {'es': 'premios Grammy', 'en': 'Grammy Award'}},
#   'from': 'mintaka'},
#  {'id': '61fb6e73',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Are there jungles in Antarctica?',
#   'target': '¿Hay junglas en la Antártica?',
#   'entities': {'Q51': {'es': 'Antártida', 'en': 'Antarctica'}},
#   'from': 'mintaka'},
#  {'id': '8eb292a6',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'How many federated states in Brazil have a population density above 100 km2?',
#   'target': '¿Cuántas provincias federales en Brasil tienen más de 100 por km2 de densidad poblacional?',
#   'entities': {'Q155': {'es': 'Brasil', 'en': 'Brazil'}},
#   'from': 'mintaka'},
#  {'id': 'e164dd0c',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which country has a larger population, India or Brazil?',
#   'target': '¿Cuál de estos países tiene una mayor densidad de población; India o Brasil?',
#   'entities': {'Q155': {'es': 'Brasil', 'en': 'Brazil'}},
#   'from': 'mintaka'},
#  {'id': '4997a262',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Was Apollo 13 nominated for Best Picture?',
#   'target': '¿Apolo 13 fue nominada como mejor película?',
#   'entities': {'Q106428': {'es': 'Apolo 13', 'en': 'Apollo 13'}},
#   'from': 'mintaka'},
#  {'id': '60b9ad3e',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'How many political leaders have North Korea have?',
#   'target': '¿Cuántos líderes políticos ha tenido Corea del Norte?',
#   'entities': {'Q423': {'es': 'Corea del Norte', 'en': 'North Korea'}},
#   'from': 'mintaka'},
#  {'id': '9884ca62',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'How many children does the lead actress in The Hunger Games have?',
#   'target': '¿Cuántos hijos tiene la actriz principal de Los Juegos del Hambre?',
#   'entities': {'Q212965': {'es': 'Los juegos del hambre',
#     'en': 'The Hunger Games'}},
#   'from': 'mintaka'},
#  {'id': '7b9bf2af',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'In what year did William the Conqueror take over England?',
#   'target': '¿En qué año Guillermo el Conquistador tomó el poder de Inglaterra?',
#   'entities': {'Q21': {'es': 'Inglaterra', 'en': 'England'}},
#   'from': 'mintaka'},
#  {'id': '7ee0de9f',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Was King Henry VIII the King of France during his reign?',
#   'target': '¿El Rey Enrique VII fue el rey de Francia durante su reinado?',
#   'entities': {'Q142': {'es': 'Francia', 'en': 'France'}},
#   'from': 'mintaka'},
#  {'id': 'ab23a7cd',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Was Brazil part of the Allied Force in World War II?',
#   'target': '¿Brasil era parte de las Fuerzas Aliadas en la Segunda Guerra Mundial?',
#   'entities': {'Q155': {'es': 'Brasil', 'en': 'Brazil'},
#    'Q362': {'es': 'Segunda Guerra Mundial', 'en': 'World War II'}},
#   'from': 'mintaka'},
#  {'id': 'afe5627b',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Where was the wife of the 6th U.S. president born?',
#   'target': '¿Dónde nació la esposa del sexto presidente de Estados Unidos?',
#   'entities': {'Q30': {'es': 'Estados Unidos',
#     'en': 'United States of America'}},
#   'from': 'mintaka'},
#  {'id': '9baf9781',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who is an American professional golfer who did not play professional golf from December 2009 to early April 2010 in an attempt to resolve marital issues?',
#   'target': '¿Quién es el golfista profesional estadounidense que no jugó como profesional desde diciembre de 2009 hasta principios de abril de 2010 para resolver problemas maritales?',
#   'entities': {'Q846570': {'es': 'Estadounidense', 'en': 'Americans'}},
#   'from': 'mintaka'},
#  {'id': 'a7d24854',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which Suzanne Collins book has more pages, Mockingjay or Catching Fire?',
#   'target': '¿Cuál libro de Suzanne Collins tiene más páginas, Sinsajo o En llamas?',
#   'entities': {'Q40354': {'es': 'Sinsajo', 'en': 'Mockingjay'},
#    'Q837140': {'es': 'En llamas', 'en': 'Catching Fire'}},
#   'from': 'mintaka'},
#  {'id': 'b3dd5b5d',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which state has more electoral votes, Texas or New York?',
#   'target': '¿Qué estado tiene más votos electorales, Texas o Nueva York?',
#   'entities': {'Q1384': {'es': 'Nueva York', 'en': 'New York'}},
#   'from': 'mintaka'},
#  {'id': 'dc3d8068',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What was the third war actually declared by the United States?',
#   'target': '¿Cuál fue la tercera guerra realmente declarada por los Estados Unidos?',
#   'entities': {'Q30': {'es': 'Estados Unidos',
#     'en': 'United States of America'}},
#   'from': 'mintaka'},
#  {'id': 'fe28d942',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'How many books are in The Chronicles of Narnia series?',
#   'target': '¿Cuántos libros tiene la serie Las crónicas de Narnia?',
#   'entities': {'Q483412': {'es': 'Las Crónicas de Narnia',
#     'en': 'The Chronicles of Narnia'}},
#   'from': 'mintaka'},
#  {'id': 'cc3037c7',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which war caused the most deaths, World War I or II?',
#   'target': '¿Qué guerra causó más muertes, la Primera o la Segunda Guerra Mundial?',
#   'entities': {'Q362': {'es': 'Segunda Guerra Mundial', 'en': 'World War II'}},
#   'from': 'mintaka'},
#  {'id': 'c17ba923',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who was the first king of England?',
#   'target': '¿Quién fue el primer rey de Inglaterra?',
#   'entities': {'Q21': {'es': 'Inglaterra', 'en': 'England'}},
#   'from': 'mintaka'},
#  {'id': '766688b7',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which former mayor of New York ran in the 2008 Republican Primaries?',
#   'target': '¿Qué exalcalde de Nueva York se postuló para las elecciones primarias republicanas en 2008?',
#   'entities': {'Q60': {'es': 'Nueva York', 'en': 'New York City'}},
#   'from': 'mintaka'},
#  {'id': 'e3123fed',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Was the book "Pride and Prejudice" by Jane Austen a crime novel?',
#   'target': '¿El libro de Orgullo y Prejuicio de Jane Austen fue una novela negra?',
#   'entities': {'Q170583': {'es': 'Orgullo y prejuicio',
#     'en': 'Pride and Prejudice'}},
#   'from': 'mintaka'},
#  {'id': 'f0f0f740',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'How many US House of Representative seats does Idaho have?',
#   'target': '¿Cuántas bancas tiene Idaho en la Cámara de Representantes de Estados Unidos?',
#   'entities': {'Q30': {'es': 'Estados Unidos',
#     'en': 'United States of America'}},
#   'from': 'mintaka'},
#  {'id': '1b58d3b7',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Was Tom Cruise in 8 Mile?',
#   'target': '¿Protagonizó Tom Cruise 8 Millas?',
#   'entities': {'Q196665': {'es': '8 Mile', 'en': '8 Mile'}},
#   'from': 'mintaka'},
#  {'id': '70eb3528',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Was Nelson Mandela president of South Africa for five years?',
#   'target': '¿Fue Nelson Mandela presidente de Sudáfrica durante cinco años?',
#   'entities': {'Q258': {'es': 'Sudáfrica', 'en': 'South Africa'}},
#   'from': 'mintaka'},
#  {'id': '661a6cf0',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who was the queen of France and also born an archduchess of Austria?',
#   'target': '¿Quién fue la reina de Francia que también nació archiduquesa de Austria?',
#   'entities': {'Q142': {'es': 'Francia', 'en': 'France'}},
#   'from': 'mintaka'},
#  {'id': 'b4c5f29f',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'How many countries are in Europe but are not part of the EU?',
#   'target': '¿Cuántos países hay en Europa, pero no forman parte de la UE?',
#   'entities': {'Q46': {'es': 'Europa', 'en': 'Europe'}},
#   'from': 'mintaka'},
#  {'id': '03c48d2c',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who was the first woman to fly solo across the Atlantic Ocean?',
#   'target': '¿Cuál fue la primera mujer en volar en solitario a través del Océano Atlántico?',
#   'entities': {'Q97': {'es': 'océano Atlántico', 'en': 'Atlantic Ocean'}},
#   'from': 'mintaka'},
#  {'id': '27eed8d8',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which of the 5 largest airports in the world, ranked by size, is not located in the United States?',
#   'target': '¿Cuál de los 5 aeropuertos más grandes del mundo, clasificados por tamaño, no se encuentran ubicados en los Estados Unidos?',
#   'entities': {'Q30': {'es': 'Estados Unidos',
#     'en': 'United States of America'}},
#   'from': 'mintaka'},
#  {'id': '19df2e0c',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What western states did Joe Biden not win in the 2020 US Presidential Election?',
#   'target': '¿Cuáles son los estados occidentales que no ganó Joe Biden en las elecciones presidenciales de Estados Unidos de 2020?',
#   'entities': {'Q22923830': {'es': 'elecciones presidenciales de Estados Unidos de 2020',
#     'en': '2020 United States presidential election'}},
#   'from': 'mintaka'},
#  {'id': '0f138360',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who was the third ruler of Egypt in the New Kingdom?',
#   'target': '¿Quién fue el tercer gobernante de Egipto en el Imperio Nuevo?',
#   'entities': {'Q79': {'es': 'Egipto', 'en': 'Egypt'}},
#   'from': 'mintaka'},
#  {'id': '6ce61911',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Was Obama the 44th president of the US?',
#   'target': '¿Obama fue el 44º presidente de Estados Unidos?',
#   'entities': {'Q30': {'es': 'Estados Unidos',
#     'en': 'United States of America'}},
#   'from': 'mintaka'},
#  {'id': 'ef7cbab8',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which empire lasted longer, Ottoman Empire or Roma Empire?',
#   'target': '¿Qué imperio duró más: el Imperio Otomano o el Imperio Romano?',
#   'entities': {'Q12560': {'es': 'Imperio otomano', 'en': 'Ottoman Empire'},
#    'Q2277': {'es': 'Imperio romano', 'en': 'Roman Empire'}},
#   'from': 'mintaka'},
#  {'id': '1ba6e4ea',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who united Greece?',
#   'target': '¿Quién unió a Grecia?',
#   'entities': {'Q41': {'es': 'Grecia', 'en': 'Greece'}},
#   'from': 'mintaka'},
#  {'id': '32690332',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What is the second longest river in the United Kingdom?',
#   'target': '¿Cuál es el segundo río más largo del Reino Unido?',
#   'entities': {'Q145': {'es': 'Reino Unido', 'en': 'United Kingdom'}},
#   'from': 'mintaka'},
#  {'id': '57930e07',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': "Who directed the movie that's based on the second book of The Lord of the Rings trilogy?",
#   'target': '¿Quién dirigió la película basada en el segundo libro de la trilogía El Señor de los Anillos?',
#   'entities': {'Q15228': {'es': 'El Señor de los Anillos',
#     'en': 'The Lord of the Rings'}},
#   'from': 'mintaka'},
#  {'id': 'bfd0a887',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which Grammy Award was "I Like It" by Cardi B nominated for but did not win?',
#   'target': '¿Qué nominación a premio Grammy fue I like it de Cardi B, pero no obtuvo ningún premio?',
#   'entities': {'Q41254': {'es': 'premios Grammy', 'en': 'Grammy Award'}},
#   'from': 'mintaka'},
#  {'id': 'e0f8c56d',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What river flows through Russia and is the longest river in Europe?',
#   'target': '¿Qué río pasa por Rusia y es el más largo de Europa?',
#   'entities': {'Q46': {'es': 'Europa', 'en': 'Europe'},
#    'Q159': {'es': 'Rusia', 'en': 'Russia'}},
#   'from': 'mintaka'},
#  {'id': '55e7694a',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which country has a larger population, Pakistan or Brazil?',
#   'target': '¿Qué país tiene población más grande? ¿Paquistán o Brasil?',
#   'entities': {'Q155': {'es': 'Brasil', 'en': 'Brazil'}},
#   'from': 'mintaka'},
#  {'id': 'fa0409cd',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'How many U.S. territories are not populated?',
#   'target': '¿Cuántos territorios de los Estados Unidos no son poblados?',
#   'entities': {'Q30': {'es': 'Estados Unidos',
#     'en': 'United States of America'}},
#   'from': 'mintaka'},
#  {'id': '706d385d',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which MLB player has hit the most home runs in their career?',
#   'target': '¿Qué jugador de las Grandes Ligas de Béisbol ha bateado la mayor cantidad de jonrones en su trayectoria profesional?',
#   'entities': {'Q1163715': {'es': 'Grandes Ligas de Béisbol',
#     'en': 'Major League Baseball'}},
#   'from': 'mintaka'},
#  {'id': '1eda5d4d',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who was president of the United States when Pearl Harbor was attacked?',
#   'target': '¿Quién era Presidente de los Estados Unidos cuando el ataque sobre Pearl Harbor?',
#   'entities': {'Q30': {'es': 'Estados Unidos',
#     'en': 'United States of America'}},
#   'from': 'mintaka'},
#  {'id': 'ff4aab1c',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What was the longest battle in the American Revolutionary War?',
#   'target': '¿Cuál fue la batalla más larga de la Guerra de Independencia de los Estados Unidos?',
#   'entities': {'Q40949': {'es': 'guerra de Independencia de los Estados Unidos',
#     'en': 'American Revolutionary War'}},
#   'from': 'mintaka'},
#  {'id': '78fe9980',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which volcanoes in Hawaii are not extinct?',
#   'target': '¿Qué volcanes de Hawái permanecen activos?',
#   'entities': {'Q782': {'es': 'Hawái', 'en': 'Hawaii'}},
#   'from': 'mintaka'},
#  {'id': '1b9040fa',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What is the estimated population of the smallest state (by land area) in the United States?',
#   'target': '¿Cuál es la población estimada del estado más pequeño (por área terrestre) en los Estados Unidos?',
#   'entities': {'Q30': {'es': 'Estados Unidos',
#     'en': 'United States of America'}},
#   'from': 'mintaka'},
#  {'id': '07cc7c15',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who starred in the movie based on Fear and Loathing in Las Vegas?',
#   'target': '¿Quién protagonizó la película basada en Miedo y Asco en Las Vegas?',
#   'entities': {'Q772435': {'es': 'Miedo y asco en Las Vegas',
#     'en': 'Fear and Loathing in Las Vegas'}},
#   'from': 'mintaka'},
#  {'id': '93896abe',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What was the first civilization in Mexico?',
#   'target': '¿Cuál fue la primera civilización en méxico?',
#   'entities': {'Q96': {'es': 'México', 'en': 'Mexico'}},
#   'from': 'mintaka'},
#  {'id': 'a6466af0',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'In what city is the White House located?',
#   'target': '¿En qué ciudad se ubica la Casa Blanca?',
#   'entities': {'Q35525': {'es': 'Casa Blanca', 'en': 'White House'}},
#   'from': 'mintaka'},
#  {'id': 'ebc7c3f7',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Is Oslo the capital of Norway?',
#   'target': '¿Oslo es la capital de Noruega?',
#   'entities': {'Q20': {'es': 'Noruega', 'en': 'Norway'}},
#   'from': 'mintaka'},
#  {'id': 'cd8f5fdd',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who is the governor of New York?',
#   'target': '¿Quién es el gobernador de Nueva York?',
#   'entities': {'Q1384': {'es': 'Nueva York', 'en': 'New York'}},
#   'from': 'mintaka'},
#  {'id': 'ba95d87e',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which NFL teams from New York did not appear in a Super Bowl in the 1990s?',
#   'target': '¿Qué equipos de la NFL de Nueva York no aparecieron en el Supertazón en los años 90?',
#   'entities': {'Q1384': {'es': 'Nueva York', 'en': 'New York'}},
#   'from': 'mintaka'},
#  {'id': 'ef24a26d',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': "Who designed Washington DC's Vietnam Veteran's Memorial?",
#   'target': '¿Quién diseñó el Monumento a los Veteranos de Vietnam de Washington D. C.?',
#   'entities': {'Q61': {'es': 'Washington D. C.', 'en': 'Washington, D.C.'}},
#   'from': 'mintaka'},
#  {'id': '0525e9c1',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which US president spent the shortest time in office?',
#   'target': '¿Qué presidentes de los Estados Unidos pasó menos tiempo en el cargo?',
#   'entities': {'Q11696': {'es': 'presidente de Estados Unidos',
#     'en': 'President of the United States'}},
#   'from': 'mintaka'},
#  {'id': '01689cae',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which of the Lord of the Rings books is the longest?',
#   'target': '¿Cuál libro de El señor de los anillos es el más largo?',
#   'entities': {'Q15228': {'es': 'El Señor de los Anillos',
#     'en': 'The Lord of the Rings'}},
#   'from': 'mintaka'},
#  {'id': '97ed8d8d',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Did Apollo 13 win Best Picture?',
#   'target': '¿Apolo 13 ganó el premio a la Mejor Película?',
#   'entities': {'Q106428': {'es': 'Apolo 13', 'en': 'Apollo 13'}},
#   'from': 'mintaka'},
#  {'id': '42572190',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Is Puerto Rico a U.S. state?',
#   'target': '¿Es Puerto Rico un estado de los Estados Unidos?',
#   'entities': {'Q30': {'es': 'Estados Unidos',
#     'en': 'United States of America'}},
#   'from': 'mintaka'},
#  {'id': '310409f0',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What is the population of the country where The Great Wall of China is located?',
#   'target': '¿Cuál es la población del país donde se encuentra la Gran Muralla China?',
#   'entities': {'Q12501': {'es': 'Gran Muralla China',
#     'en': 'Great Wall of China'}},
#   'from': 'mintaka'},
#  {'id': '8e11d963',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'How many Original Colonies were there in the US?',
#   'target': '¿Cuántos estados originales había en los Estados Unidos?',
#   'entities': {'Q30': {'es': 'Estados Unidos',
#     'en': 'United States of America'}},
#   'from': 'mintaka'},
#  {'id': 'd330a274',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which U.S. state has a longer coastline, Oregon or Washington?',
#   'target': '¿Qué estado de Estados Unidos tiene una mayor franja costera, Oregón o Washington?',
#   'entities': {'Q30': {'es': 'Estados Unidos',
#     'en': 'United States of America'},
#    'Q824': {'es': 'Oregón', 'en': 'Oregon'}},
#   'from': 'mintaka'},
#  {'id': '0dc05e5b',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What was the last Confederate state to rejoin the Union?',
#   'target': '¿Cuál fue el último estado confederado en reincorporarse a la Unión?',
#   'entities': {'Q214102': {'es': 'Unión', 'en': 'Union'}},
#   'from': 'mintaka'},
#  {'id': 'fa6d3559',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who hosted the Grammys this year?',
#   'target': '¿Quién fue el anfitrión de los premios Grammy este año?',
#   'entities': {'Q41254': {'es': 'premios Grammy', 'en': 'Grammy Award'}},
#   'from': 'mintaka'},
#  {'id': '0db78efa',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'The Eiffel Tower can be found in which European capital city?',
#   'target': '¿En qué ciudad y capital europea se encuentra la Torre Eiffel?',
#   'entities': {'Q243': {'es': 'Torre Eiffel', 'en': 'Eiffel Tower'}},
#   'from': 'mintaka'},
#  {'id': 'fafd8bb6',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who was the oldest person to be inaugurated president of the United States?',
#   'target': '¿Quién es la persona de mayor edad que ha asumido el cargo de presidente de los Estados Unidos?',
#   'entities': {'Q30': {'es': 'Estados Unidos',
#     'en': 'United States of America'}},
#   'from': 'mintaka'},
#  {'id': '2f75520b',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Name the first Republican president of the United States of America?',
#   'target': '¿Cuál es el nombre del primer presidente republicano de Estados Unidos?',
#   'entities': {'Q30': {'es': 'Estados Unidos',
#     'en': 'United States of America'}},
#   'from': 'mintaka'},
#  {'id': '5474e8e4',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which king of England never lost a war?',
#   'target': '¿Cuál rey de Inglaterra nunca perdió una guerra?',
#   'entities': {'Q21': {'es': 'Inglaterra', 'en': 'England'}},
#   'from': 'mintaka'},
#  {'id': '23c90d2d',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'How many active volcanoes are in Hawaii?',
#   'target': '¿Cuántos volcanes activos hay en Hawái?',
#   'entities': {'Q782': {'es': 'Hawái', 'en': 'Hawaii'}},
#   'from': 'mintaka'},
#  {'id': '9ba2150a',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What pivotal naval battle of World War II occurred six months after the Japanese attack on Pearl Harbor?',
#   'target': '¿Qué batalla naval crucial de la Segunda Guerra Mundial ocurrió seis meses después del ataque japonés en Pearl Harbor?',
#   'entities': {'Q17': {'es': 'Japón', 'en': 'Japan'},
#    'Q362': {'es': 'Segunda Guerra Mundial', 'en': 'World War II'}},
#   'from': 'mintaka'},
#  {'id': '4a0b303c',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who has won more Academy Awards, Katharine Hepburn or Daniel Day-Lewis?',
#   'target': '¿Quién ganó más premios de la Academia, Katherine Hepburn o Daniel Day-Lewis?',
#   'entities': {'Q56016': {'es': 'Katharine Hepburn',
#     'en': 'Katharine Hepburn'}},
#   'from': 'mintaka'},
#  {'id': 'ec4104a2',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who is the oldest person to win the Grammy Award for Song of the Year?',
#   'target': '¿Quién es la persona de mayor edad en ganar un premio Grammy a la canción del año?',
#   'entities': {'Q1027904': {'es': 'premio Grammy a la canción del año',
#     'en': 'Grammy Award for Song of the Year'}},
#   'from': 'mintaka'},
#  {'id': 'ec30f356',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'How many governors of Kansas have not been Republicans?',
#   'target': '¿Cuántos gobernadores de Kansan no han sido republicanos?',
#   'entities': {'Q1558': {'es': 'Kansas', 'en': 'Kansas'}},
#   'from': 'mintaka'},
#  {'id': 'eb4668cc',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What is the largest walking trail in the U.S.?',
#   'target': '¿Cuál es el sendero para caminar más largo en los Estados Unidos?',
#   'entities': {'Q30': {'es': 'Estados Unidos',
#     'en': 'United States of America'}},
#   'from': 'mintaka'},
#  {'id': '148a5b90',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who is the tallest actress?',
#   'target': '¿Quién es la actriz más alta?',
#   'entities': {'Q33999': {'es': 'actor', 'en': 'actor'}},
#   'from': 'mintaka'},
#  {'id': 'e66650dc',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who wrote Pride and Prejudice?',
#   'target': '¿Quién escribió Orgullo y prejuicio?',
#   'entities': {'Q170583': {'es': 'Orgullo y prejuicio',
#     'en': 'Pride and Prejudice'}},
#   'from': 'mintaka'},
#  {'id': '04a666ad',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which is larger by area, Brazil or Mongolia?',
#   'target': '¿Quién tiene una mayor superficie, Brasil o Mongolia?',
#   'entities': {'Q155': {'es': 'Brasil', 'en': 'Brazil'}},
#   'from': 'mintaka'},
#  {'id': '51696706',
# ...
#   'entities': {'Q2875': {'es': 'Lo que el viento se llevó',
#     'en': 'Gone with the Wind'}},
#   'from': 'mintaka'},
#  {'id': '504920e3',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'How many Jaws movies have there been?',
#   'target': '¿Cuántas películas hay de Tiburón?',
#   'entities': {'Q189505': {'es': 'Tiburón', 'en': 'Jaws'}},
#   'from': 'mintaka'},
#  {'id': 'f9abc504',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who was the first king of Norway?',
#   'target': '¿Quién fue el primer rey de Noruega?',
#   'entities': {'Q20': {'es': 'Noruega', 'en': 'Norway'}},
#   'from': 'mintaka'},
#  {'id': 'bd2a55d1',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Has Metallica ever won a Grammy Award?',
#   'target': '¿Metallica alguna vez ganó un premio Grammy?',
#   'entities': {'Q41254': {'es': 'premios Grammy', 'en': 'Grammy Award'}},
#   'from': 'mintaka'},
#  {'id': '4da39379',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What United States president served as both president and vice president without being elected?',
#   'target': '¿Qué presidente de los Estados Unidos fue tanto presidente como vicepresidente sin ser electo?',
#   'entities': {'Q11696': {'es': 'presidente de Estados Unidos',
#     'en': 'President of the United States'}},
#   'from': 'mintaka'},
#  {'id': '37619232',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who was the Pope at the beginning of this current millennium 2000 AD?',
#   'target': '¿Quién era el Papa al comienzo de este milenio actual 2000 d. C.?',
#   'entities': {'Q19546': {'es': 'papa', 'en': 'pope'}},
#   'from': 'mintaka'},
#  {'id': 'b6d811c4',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who is a current senator of Utah and a former governor of Massachusetts?',
#   'target': '¿Quién es actualmente senador por Utah y antes gobernador de Massachusetss?',
#   'entities': {'Q771': {'es': 'Massachusetts', 'en': 'Massachusetts'}},
#   'from': 'mintaka'},
#  {'id': 'ea446ac8',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': "Where was the captain of the U.S. women's national soccer team born?",
#   'target': '¿Dónde nació la capitana del equipo femenino de Estados Unidos de sóccer?',
#   'entities': {'Q30': {'es': 'Estados Unidos',
#     'en': 'United States of America'}},
#   'from': 'mintaka'},
#  {'id': 'f565206f',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Is the Nile River the longest river in the world?',
#   'target': '¿El río Nilo es el más largo del mundo?',
#   'entities': {'Q3392': {'es': 'Nilo', 'en': 'Nile'}},
#   'from': 'mintaka'},
#  {'id': '4a0150f4',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'How many people won the 1956 Nobel Prize in Physics?',
#   'target': '¿Cuántas personas ganaron el Premio Nobel de Física en 1956?',
#   'entities': {'Q38104': {'es': 'Premio Nobel de Física',
#     'en': 'Nobel Prize in Physics'}},
#   'from': 'mintaka'},
#  {'id': '15924342',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which Lord of the Rings book has the fewest pages?',
#   'target': '¿Qué libro de El Señor de los Anillos tiene menos páginas?',
#   'entities': {'Q15228': {'es': 'El Señor de los Anillos',
#     'en': 'The Lord of the Rings'}},
#   'from': 'mintaka'},
#  {'id': '4a4114bf',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'How old was the 35th president of the United States when he died?',
#   'target': '¿A qué edad falleció el 35º presidente de los Estados Unidos?',
#   'entities': {'Q30': {'es': 'Estados Unidos',
#     'en': 'United States of America'}},
#   'from': 'mintaka'},
#  {'id': '9ec50e04',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Is Rome the capital of China?',
#   'target': '¿Roma es la capital de China?',
#   'entities': {'Q220': {'es': 'Roma', 'en': 'Rome'}},
#   'from': 'mintaka'},
#  {'id': 'b9150f60',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who was the first vice president of the United States?',
#   'target': '¿Quién fue el primer vicepresidente de Estados Unidos?',
#   'entities': {'Q30': {'es': 'Estados Unidos',
#     'en': 'United States of America'}},
#   'from': 'mintaka'},
#  {'id': '1d44888a',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who was the first Catholic president of the United States?',
#   'target': '¿Quién fue el primer presidente católico de los Estados Unidos?',
#   'entities': {'Q30': {'es': 'Estados Unidos',
#     'en': 'United States of America'}},
#   'from': 'mintaka'},
#  {'id': '25cbed13',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What was the first monument erected in America?',
#   'target': '¿Cuál fue el primer monumento erigido en Estados Unidos?',
#   'entities': {'Q30': {'es': 'Estados Unidos',
#     'en': 'United States of America'}},
#   'from': 'mintaka'},
#  {'id': 'f3fa6401',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What year did the Battle of Midway take place?',
#   'target': '¿En qué año tuvo lugar la batalla de Midway?',
#   'entities': {'Q173034': {'es': 'Batalla de Midway',
#     'en': 'Battle of Midway'}},
#   'from': 'mintaka'},
#  {'id': '5b8482dd',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which new Orléans native claimed to be the father of jazz music?',
#   'target': '¿Qué nativo de Nueva Orleans reclamó ser el padre de la música jazz?',
#   'entities': {'Q34404': {'es': 'Nueva Orleans', 'en': 'New Orleans'}},
#   'from': 'mintaka'},
#  {'id': '699e17c7',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Did Dr. Dre win a Grammy for "Let me ride"?',
#   'target': '¿Ganó Dr Dre un Grammy por Let me ride?',
#   'entities': {'Q6078': {'es': 'Dr. Dre', 'en': 'Dr. Dre'}},
#   'from': 'mintaka'},
#  {'id': 'bead4e52',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What was Bangkok nicknamed in the nineteenth century?',
#   'target': '¿Cómo se apodó a Bankok en el siglo XIX?',
#   'entities': {'Q1861': {'es': 'Bangkok', 'en': 'Bangkok'}},
#   'from': 'mintaka'},
#  {'id': '4e2671e1',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who was the first United States president?',
#   'target': '¿Quién fue el primer presidente de los Estados Unidos?',
#   'entities': {'Q30': {'es': 'Estados Unidos',
#     'en': 'United States of America'}},
#   'from': 'mintaka'},
#  {'id': 'f18090c8',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What is the largest city in Mexico by population?',
#   'target': '¿Cuál es la ciudad más grande de México por población?',
#   'entities': {'Q96': {'es': 'México', 'en': 'Mexico'}},
#   'from': 'mintaka'},
#  {'id': 'e1094823',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'How many U.S. states did Bernie Sanders win in the 2020 Democratic Party Primaries?',
#   'target': '¿En cuántos estados de los EE. UU. ganó Bernie Sanders en las primarias del partido demócrata de 2020?',
#   'entities': {'Q29552': {'es': 'Partido Demócrata',
#     'en': 'Democratic Party'}},
#   'from': 'mintaka'},
#  {'id': 'b7ccd8f4',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which World War I offensive had the most casualties?',
#   'target': '¿Qué ofensiva de la Primera Guerra Mundial tuvo mayor bajas?',
#   'entities': {'Q361': {'es': 'Primera Guerra Mundial', 'en': 'World War I'}},
#   'from': 'mintaka'},
#  {'id': '2f692c5c',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'How many Republican mayors has New York City had since 1974?',
#   'target': '¿Cuántos alcaldes republicanos ha tenido la ciudad de Nueva York desde 1974?',
#   'entities': {'Q60': {'es': 'Nueva York', 'en': 'New York City'}},
#   'from': 'mintaka'},
#  {'id': 'dede6343',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'How many islands in the Caribbean are over 29,000 square miles?',
#   'target': '¿Cuántas islas del Caribe tiene más de 29 000 millas cuadradas?',
#   'entities': {'Q664609': {'es': 'Caribe', 'en': 'Caribbean'}},
#   'from': 'mintaka'},
#  {'id': '6f051299',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'How many books are in the Bible?',
#   'target': '¿Cuántos libros contiene la Biblia?',
#   'entities': {'Q1845': {'es': 'Biblia', 'en': 'Bible'}},
#   'from': 'mintaka'},
#  {'id': 'e527e00b',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who was the first female pharaoh of Egypt?',
#   'target': '¿Quién fue la primera faraona mujer en Egipto?',
#   'entities': {'Q79': {'es': 'Egipto', 'en': 'Egypt'}},
#   'from': 'mintaka'},
#  {'id': '56b1e4c8',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What is the nickname for New Orléans?',
#   'target': '¿Qué sobrenombre tiene Nueva Orleans?',
#   'entities': {'Q34404': {'es': 'Nueva Orleans', 'en': 'New Orleans'}},
#   'from': 'mintaka'},
#  {'id': '9b71e0bf',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Was Caligula the third emperor of Rome?',
#   'target': '¿Calígula fue el tercer emperador de Roma?',
#   'entities': {'Q220': {'es': 'Roma', 'en': 'Rome'},
#    'Q1409': {'es': 'Calígula', 'en': 'Caligula'}},
#   'from': 'mintaka'},
#  {'id': '91ae4541',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which country has a larger population, Canada or China?',
#   'target': '¿Qué país tiene más habitantes, Canadá o China?',
#   'entities': {'Q16': {'es': 'Canadá', 'en': 'Canada'}},
#   'from': 'mintaka'},
#  {'id': '6b22aff8',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which Lord of the Rings movie did not get nominated for the Best Director Oscar?',
#   'target': '¿Qué película de la saga de El Señor de los Anillos no fue nominada al Óscar para Mejor Director?',
#   'entities': {'Q190214': {'es': 'El Señor de los Anillos',
#     'en': 'The Lord of the Rings trilogy'}},
#   'from': 'mintaka'},
#  {'id': 'e6cc1fde',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which colony became the first state in the US?',
#   'target': '¿Qué colonia se convirtió en el primer estado de los Estados Unidos?',
#   'entities': {'Q30': {'es': 'Estados Unidos',
#     'en': 'United States of America'}},
#   'from': 'mintaka'},
#  {'id': '32be4b89',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who was the German dictator that started World War II and was married to Eva Braun shortly before their death?',
#   'target': '¿Quién era el dictador alemán que dio inicio a la Segunda Guerra Mundial y estuvo casado con Eva Braun poco antes de su muerte?',
#   'entities': {'Q362': {'es': 'Segunda Guerra Mundial', 'en': 'World War II'}},
#   'from': 'mintaka'},
#  {'id': 'cb89fc4c',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Where is the actor who played Captain Jack Sparrow from?',
#   'target': '¿De dónde es el actor que interpretó al Capitán Jack Sparrow?',
#   'entities': {'Q202857': {'es': 'Jack Sparrow',
#     'en': 'Captain Jack Sparrow'}},
#   'from': 'mintaka'},
#  {'id': '7836c9bd',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Did the USA side with Germany in World War II?',
#   'target': '¿Peleó Estados Unidos junto a Alemania en la Segunda Guerra Mundial?',
#   'entities': {'Q362': {'es': 'Segunda Guerra Mundial', 'en': 'World War II'},
#    'Q183': {'es': 'Alemania', 'en': 'Germany'},
#    'Q30': {'es': 'Estados Unidos', 'en': 'United States of America'}},
#   'from': 'mintaka'},
#  {'id': '1a1d9478',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Are the Rolling Stones from the UK?',
#   'target': '¿Los Rolling Stones son del Reino Unido?',
#   'entities': {'Q145': {'es': 'Reino Unido', 'en': 'United Kingdom'}},
#   'from': 'mintaka'},
#  {'id': 'd3857175',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which state came first in the Union, Pennsylvania or Delaware?',
#   'target': '¿Qué estado se asoció primero a la unión: Pensilvania o Delaware?',
#   'entities': {'Q1400': {'es': 'Pensilvania', 'en': 'Pennsylvania'}},
#   'from': 'mintaka'},
#  {'id': 'e85bf7ac',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which Game of Thrones battle is the longest?',
#   'target': '¿Qué batalla de Juego de Tronos es la más larga?',
#   'entities': {'Q23572': {'es': 'Juego de Tronos', 'en': 'Game of Thrones'}},
#   'from': 'mintaka'},
#  {'id': 'e1e3808a',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Is Jacinda Ardern the 40th prime minister of New Zealand?',
#   'target': '¿Jacinda Ardern es la 40º primera ministra de Nueva Zelanda?',
#   'entities': {'Q664': {'es': 'Nueva Zelanda', 'en': 'New Zealand'}},
#   'from': 'mintaka'},
#  {'id': '0a0600c3',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What country has a higher population, Germany or Cambodia?',
#   'target': '¿Cuál de estos países tiene más densidad de población; Alemania o Camboya?',
#   'entities': {'Q183': {'es': 'Alemania', 'en': 'Germany'},
#    'Q424': {'es': 'Camboya', 'en': 'Cambodia'}},
#   'from': 'mintaka'},
#  {'id': 'bfbd5e8b',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'In what country is the Great Wall of China located?',
#   'target': '¿En qué país se ubica la Gran Muralla China?',
#   'entities': {'Q12501': {'es': 'Gran Muralla China',
#     'en': 'Great Wall of China'}},
#   'from': 'mintaka'},
#  {'id': '448888db',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which book is longer, The Lord of the Rings or Atlas Shrugged?',
#   'target': '¿Qué libro es más largo: El señor de los anillos o La rebelión del Atlas?',
#   'entities': {'Q374098': {'es': 'La rebelión de Atlas',
#     'en': 'Atlas Shrugged'},
#    'Q15228': {'es': 'El Señor de los Anillos', 'en': 'The Lord of the Rings'}},
#   'from': 'mintaka'},
#  {'id': 'c80fcaa3',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Who ran for president in 2020 and graduated from the University of Pennsylvania?',
#   'target': '¿Quién compitió en las elecciones presidenciales de 2020 y se graduó en la Universidad de Pensilvania?',
#   'entities': {'Q49117': {'es': 'Universidad de Pensilvania',
#     'en': 'University of Pennsylvania'}},
#   'from': 'mintaka'},
#  {'id': '71a173fc',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'When did the Saxons invade England?',
#   'target': '¿Cuándo invadieron Inglaterra los sajones?',
#   'entities': {'Q21': {'es': 'Inglaterra', 'en': 'England'}},
#   'from': 'mintaka'},
#  {'id': 'b41213f2',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which country has a larger population, Russia or Japan?',
#   'target': '¿Cuál de estos países tiene mayor población: Rusia o Japón?',
#   'entities': {'Q159': {'es': 'Rusia', 'en': 'Russia'},
#    'Q17': {'es': 'Japón', 'en': 'Japan'}},
#   'from': 'mintaka'},
#  {'id': '2c11c7d8',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'Which Chronicles of Narnia books have not been made into a movie distributed by Disney?',
#   'target': '¿Cuál libro de Las Cronicas de Narnia no fue adaptado a película distribuida por Disney?',
#   'entities': {'Q483412': {'es': 'Las Crónicas de Narnia',
#     'en': 'The Chronicles of Narnia'}},
#   'from': 'mintaka'},
#  {'id': '682d44ee',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What is on top of the Washington Monument?',
#   'target': '¿Qué está en la cima del monumento a Washington?',
#   'entities': {'Q178114': {'es': 'Monumento a Washington',
#     'en': 'Washington Monument'}},
#   'from': 'mintaka'},
#  {'id': '0363194f',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What United States president was the tallest and the first to have a full beard?',
#   'target': '¿Cuál presidente de los Estados Unidos fue el más alto y el primero que tuvo una barba completa?',
#   'entities': {'Q30': {'es': 'Estados Unidos',
#     'en': 'United States of America'}},
#   'from': 'mintaka'},
#  {'id': '903b74bb',
#   'source_locale': 'en',
#   'target_locale': 'es',
#   'source': 'What river flows through Brazil and is the longest river in South America?',
#   'target': '¿Qué río pasa por Brasil y es el más largo en Sudamérica?',
#   'entities': {'Q155': {'es': 'Brasil', 'en': 'Brazil'}},
#   'from': 'mintaka'}]

# %%
print("Loading SpanMarker model...")
spanmarker_model = SpanMarkerModel.from_pretrained("tomaarsen/span-marker-mbert-base-multinerd")
ensure_pad_token(spanmarker_model)
# Out:
# Loading SpanMarker model...
# The new embeddings will be initialized from a multivariate normal distribution that has old embeddings' mean and covariance. As described in this article: https://nlp.stanford.edu/~johnhew/vocab-expansion.html. To disable this, use `mean_resizing=False`
# Setting pad_token manually...

# %%
print("Loading M2M100 translation model...")
m2m_model = M2M100ForConditionalGeneration.from_pretrained("facebook/m2m100_418M")
m2m_tokenizer = M2M100Tokenizer.from_pretrained("facebook/m2m100_418M")
# Out:
# Loading M2M100 translation model...

# %%
translated_sentences = []

for idx, entry in enumerate(spanish_data):  # Process only the first 10 entries

    # Get source text (English) and target text (Italian)
    eng_text = entry['source']
    esp_text = entry['target']

    # Mask entities in the English text
    masked_eng_text, mapping = mask_entities_with_spanmarker(eng_text, spanmarker_model)
    print(f"Masked English Text: {masked_eng_text}")
    print(f"Entity Mapping: {json.dumps(mapping, indent=4)}")

    # Filter entities by confidence score
    filtered_mapping = {
        key: value for key, value in mapping.items() if value["confidence"] > 0.8
    }
    print(f"Filtered Mapping (Confidence > 0.8): {json.dumps(filtered_mapping, indent=4)}")

    # Translate non-entity parts of the text
    m2m_tokenizer.src_lang = "en"
    tgt_lang = "it"
    translated_text_with_placeholders = translate_with_placeholders_m2m(
        masked_eng_text, filtered_mapping, src_lang="en", tgt_lang="es"
    )
    print(f"Translated Text with Placeholders: {translated_text_with_placeholders}")

    # Reintegrate entities into the translated text
    final_translation = reintegrate_entities(
        translated_text_with_placeholders, filtered_mapping, src_lang="en", tgt_lang="es"
    )
    print(f"Final Translation: {final_translation}")

    # Append final translation to the results
    translated_sentences.append({
        "id": entry["id"],
        "source": eng_text,
        "target": esp_text,
        "masked_source": masked_eng_text,
        "translation": final_translation,
        "filtered_mapping": filtered_mapping
    })

# Save the results
results_path = "data/translated_spanish_test.json"
with open(results_path, "w") as results_file:
    json.dump(translated_sentences, results_file, indent=4)

print(f"Translation results for test set saved to {results_path}")
# Out:
# Masked English Text: Who was the first son of [ENTITY_PER_1]'s second wife?
# Entity Mapping: {
#     "[ENTITY_PER_1]": {
#         "original_text": "Peter the Great",
#         "type": "PER",
#         "confidence": 0.9930858612060547,
#         "start": 25,
#         "end": 40
#     }
# }
# Filtered Mapping (Confidence > 0.8): {
#     "[ENTITY_PER_1]": {
#         "original_text": "Peter the Great",
#         "type": "PER",
#         "confidence": 0.9930858612060547,
#         "start": 25,
#         "end": 40
#     }
# }
# Translated Text with Placeholders: ¿Quién fue el primer hijo de la segunda esposa de [ENTITY_PER_1]?
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Final Translation: ¿Quién fue el primer hijo de la segunda esposa de Pedro el Gran?
# Masked English Text: Who is considered the founder of the [ENTITY_TIME_1] in ancient [ENTITY_LOC_1]?
# Entity Mapping: {
#     "[ENTITY_TIME_1]": {
#         "original_text": "Xia dynasty",
#         "type": "TIME",
#         "confidence": 0.41634589433670044,
#         "start": 37,
#         "end": 48
#     },
#     "[ENTITY_LOC_1]": {
#         "original_text": "China",
#         "type": "LOC",
#         "confidence": 0.9988638162612915,
#         "start": 64,
#         "end": 69
#     }
# }
# Filtered Mapping (Confidence > 0.8): {
#     "[ENTITY_LOC_1]": {
#         "original_text": "China",
#         "type": "LOC",
#         "confidence": 0.9988638162612915,
#         "start": 64,
#         "end": 69
#     }
# }
# Translated Text with Placeholders: ¿Quién es considerado el fundador de [ENTITY_TIME_1] en el antiguo [ENTITY_LOC_1]?
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Final Translation: ¿Quién es considerado el fundador de [ENTITY_TIME_1] en el antiguo China?
# Masked English Text: Who was in charge of [ENTITY_LOC_1] during [ENTITY_EVE_1]?
# Entity Mapping: {
#     "[ENTITY_LOC_1]": {
#         "original_text": "Great Britain",
#         "type": "LOC",
#         "confidence": 0.9999412298202515,
#         "start": 21,
#         "end": 34
#     },
#     "[ENTITY_EVE_1]": {
#         "original_text": "World War 2",
#         "type": "EVE",
#         "confidence": 0.9996432065963745,
#         "start": 43,
#         "end": 54
#     }
# }
# Filtered Mapping (Confidence > 0.8): {
#     "[ENTITY_LOC_1]": {
#         "original_text": "Great Britain",
#         "type": "LOC",
#         "confidence": 0.9999412298202515,
#         "start": 21,
#         "end": 34
#     },
#     "[ENTITY_EVE_1]": {
#         "original_text": "World War 2",
#         "type": "EVE",
#         "confidence": 0.9996432065963745,
#         "start": 43,
#         "end": 54
#     }
# }
# Translated Text with Placeholders: ¿Quién fue responsable de [ENTITY_LOC_1] durante [ENTITY_EVE_1]?
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Final Translation: ¿Quién fue responsable de Gran Bretaña durante Guerra Mundial 2?
# Masked English Text: What is the longest river in the [ENTITY_LOC_1] that also flows through [ENTITY_LOC_2] and [ENTITY_LOC_3]?
# Entity Mapping: {
#     "[ENTITY_LOC_1]": {
#         "original_text": "UK",
#         "type": "LOC",
#         "confidence": 0.9996622800827026,
#         "start": 33,
#         "end": 35
#     },
#     "[ENTITY_LOC_2]": {
#         "original_text": "Wales",
#         "type": "LOC",
#         "confidence": 0.9999678134918213,
#         "start": 72,
#         "end": 77
#     },
#     "[ENTITY_LOC_3]": {
#         "original_text": "England",
#         "type": "LOC",
#         "confidence": 0.9999411106109619,
#         "start": 91,
#         "end": 98
#     }
# }
# Filtered Mapping (Confidence > 0.8): {
#     "[ENTITY_LOC_1]": {
#         "original_text": "UK",
#         "type": "LOC",
#         "confidence": 0.9996622800827026,
#         "start": 33,
#         "end": 35
#     },
#     "[ENTITY_LOC_2]": {
#         "original_text": "Wales",
#         "type": "LOC",
#         "confidence": 0.9999678134918213,
#         "start": 72,
#         "end": 77
#     },
#     "[ENTITY_LOC_3]": {
#         "original_text": "England",
#         "type": "LOC",
#         "confidence": 0.9999411106109619,
#         "start": 91,
#         "end": 98
#     }
# }
# Translated Text with Placeholders: ¿Cuál es el río más largo en [ENTITY_LOC_1] que también fluye a través de [ENTITY_LOC_2] y [ENTITY_LOC_3]?
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Final Translation: ¿Cuál es el río más largo en Reino Unido que también fluye a través de El País de Gales y Inglaterra?
# Masked English Text: How many states are in the [ENTITY_LOC_1]?
# Entity Mapping: {
#     "[ENTITY_LOC_1]": {
#         "original_text": "United States",
#         "type": "LOC",
#         "confidence": 0.999936580657959,
#         "start": 27,
#         "end": 40
#     }
# }
# Filtered Mapping (Confidence > 0.8): {
#     "[ENTITY_LOC_1]": {
#         "original_text": "United States",
#         "type": "LOC",
#         "confidence": 0.999936580657959,
#         "start": 27,
#         "end": 40
#     }
# }
# Translated Text with Placeholders: ¿Cuántos estados hay en el [ENTITY_LOC_1]?
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Final Translation: ¿Cuántos estados hay en el Estados Unidos?
# Masked English Text: What is the tallest point in the 3rd smallest country in [ENTITY_LOC_1]?
# Entity Mapping: {
#     "[ENTITY_LOC_1]": {
#         "original_text": "Europe",
#         "type": "LOC",
#         "confidence": 0.999890923500061,
#         "start": 57,
#         "end": 63
#     }
# }
# Filtered Mapping (Confidence > 0.8): {
#     "[ENTITY_LOC_1]": {
#         "original_text": "Europe",
#         "type": "LOC",
#         "confidence": 0.999890923500061,
#         "start": 57,
#         "end": 63
#     }
# }
# Translated Text with Placeholders: ¿Cuál es el punto más alto en el tercer país más pequeño en [ENTITY_LOC_1]?
